# %% [markdown]
# # HM2: Numerical Optimization for Logistic Regression.
#
# ### Name: Michael Eng

# %% [markdown]
# ## 0. You will do the following:
#
# 1. Read the lecture note: [click here](https://github.com/wangshusen/DeepLearning/blob/master/LectureNotes/Logistic/paper/logistic.pdf)
#
# 2. Read, complete, and run my code.
#
# 3. **Implement mini-batch SGD** and evaluate the performance.
#
# 4. Convert the .IPYNB file to .HTML file.
#
#     * The HTML file must contain **the code** and **the output after execution**.
#
#     * Missing **the output after execution** will not be graded.
#
# 5. Upload this .HTML file to your Google Drive, Dropbox, or your Github repo.  (If you submit the file to Google Drive or Dropbox, you must make the file "open-access". The delay caused by "deny of access" may result in late penalty.)
#
# 6. Submit the link to this .HTML file to Canvas.
#
#     * Example: https://github.com/wangshusen/CS583-2020S/blob/master/homework/HM2/HM2.html
#
#
# ## Grading criteria:
#
# 1. When computing the ```gradient``` and ```objective function value``` using a batch of samples, use **matrix-vector multiplication** rather than a FOR LOOP of **vector-vector multiplications**.
#
# 2. Plot ```objective function value``` against ```epochs```. In the plot, compare GD, SGD, and MB-SGD (with $b=8$ and $b=64$). The plot must look reasonable.

# %% [markdown]
# # 1. Data processing
#
# - Download the Diabete dataset from https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/diabetes
# - Load the data using sklearn.
# - Preprocess the data.

# %% [markdown]
# ## 1.1. Load the data

# %%
from sklearn import datasets
import numpy

x_sparse, y = datasets.load_svmlight_file('diabetes')
x = x_sparse.todense()

print('Shape of x: ' + str(x.shape))
print('Shape of y: ' + str(y.shape))
# Out:
# Shape of x: (768, 8)
# Shape of y: (768,)

# %% [markdown]
# ## 1.2. Partition to training and test sets

# %%
# partition the data to training and test sets
n = x.shape[0]
n_train = 640
n_test = n - n_train

rand_indices = numpy.random.permutation(n)
train_indices = rand_indices[0:n_train]
test_indices = rand_indices[n_train:n]

x_train = x[train_indices, :]
x_test = x[test_indices, :]
y_train = y[train_indices].reshape(n_train, 1)
y_test = y[test_indices].reshape(n_test, 1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train.shape))
print('Shape of y_test: ' + str(y_test.shape))
# Out:
# Shape of x_train: (640, 8)
# Shape of x_test: (128, 8)
# Shape of y_train: (640, 1)
# Shape of y_test: (128, 1)

# %% [markdown]
# ## 1.3. Feature scaling

# %% [markdown]
# Use the standardization to trainsform both training and test features

# %%
# Standardization
import numpy

# calculate mu and sig using the training set
d = x_train.shape[1]
mu = numpy.mean(x_train, axis=0).reshape(1, d)
sig = numpy.std(x_train, axis=0).reshape(1, d)

# transform the training features
x_train = (x_train - mu) / (sig + 1E-6)

# transform the test features
x_test = (x_test - mu) / (sig + 1E-6)

print('test mean = ')
print(numpy.mean(x_test, axis=0))

print('test std = ')
print(numpy.std(x_test, axis=0))
# Out:
# test mean =
# [[-0.01426002 -0.0214525   0.0142114  -0.01920219 -0.03301505 -0.02590305
#    0.10470225  0.11214563]]
# test std =
# [[0.94688349 0.96788453 0.96314811 0.99725731 0.94316074 0.86209049
#   1.1834352  1.09614732]]

# %% [markdown]
# ## 1.4. Add a dimension of all ones

# %%
n_train, d = x_train.shape
x_train = numpy.concatenate((x_train, numpy.ones((n_train, 1))), axis=1)

n_test, d = x_test.shape
x_test = numpy.concatenate((x_test, numpy.ones((n_test, 1))), axis=1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
# Out:
# Shape of x_train: (640, 9)
# Shape of x_test: (128, 9)

# %% [markdown]
# # 2. Logistic regression model
#
# The objective function is $Q (w; X, y) = \frac{1}{n} \sum_{i=1}^n \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.

# %%
# Calculate the objective function value
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     objective function value (scalar)
def objective(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(-yxw) # n-by-1 matrix
    vec2 = numpy.log(1 + vec1) # n-by-1 matrix
    loss = numpy.mean(vec2) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    return loss + reg

# %%
# initialize w
d = x_train.shape[1]
w = numpy.zeros((d, 1))

# evaluate the objective function value at w
lam = 1E-6
objval0 = objective(w, x_train, y_train, lam)
print('Initial objective function value = ' + str(objval0))
# Out:
# Initial objective function value = 0.6931471805599453

# %% [markdown]
# # 3. Numerical optimization

# %% [markdown]
# ## 3.1. Gradient descent

# %% [markdown]
# The gradient at $w$ is $g = - \frac{1}{n} \sum_{i=1}^n \frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$

# %%
# Calculate the gradient
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     g: g: d-by-1 matrix, full gradient
def gradient(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(yxw) # n-by-1 matrix
    vec2 = numpy.divide(yx, 1+vec1) # n-by-d matrix
    vec3 = -numpy.mean(vec2, axis=0).reshape(d, 1) # d-by-1 matrix
    g = vec3 + lam * w
    return g

# %%
# Gradient descent for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_iter: integer, the maximal iterations
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: d-by-1 matrix, the solution
#     objvals: a record of each iteration's objective value
def grad_descent(x, y, lam, stepsize, max_iter=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_iter) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_iter):
        objval = objective(w, x, y, lam)
        objvals[t] = objval
        print('Objective value at t=' + str(t) + ' is ' + str(objval))
        g = gradient(w, x, y, lam)
        w -= stepsize * g
    
    return w, objvals

# %% [markdown]
# Run gradient descent.

# %%
lam = 1E-6
stepsize = 1.0
w, objvals_gd = grad_descent(x_train, y_train, lam, stepsize)
# Out:
# Objective value at t=0 is 0.6931471805599453
# Objective value at t=1 is 0.585037238763272
# Objective value at t=2 is 0.5418677512636944
# Objective value at t=3 is 0.5188175653602003
# Objective value at t=4 is 0.5044361886968358
# Objective value at t=5 is 0.4946618562860769
# Objective value at t=6 is 0.4876623461162789
# Objective value at t=7 is 0.4824717335614427
# Objective value at t=8 is 0.47852461776919225
# Objective value at t=9 is 0.4754651701813792
# Objective value at t=10 is 0.47305752800114365
# Objective value at t=11 is 0.4711391959768166
# Objective value at t=12 is 0.46959483062078683
# Objective value at t=13 is 0.4683405719381968
# Objective value at t=14 is 0.46731422884952234
# Objective value at t=15 is 0.46646889889866394
# Objective value at t=16 is 0.46576869404753163
# Objective value at t=17 is 0.4651858050206751
# Objective value at t=18 is 0.46469844173768643
# Objective value at t=19 is 0.4642893614705294
# Objective value at t=20 is 0.4639447997170621
# Objective value at t=21 is 0.4636536821867398
# Objective value at t=22 is 0.46340703628133795
# Objective value at t=23 is 0.4631975462741254
# Objective value at t=24 is 0.46301921340961305
# Objective value at t=25 is 0.4628670935685747
# Objective value at t=26 is 0.46273709293543275
# Objective value at t=27 is 0.4626258075003215
# Objective value at t=28 is 0.46253039601477247
# Objective value at t=29 is 0.4624484787113133
# Objective value at t=30 is 0.4623780560327398
# Objective value at t=31 is 0.46231744302406064
# Objective value at t=32 is 0.46226521607391385
# Objective value at t=33 is 0.46222016945909955
# Objective value at t=34 is 0.4621812797199287
# Objective value at t=35 is 0.4621476763275262
# Objective value at t=36 is 0.46211861743417837
# Objective value at t=37 is 0.4620934697508986
# Objective value at t=38 is 0.4620716917919365
# Objective value at t=39 is 0.46205281987808083
# Objective value at t=40 is 0.46203645640970387
# Objective value at t=41 is 0.46202226001432745
# Objective value at t=42 is 0.4620099372478174
# Objective value at t=43 is 0.4619992355875283
# Objective value at t=44 is 0.4619899375031286
# Objective value at t=45 is 0.46198185542898085
# Objective value at t=46 is 0.4619748274927783
# Objective value at t=47 is 0.4619687138801621
# Objective value at t=48 is 0.4619633937354439
# Objective value at t=49 is 0.46195876251524104
# Objective value at t=50 is 0.4619547297255389
# Objective value at t=51 is 0.46195121698398367
# Objective value at t=52 is 0.4619481563585482
# Objective value at t=53 is 0.46194548894145
# Objective value at t=54 is 0.461943163623642
# Objective value at t=55 is 0.4619411360405646
# Objective value at t=56 is 0.4619393676643359
# Objective value at t=57 is 0.4619378250213222
# Objective value at t=58 is 0.4619364790171913
# Objective value at t=59 is 0.461935304354211
# Objective value at t=60 is 0.46193427902780604
# Objective value at t=61 is 0.4619333838912814
# Objective value at t=62 is 0.4619326022792305
# Objective value at t=63 is 0.46193191968151054
# Objective value at t=64 is 0.4619313234608282
# Objective value at t=65 is 0.461930802607966
# Objective value at t=66 is 0.46193034752951967
# Objective value at t=67 is 0.46192994986373864
# Objective value at t=68 is 0.4619296023206734
# Objective value at t=69 is 0.46192929854336084
# Objective value at t=70 is 0.4619290329872275
# Objective value at t=71 is 0.46192880081528004
# Objective value at t=72 is 0.4619285978069821
# Objective value at t=73 is 0.4619284202790007
# Objective value at t=74 is 0.46192826501625567
# Objective value at t=75 is 0.46192812921191184
# Objective value at t=76 is 0.4619280104151389
# Objective value at t=77 is 0.4619279064856222
# Objective value at t=78 is 0.4619278155539373
# Objective value at t=79 is 0.46192773598702874
# Objective value at t=80 is 0.4619276663581238
# Objective value at t=81 is 0.46192760542050804
# Objective value at t=82 is 0.46192755208466074
# Objective value at t=83 is 0.46192750539831545
# Objective value at t=84 is 0.46192746452906863
# Objective value at t=85 is 0.4619274287492071
# Objective value at t=86 is 0.46192739742246985
# Objective value at t=87 is 0.46192736999249295
# Objective value at t=88 is 0.4619273459727261
# Objective value at t=89 is 0.46192732493762784
# Objective value at t=90 is 0.46192730651497776
# Objective value at t=91 is 0.4619272903791649
# Objective value at t=92 is 0.4619272762453227
# Objective value at t=93 is 0.46192726386420857
# Objective value at t=94 is 0.4619272530177289
# Objective value at t=95 is 0.46192724351502956
# Objective value at t=96 is 0.4619272351890793
# Objective value at t=97 is 0.4619272278936838
# Objective value at t=98 is 0.4619272215008761
# Objective value at t=99 is 0.46192721589863495

# %% [markdown]
# ## 3.2. Stochastic gradient descent (SGD)
#
# Define $Q_i (w) = \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.
#
# The stochastic gradient at $w$ is $g_i = \frac{\partial Q_i }{ \partial w} = -\frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_i and the gradient of Q_i
# Inputs:
#     w: d-by-1 matrix
#     xi: 1-by-d matrix
#     yi: scalar
#     lam: scalar, the regularization parameter
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def stochastic_objective_gradient(w, xi, yi, lam):
    d = xi.shape[0]
    yx = yi * xi # 1-by-d matrix
    yxw = float(numpy.dot(yx, w)) # scalar
    
    # calculate objective function Q_i
    loss = numpy.log(1 + numpy.exp(-yxw)) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    obj = loss + reg
    
    # calculate stochastic gradient
    g_loss = -yx.T / (1 + numpy.exp(yxw)) # d-by-1 matrix
    g = g_loss + lam * w # d-by-1 matrix
    
    return obj, g

# %%
# SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def sgd(x, y, lam, stepsize, max_epoch=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_epoch) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_epoch):
        # randomly shuffle the samples
        rand_indices = numpy.random.permutation(n)
        x_rand = x[rand_indices, :]
        y_rand = y[rand_indices, :]
        
        objval = 0 # accumulate the objective values
        for i in range(n):
            xi = x_rand[i, :] # 1-by-d matrix
            yi = float(y_rand[i, :]) # scalar
            obj, g = stochastic_objective_gradient(w, xi, yi, lam)
            objval += obj
            w -= stepsize * g
        
        stepsize *= 0.9 # decrease step size
        objval /= n
        objvals[t] = objval
        print('Objective value at epoch t=' + str(t) + ' is ' + str(objval))
    
    return w, objvals

# %% [markdown]
# Run SGD.

# %%
lam = 1E-6
stepsize = 0.1
w, objvals_sgd = sgd(x_train, y_train, lam, stepsize)
# Out:
# Objective value at epoch t=0 is 0.5297505540310775
# Objective value at epoch t=1 is 0.5067633268048698
# Objective value at epoch t=2 is 0.5013113534657341
# Objective value at epoch t=3 is 0.5014539343699199
# Objective value at epoch t=4 is 0.4930303287455546
# Objective value at epoch t=5 is 0.49275783630729003
# Objective value at epoch t=6 is 0.4820457703080809
# Objective value at epoch t=7 is 0.49186810067311315
# Objective value at epoch t=8 is 0.48016620043864205
# Objective value at epoch t=9 is 0.4790141454607807
# Objective value at epoch t=10 is 0.47902081592160856
# Objective value at epoch t=11 is 0.48082132040090836
# Objective value at epoch t=12 is 0.4757383944592851
# Objective value at epoch t=13 is 0.47795193792634566
# Objective value at epoch t=14 is 0.47639197004544487
# Objective value at epoch t=15 is 0.472696169174473
# Objective value at epoch t=16 is 0.47341266982661906
# Objective value at epoch t=17 is 0.471284799063484
# Objective value at epoch t=18 is 0.4703926415707874
# Objective value at epoch t=19 is 0.4700440010995056
# Objective value at epoch t=20 is 0.4691954760748769
# Objective value at epoch t=21 is 0.4690394380480205
# Objective value at epoch t=22 is 0.4682783123494515
# Objective value at epoch t=23 is 0.4677368124300078
# Objective value at epoch t=24 is 0.4671539774903207
# Objective value at epoch t=25 is 0.46632577388348195
# Objective value at epoch t=26 is 0.46657995217822534
# Objective value at epoch t=27 is 0.46577032009126074
# Objective value at epoch t=28 is 0.4655089980933643
# Objective value at epoch t=29 is 0.46530377376783427
# Objective value at epoch t=30 is 0.4647623036939912
# Objective value at epoch t=31 is 0.46463254062620224
# Objective value at epoch t=32 is 0.4642188692670601
# Objective value at epoch t=33 is 0.4639439892235866
# Objective value at epoch t=34 is 0.4638836284144487
# Objective value at epoch t=35 is 0.46376344251223334
# Objective value at epoch t=36 is 0.4635446026828123
# Objective value at epoch t=37 is 0.4633786126491957
# Objective value at epoch t=38 is 0.4631986078561643
# Objective value at epoch t=39 is 0.463119105421024
# Objective value at epoch t=40 is 0.46300243201145286
# Objective value at epoch t=41 is 0.4628896591739327
# Objective value at epoch t=42 is 0.46278933932203625
# Objective value at epoch t=43 is 0.46270108477613825
# Objective value at epoch t=44 is 0.46263686363863527
# Objective value at epoch t=45 is 0.46256800548564103
# Objective value at epoch t=46 is 0.4625015296027531
# Objective value at epoch t=47 is 0.4624403045707325
# Objective value at epoch t=48 is 0.46238718448830873
# Objective value at epoch t=49 is 0.4623476688934317
# Objective value at epoch t=50 is 0.4623045872177191
# Objective value at epoch t=51 is 0.46226726591395584
# Objective value at epoch t=52 is 0.4622331847360804
# Objective value at epoch t=53 is 0.4622020794289313
# Objective value at epoch t=54 is 0.46217623425534854
# Objective value at epoch t=55 is 0.4621508393202367
# Objective value at epoch t=56 is 0.46212871769089114
# Objective value at epoch t=57 is 0.4621078444554797
# Objective value at epoch t=58 is 0.46209018553315434
# Objective value at epoch t=59 is 0.46207443838500045
# Objective value at epoch t=60 is 0.46205914091287414
# Objective value at epoch t=61 is 0.46204634429495356
# Objective value at epoch t=62 is 0.4620344771360806
# Objective value at epoch t=63 is 0.46202381800487985
# Objective value at epoch t=64 is 0.46201418701991787
# Objective value at epoch t=65 is 0.4620055240170332
# Objective value at epoch t=66 is 0.46199769725420675
# Objective value at epoch t=67 is 0.4619905264881076
# Objective value at epoch t=68 is 0.4619842984986331
# Objective value at epoch t=69 is 0.4619786426186738
# Objective value at epoch t=70 is 0.46197351653062596
# Objective value at epoch t=71 is 0.46196881029305265
# Objective value at epoch t=72 is 0.46196474338060184
# Objective value at epoch t=73 is 0.46196099685492653
# Objective value at epoch t=74 is 0.4619576004903199
# Objective value at epoch t=75 is 0.4619545901727705
# Objective value at epoch t=76 is 0.46195185606735495
# Objective value at epoch t=77 is 0.46194941023256186
# Objective value at epoch t=78 is 0.4619471990837597
# Objective value at epoch t=79 is 0.4619452072220233
# Objective value at epoch t=80 is 0.46194342294321344
# Objective value at epoch t=81 is 0.46194180935554624
# Objective value at epoch t=82 is 0.4619403590019296
# Objective value at epoch t=83 is 0.4619390541878463
# Objective value at epoch t=84 is 0.4619378784763817
# Objective value at epoch t=85 is 0.4619368206295735
# Objective value at epoch t=86 is 0.4619358689908862
# Objective value at epoch t=87 is 0.4619350117255575
# Objective value at epoch t=88 is 0.4619342413646138
# Objective value at epoch t=89 is 0.461933547135144
# Objective value at epoch t=90 is 0.46193292284225923
# Objective value at epoch t=91 is 0.4619323601870544
# Objective value at epoch t=92 is 0.46193185397955727
# Objective value at epoch t=93 is 0.4619313992281602
# Objective value at epoch t=94 is 0.4619309895090531
# Objective value at epoch t=95 is 0.4619306206681708
# Objective value at epoch t=96 is 0.46193028878929115
# Objective value at epoch t=97 is 0.4619299899731807
# Objective value at epoch t=98 is 0.461929721030723
# Objective value at epoch t=99 is 0.46192947894672365

# %% [markdown]
# # 4. Compare GD with SGD
#
# Plot objective function values against epochs.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(6, 4))

epochs_gd = range(len(objvals_gd))
epochs_sgd = range(len(objvals_sgd))

line0, = plt.plot(epochs_gd, objvals_gd, '--b', LineWidth=4)
line1, = plt.plot(epochs_sgd, objvals_sgd, '-r', LineWidth=2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1], ['GD', 'SGD'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_gd_sgd.pdf', format='pdf', dpi=1200)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if __name__ == '__main__':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later

# %% [markdown]
# # 5. Prediction

# %%
# Predict class label
# Inputs:
#     w: d-by-1 matrix
#     X: m-by-d matrix
# Return:
#     f: m-by-1 matrix, the predictions
def predict(w, X):
    xw = numpy.dot(X, w)
    f = numpy.sign(xw)
    return f

# %%
# evaluate training error
f_train = predict(w, x_train)
diff = numpy.abs(f_train - y_train) / 2
error_train = numpy.mean(diff)
print('Training classification error is ' + str(error_train))
# Out:
# Training classification error is 0.215625

# %%
# evaluate test error
f_test = predict(w, x_test)
diff = numpy.abs(f_test - y_test) / 2
error_test = numpy.mean(diff)
print('Test classification error is ' + str(error_test))
# Out:
# Test classification error is 0.25

# %% [markdown]
# # 6. Mini-batch SGD (fill the code)

# %% [markdown]
# ## 6.1. Compute the objective $Q_I$ and its gradient using a batch of samples
#
# Define $Q_I (w) = \frac{1}{b} \sum_{i \in I} \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $, where $I$ is a set containing $b$ indices randomly drawn from $\{ 1, \cdots , n \}$ without replacement.
#
# The stochastic gradient at $w$ is $g_I = \frac{\partial Q_I }{ \partial w} = \frac{1}{b} \sum_{i \in I} \frac{- y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_I and the gradient of Q_I
# Inputs:
#     w: d-by-1 matrix
#     xi: b-by-d matrix
#     yi: b-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def mb_stochastic_objective_gradient(w, xi, yi, lam, b):
    
    d = xi.shape[0]
    
    yx = numpy.multiply(yi, xi) # b-by-d matrix
    yxw = numpy.dot(yx, w) # b-by-1 matrix
    
    # calculate objective function Q_i
    loss = 1 / b * numpy.sum(numpy.log(1 + numpy.exp(-yxw))) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar

    obj = loss + reg 

    # calculate stochastic gradient
    g_loss = numpy.sum(-yx.T / (1 + numpy.exp(yxw)).T, axis=1) # d-by-1 matrix
    g = g_loss + lam * w # d-by-1 matrix
    
    return obj, g

# %% [markdown]
# ## 6.2. Implement mini-batch SGD
#
# Hints:
# 1. In every epoch, randomly permute the $n$ samples (just like SGD).
# 2. Each epoch has $\frac{n}{b}$ iterations. In every iteration, use $b$ samples, and compute the gradient and objective using the ``mb_stochastic_objective_gradient`` function. In the next iteration, use the next $b$ samples, and so on.

# %%
# Mini-Batch SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def mb_sgd(x, y, lam, b, stepsize, max_epoch=100, w=None):
    
    n, d = x.shape
    objvals = numpy.zeros(max_epoch) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
        
    for t in range(max_epoch):
        indecies = numpy.arange(n)
        numpy.random.shuffle(indecies)
        objval = 0 # accumulate the objective values

        batches = int(n / b)
        for j in range(batches):
            first_index = j * b
            last_index = (j + 1) * b
            xb = x[indecies[first_index:last_index],:]
            yb = y[indecies[first_index:last_index],:]
            
            obj, g = mb_stochastic_objective_gradient(w, xb, yb, lam, b)
            objval += obj
            w -= stepsize * g
        
        stepsize *= 0.9 # decrease step size
        objval /= batches 
        objvals[t] = objval
        print('Objective value at epoch t=' + str(t) + ' is ' + str(objval))
    
    return w, objvals

# %% [markdown]
# ## 6.3. Run MB-SGD

# %%
# MB-SGD with batch size b=8
lam = 1E-6 # do not change
b = 8 # do not change
stepsize = 0.1 # you must tune this parameter

stepsizes = [0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
errors_train8 = []
errors_test8 = []
objvals_mbsgd8 = []

for stepsize in stepsizes:
    w_tmp, objval_tmp = mb_sgd(x_train, y_train, lam, b, stepsize)
    f_train = predict(w_tmp, x_train)
    diff = numpy.abs(f_train - y_train) / 2
    error_train = numpy.mean(diff)
    f_test = predict(w_tmp, x_test)
    diff = numpy.abs(f_test - y_test) / 2
    error_test = numpy.mean(diff)
    
    errors_train8.append(error_train)
    errors_test8.append(error_test)
    objvals_mbsgd8.append(objval_tmp)
# Out:
# Objective value at epoch t=0 is 0.6927278086004341
# Objective value at epoch t=1 is 0.691903327808175
# Objective value at epoch t=2 is 0.6911643574244015
# Objective value at epoch t=3 is 0.6905015112768085
# Objective value at epoch t=4 is 0.6899075583345338
# Objective value at epoch t=5 is 0.6893752701384026
# Objective value at epoch t=6 is 0.688898052392309
# Objective value at epoch t=7 is 0.6884695573754275
# Objective value at epoch t=8 is 0.6880846767419859
# Objective value at epoch t=9 is 0.6877393264093132
# Objective value at epoch t=10 is 0.6874291751971534
# Objective value at epoch t=11 is 0.6871502572641145
# Objective value at epoch t=12 is 0.6868999108007011
# Objective value at epoch t=13 is 0.6866746564464254
# Objective value at epoch t=14 is 0.6864725417596651
# Objective value at epoch t=15 is 0.686290568028633
# Objective value at epoch t=16 is 0.6861270816434204
# Objective value at epoch t=17 is 0.6859803131855617
# Objective value at epoch t=18 is 0.6858481309294031
# Objective value at epoch t=19 is 0.6857292980200411
# Objective value at epoch t=20 is 0.6856223560711118
# Objective value at epoch t=21 is 0.6855262464995742
# Objective value at epoch t=22 is 0.6854399055214682
# Objective value at epoch t=23 is 0.6853620967211305
# Objective value at epoch t=24 is 0.685292123508934
# Objective value at epoch t=25 is 0.6852291131778865
# Objective value at epoch t=26 is 0.6851725081914721
# Objective value at epoch t=27 is 0.6851216348437494
# Objective value at epoch t=28 is 0.6850757486478846
# Objective value at epoch t=29 is 0.6850345588589876
# Objective value at epoch t=30 is 0.6849973881096492
# Objective value at epoch t=31 is 0.6849640524103614
# Objective value at epoch t=32 is 0.6849339880329941
# Objective value at epoch t=33 is 0.6849069994662565
# Objective value at epoch t=34 is 0.6848826281619191
# Objective value at epoch t=35 is 0.684860734466626
# Objective value at epoch t=36 is 0.6848410567765228
# Objective value at epoch t=37 is 0.684823332742257
# Objective value at epoch t=38 is 0.6848073756046611
# Objective value at epoch t=39 is 0.6847930301937315
# Objective value at epoch t=40 is 0.6847801013519463
# Objective value at epoch t=41 is 0.6847684706150861
# Objective value at epoch t=42 is 0.684758010712381
# Objective value at epoch t=43 is 0.6847486029511384
# Objective value at epoch t=44 is 0.6847401285654781
# Objective value at epoch t=45 is 0.6847325039062089
# Objective value at epoch t=46 is 0.6847256375492482
# Objective value at epoch t=47 is 0.6847194614564878
# Objective value at epoch t=48 is 0.6847139066583648
# Objective value at epoch t=49 is 0.684708911983433
# Objective value at epoch t=50 is 0.6847043962224928
# Objective value at epoch t=51 is 0.684700355178996
# Objective value at epoch t=52 is 0.6846967030353874
# Objective value at epoch t=53 is 0.6846934218812508
# Objective value at epoch t=54 is 0.6846904705731872
# Objective value at epoch t=55 is 0.6846878076507292
# Objective value at epoch t=56 is 0.6846854207012112
# Objective value at epoch t=57 is 0.6846832656647349
# Objective value at epoch t=58 is 0.6846813289644413
# Objective value at epoch t=59 is 0.6846795855298582
# Objective value at epoch t=60 is 0.6846780155231056
# Objective value at epoch t=61 is 0.6846766036383968
# Objective value at epoch t=62 is 0.6846753309546687
# Objective value at epoch t=63 is 0.6846741871062347
# Objective value at epoch t=64 is 0.6846731587297509
# Objective value at epoch t=65 is 0.6846722301135536
# Objective value at epoch t=66 is 0.6846713978939654
# Objective value at epoch t=67 is 0.6846706466381334
# Objective value at epoch t=68 is 0.6846699710564124
# Objective value at epoch t=69 is 0.6846693635044756
# Objective value at epoch t=70 is 0.6846688156537978
# Objective value at epoch t=71 is 0.6846683236043051
# Objective value at epoch t=72 is 0.684667880454979
# Objective value at epoch t=73 is 0.6846674810592475
# Objective value at epoch t=74 is 0.6846671223839624
# Objective value at epoch t=75 is 0.6846667992487812
# Objective value at epoch t=76 is 0.6846665087159108
# Objective value at epoch t=77 is 0.6846662469953675
# Objective value at epoch t=78 is 0.6846660115515892
# Objective value at epoch t=79 is 0.6846657993258483
# Objective value at epoch t=80 is 0.6846656086110596
# Objective value at epoch t=81 is 0.6846654369063905
# Objective value at epoch t=82 is 0.6846652821805198
# Objective value at epoch t=83 is 0.6846651433017835
# Objective value at epoch t=84 is 0.6846650180978052
# Objective value at epoch t=85 is 0.6846649055029606
# Objective value at epoch t=86 is 0.6846648041166914
# Objective value at epoch t=87 is 0.6846647127894657
# Objective value at epoch t=88 is 0.6846646306334442
# Objective value at epoch t=89 is 0.684664556722572
# Objective value at epoch t=90 is 0.6846644902184147
# Objective value at epoch t=91 is 0.6846644304099787
# Objective value at epoch t=92 is 0.6846643764116885
# Objective value at epoch t=93 is 0.6846643279652133
# Objective value at epoch t=94 is 0.6846642843457481
# Objective value at epoch t=95 is 0.6846642450276279
# Objective value at epoch t=96 is 0.6846642096829066
# Objective value at epoch t=97 is 0.6846641778617851
# Objective value at epoch t=98 is 0.6846641492442639
# Objective value at epoch t=99 is 0.6846641234562927
# Objective value at epoch t=0 is 0.6890305053594237
# Objective value at epoch t=1 is 0.6811485977840315
# Objective value at epoch t=2 is 0.6743903846742122
# Objective value at epoch t=3 is 0.6685659594805052
# Objective value at epoch t=4 is 0.663516165613449
# Objective value at epoch t=5 is 0.6591347201479933
# Objective value at epoch t=6 is 0.6553123880508196
# Objective value at epoch t=7 is 0.6519612146076619
# Objective value at epoch t=8 is 0.649019993102941
# Objective value at epoch t=9 is 0.6464318758491749
# Objective value at epoch t=10 is 0.6441506872702986
# Objective value at epoch t=11 is 0.642131251149636
# Objective value at epoch t=12 is 0.6403431245734301
# Objective value at epoch t=13 is 0.6387558272856869
# Objective value at epoch t=14 is 0.6373474911447998
# Objective value at epoch t=15 is 0.6360911957152056
# Objective value at epoch t=16 is 0.6349747820292034
# Objective value at epoch t=17 is 0.6339796935548689
# Objective value at epoch t=18 is 0.6330907660914373
# Objective value at epoch t=19 is 0.6322976937727686
# Objective value at epoch t=20 is 0.6315869805598806
# Objective value at epoch t=21 is 0.6309514065947464
# Objective value at epoch t=22 is 0.6303837575286148
# Objective value at epoch t=23 is 0.6298744610421839
# Objective value at epoch t=24 is 0.6294182902025669
# Objective value at epoch t=25 is 0.6290093295446312
# Objective value at epoch t=26 is 0.6286436011326682
# Objective value at epoch t=27 is 0.6283135464422526
# Objective value at epoch t=28 is 0.6280180874153622
# Objective value at epoch t=29 is 0.6277536704897912
# Objective value at epoch t=30 is 0.6275154983281431
# Objective value at epoch t=31 is 0.6273012409128832
# Objective value at epoch t=32 is 0.6271092289682668
# Objective value at epoch t=33 is 0.6269368771992883
# Objective value at epoch t=34 is 0.6267819247123482
# Objective value at epoch t=35 is 0.6266425735095374
# Objective value at epoch t=36 is 0.6265173168970896
# Objective value at epoch t=37 is 0.6264045120860589
# Objective value at epoch t=38 is 0.6263035117565104
# Objective value at epoch t=39 is 0.6262121486545247
# Objective value at epoch t=40 is 0.6261304960163099
# Objective value at epoch t=41 is 0.6260568690726938
# Objective value at epoch t=42 is 0.6259905061570037
# Objective value at epoch t=43 is 0.6259310977812809
# Objective value at epoch t=44 is 0.625877417993528
# Objective value at epoch t=45 is 0.6258293084843781
# Objective value at epoch t=46 is 0.6257859721088845
# Objective value at epoch t=47 is 0.6257468412044893
# Objective value at epoch t=48 is 0.6257117430833905
# Objective value at epoch t=49 is 0.6256801213636801
# Objective value at epoch t=50 is 0.6256517884135282
# Objective value at epoch t=51 is 0.6256262214753991
# Objective value at epoch t=52 is 0.6256032101752619
# Objective value at epoch t=53 is 0.6255825269831935
# Objective value at epoch t=54 is 0.6255638956376145
# Objective value at epoch t=55 is 0.6255471402604552
# Objective value at epoch t=56 is 0.6255320298713597
# Objective value at epoch t=57 is 0.6255184719753699
# Objective value at epoch t=58 is 0.6255062615034734
# Objective value at epoch t=59 is 0.6254952740382196
# Objective value at epoch t=60 is 0.6254853722679633
# Objective value at epoch t=61 is 0.6254764676944193
# Objective value at epoch t=62 is 0.6254684674791171
# Objective value at epoch t=63 is 0.6254612532541641
# Objective value at epoch t=64 is 0.6254547795001104
# Objective value at epoch t=65 is 0.6254489311677116
# Objective value at epoch t=66 is 0.6254436759839599
# Objective value at epoch t=67 is 0.6254389490854028
# Objective value at epoch t=68 is 0.6254346899247569
# Objective value at epoch t=69 is 0.6254308615437174
# Objective value at epoch t=70 is 0.6254274086303416
# Objective value at epoch t=71 is 0.625424310059583
# Objective value at epoch t=72 is 0.6254215223664132
# Objective value at epoch t=73 is 0.6254190074572359
# Objective value at epoch t=74 is 0.6254167484086439
# Objective value at epoch t=75 is 0.6254147144496305
# Objective value at epoch t=76 is 0.625412881822934
# Objective value at epoch t=77 is 0.6254112328224171
# Objective value at epoch t=78 is 0.6254097488110488
# Objective value at epoch t=79 is 0.6254084149928562
# Objective value at epoch t=80 is 0.6254072148464712
# Objective value at epoch t=81 is 0.6254061315859861
# Objective value at epoch t=82 is 0.6254051586398829
# Objective value at epoch t=83 is 0.6254042820145861
# Objective value at epoch t=84 is 0.6254034934174738
# Objective value at epoch t=85 is 0.6254027848184219
# Objective value at epoch t=86 is 0.6254021469808883
# Objective value at epoch t=87 is 0.6254015724246382
# Objective value at epoch t=88 is 0.6254010537532881
# Objective value at epoch t=89 is 0.6254005886781293
# Objective value at epoch t=90 is 0.625400169696347
# Objective value at epoch t=91 is 0.6253997923181048
# Objective value at epoch t=92 is 0.6253994536947826
# Objective value at epoch t=93 is 0.6253991486541024
# Objective value at epoch t=94 is 0.6253988738808349
# Objective value at epoch t=95 is 0.6253986261755944
# Objective value at epoch t=96 is 0.6253984031684792
# Objective value at epoch t=97 is 0.6253982028594374
# Objective value at epoch t=98 is 0.6253980222930331
# Objective value at epoch t=99 is 0.6253978600738643
# Objective value at epoch t=0 is 0.6577931711285494
# Objective value at epoch t=1 is 0.6061368547467026
# Objective value at epoch t=2 is 0.5755078593796843
# Objective value at epoch t=3 is 0.5558594106388537
# Objective value at epoch t=4 is 0.5423264254408793
# Objective value at epoch t=5 is 0.5323978332412876
# Objective value at epoch t=6 is 0.5249636642269108
# Objective value at epoch t=7 is 0.5192081012272867
# Objective value at epoch t=8 is 0.514644326079335
# Objective value at epoch t=9 is 0.5109816412184116
# Objective value at epoch t=10 is 0.5079379191433624
# Objective value at epoch t=11 is 0.5054256627224518
# Objective value at epoch t=12 is 0.5033224916093835
# Objective value at epoch t=13 is 0.5015604900842521
# Objective value at epoch t=14 is 0.5000306022805748
# Objective value at epoch t=15 is 0.4987418944078793
# Objective value at epoch t=16 is 0.4976445398544486
# Objective value at epoch t=17 is 0.496653184419669
# Objective value at epoch t=18 is 0.4958162318694125
# Objective value at epoch t=19 is 0.4950744156012904
# Objective value at epoch t=20 is 0.4944396017860643
# Objective value at epoch t=21 is 0.4938664429913692
# Objective value at epoch t=22 is 0.49335969217326525
# Objective value at epoch t=23 is 0.4929254338387685
# Objective value at epoch t=24 is 0.4925369092817304
# Objective value at epoch t=25 is 0.49219340695294456
# Objective value at epoch t=26 is 0.4918834545976927
# Objective value at epoch t=27 is 0.4916076309114305
# Objective value at epoch t=28 is 0.491361020726279
# Objective value at epoch t=29 is 0.49114703734739
# Objective value at epoch t=30 is 0.4909552194417932
# Objective value at epoch t=31 is 0.4907819391474952
# Objective value at epoch t=32 is 0.4906247908937183
# Objective value at epoch t=33 is 0.4904853792833984
# Objective value at epoch t=34 is 0.4903634684342736
# Objective value at epoch t=35 is 0.490250740665697
# Objective value at epoch t=36 is 0.4901543181970977
# Objective value at epoch t=37 is 0.4900640660119504
# Objective value at epoch t=38 is 0.4899846209602086
# Objective value at epoch t=39 is 0.4899130524899732
# Objective value at epoch t=40 is 0.48985086099035363
# Objective value at epoch t=41 is 0.4897929729458643
# Objective value at epoch t=42 is 0.4897400483230613
# Objective value at epoch t=43 is 0.48969453199729696
# Objective value at epoch t=44 is 0.48965212467785746
# Objective value at epoch t=45 is 0.48961476800890447
# Objective value at epoch t=46 is 0.4895814423925139
# Objective value at epoch t=47 is 0.48955081086612295
# Objective value at epoch t=48 is 0.4895234276821784
# Objective value at epoch t=49 is 0.4894993993230886
# Objective value at epoch t=50 is 0.4894776044089764
# Objective value at epoch t=51 is 0.48945830185139005
# Objective value at epoch t=52 is 0.48944009323852156
# Objective value at epoch t=53 is 0.48942386211219413
# Objective value at epoch t=54 is 0.4894094294798982
# Objective value at epoch t=55 is 0.48939680333748303
# Objective value at epoch t=56 is 0.48938499172968886
# Objective value at epoch t=57 is 0.48937451541630705
# Objective value at epoch t=58 is 0.48936520982961723
# Objective value at epoch t=59 is 0.48935662925961604
# Objective value at epoch t=60 is 0.48934914282630915
# Objective value at epoch t=61 is 0.4893421611706829
# Objective value at epoch t=62 is 0.48933604054569163
# Objective value at epoch t=63 is 0.48933046039139605
# Objective value at epoch t=64 is 0.4893255583626169
# Objective value at epoch t=65 is 0.4893210090422796
# Objective value at epoch t=66 is 0.4893169650255573
# Objective value at epoch t=67 is 0.489313305860104
# Objective value at epoch t=68 is 0.4893100787895973
# Objective value at epoch t=69 is 0.4893071305472853
# Objective value at epoch t=70 is 0.4893044106268098
# Objective value at epoch t=71 is 0.4893020179016478
# Objective value at epoch t=72 is 0.48929988176105627
# Objective value at epoch t=73 is 0.4892979781196921
# Objective value at epoch t=74 is 0.4892962226691158
# Objective value at epoch t=75 is 0.48929467544810323
# Objective value at epoch t=76 is 0.4892932556384085
# Objective value at epoch t=77 is 0.4892919760536862
# Objective value at epoch t=78 is 0.4892908488381155
# Objective value at epoch t=79 is 0.48928983093684986
# Objective value at epoch t=80 is 0.48928891598190727
# Objective value at epoch t=81 is 0.4892880793863642
# Objective value at epoch t=82 is 0.4892873451450894
# Objective value at epoch t=83 is 0.48928666182023095
# Objective value at epoch t=84 is 0.4892860624739919
# Objective value at epoch t=85 is 0.48928551173229573
# Objective value at epoch t=86 is 0.48928501632979576
# Objective value at epoch t=87 is 0.4892845942473526
# Objective value at epoch t=88 is 0.48928417811567027
# Objective value at epoch t=89 is 0.4892838182617167
# Objective value at epoch t=90 is 0.4892835019081258
# Objective value at epoch t=91 is 0.48928320920856255
# Objective value at epoch t=92 is 0.4892829555358551
# Objective value at epoch t=93 is 0.4892827175487713
# Objective value at epoch t=94 is 0.4892825090241689
# Objective value at epoch t=95 is 0.489282319010078
# Objective value at epoch t=96 is 0.48928214500939876
# Objective value at epoch t=97 is 0.489281988766444
# Objective value at epoch t=98 is 0.4892818517983349
# Objective value at epoch t=99 is 0.48928172794075087
# Objective value at epoch t=0 is 0.5489500547354241
# Objective value at epoch t=1 is 0.4844351346426688
# Objective value at epoch t=2 is 0.4724583042360872
# Objective value at epoch t=3 is 0.4691593461846278
# Objective value at epoch t=4 is 0.46741137403596855
# Objective value at epoch t=5 is 0.4664066756624323
# Objective value at epoch t=6 is 0.466452924030782
# Objective value at epoch t=7 is 0.46550301397958754
# Objective value at epoch t=8 is 0.4649504022359544
# Objective value at epoch t=9 is 0.4649943124005165
# Objective value at epoch t=10 is 0.46425399874933804
# Objective value at epoch t=11 is 0.46411795508204523
# Objective value at epoch t=12 is 0.4639286653800623
# Objective value at epoch t=13 is 0.4636284397553879
# Objective value at epoch t=14 is 0.46353291233309646
# Objective value at epoch t=15 is 0.46328851353362877
# Objective value at epoch t=16 is 0.46323700469374496
# Objective value at epoch t=17 is 0.4630262493081537
# Objective value at epoch t=18 is 0.46292702552662257
# Objective value at epoch t=19 is 0.46288946129830427
# Objective value at epoch t=20 is 0.4627633954783332
# Objective value at epoch t=21 is 0.46273393401354923
# Objective value at epoch t=22 is 0.4626466398938634
# Objective value at epoch t=23 is 0.46257408702752817
# Objective value at epoch t=24 is 0.4624503641358048
# Objective value at epoch t=25 is 0.46244431752070103
# Objective value at epoch t=26 is 0.46240218522670895
# Objective value at epoch t=27 is 0.4623376111629045
# Objective value at epoch t=28 is 0.462299707514061
# Objective value at epoch t=29 is 0.4622588519170365
# Objective value at epoch t=30 is 0.46223804378690153
# Objective value at epoch t=31 is 0.46221028675891623
# Objective value at epoch t=32 is 0.4621689351360533
# Objective value at epoch t=33 is 0.46214635585558794
# Objective value at epoch t=34 is 0.4621573080251247
# Objective value at epoch t=35 is 0.4621308501412586
# Objective value at epoch t=36 is 0.46208913759469217
# Objective value at epoch t=37 is 0.4620750504618697
# Objective value at epoch t=38 is 0.46206328715881967
# Objective value at epoch t=39 is 0.46205277869504113
# Objective value at epoch t=40 is 0.4620377678742707
# Objective value at epoch t=41 is 0.4620355430707221
# Objective value at epoch t=42 is 0.4620265667565035
# Objective value at epoch t=43 is 0.46200979428580535
# Objective value at epoch t=44 is 0.4620048228436321
# Objective value at epoch t=45 is 0.46199367062587005
# Objective value at epoch t=46 is 0.46198939601009564
# Objective value at epoch t=47 is 0.4619852352416687
# Objective value at epoch t=48 is 0.4619826716142145
# Objective value at epoch t=49 is 0.4619790854852539
# Objective value at epoch t=50 is 0.4619710436726069
# Objective value at epoch t=51 is 0.46196885115748126
# Objective value at epoch t=52 is 0.4619597223688201
# Objective value at epoch t=53 is 0.4619596140819368
# Objective value at epoch t=54 is 0.46195675356263777
# Objective value at epoch t=55 is 0.46195537438089157
# Objective value at epoch t=56 is 0.46195234344272007
# Objective value at epoch t=57 is 0.4619515186297048
# Objective value at epoch t=58 is 0.46194961672337786
# Objective value at epoch t=59 is 0.46194630889991395
# Objective value at epoch t=60 is 0.4619447431877289
# Objective value at epoch t=61 is 0.46194395741740174
# Objective value at epoch t=62 is 0.4619426726699545
# Objective value at epoch t=63 is 0.4619413185901363
# Objective value at epoch t=64 is 0.46194057936758304
# Objective value at epoch t=65 is 0.46194064994265405
# Objective value at epoch t=66 is 0.46193932400482096
# Objective value at epoch t=67 is 0.46193781296027214
# Objective value at epoch t=68 is 0.46193757139480535
# Objective value at epoch t=69 is 0.46193721809185373
# Objective value at epoch t=70 is 0.4619365079847454
# Objective value at epoch t=71 is 0.4619359910884563
# Objective value at epoch t=72 is 0.4619359439183257
# Objective value at epoch t=73 is 0.461935414555548
# Objective value at epoch t=74 is 0.4619351613512239
# Objective value at epoch t=75 is 0.4619346834353766
# Objective value at epoch t=76 is 0.46193440753438153
# Objective value at epoch t=77 is 0.4619339755296224
# Objective value at epoch t=78 is 0.46193388260081747
# Objective value at epoch t=79 is 0.4619337375147515
# Objective value at epoch t=80 is 0.46193359548568624
# Objective value at epoch t=81 is 0.46193323898814836
# Objective value at epoch t=82 is 0.46193312184016877
# Objective value at epoch t=83 is 0.4619330187782712
# Objective value at epoch t=84 is 0.46193308122372867
# Objective value at epoch t=85 is 0.4619328124697568
# Objective value at epoch t=86 is 0.46193283796068263
# Objective value at epoch t=87 is 0.46193265136567135
# Objective value at epoch t=88 is 0.4619326806236862
# Objective value at epoch t=89 is 0.4619325968334591
# Objective value at epoch t=90 is 0.4619325339832846
# Objective value at epoch t=91 is 0.4619324175964842
# Objective value at epoch t=92 is 0.46193235212312206
# Objective value at epoch t=93 is 0.4619322946335241
# Objective value at epoch t=94 is 0.46193233325011535
# Objective value at epoch t=95 is 0.46193225790807546
# Objective value at epoch t=96 is 0.46193223340333
# Objective value at epoch t=97 is 0.4619321937835581
# Objective value at epoch t=98 is 0.4619321742592085
# Objective value at epoch t=99 is 0.46193215966867
# Objective value at epoch t=0 is 0.5207639268960068
# Objective value at epoch t=1 is 0.5089314010471748
# Objective value at epoch t=2 is 0.509697670908291
# Objective value at epoch t=3 is 0.5006299051961316
# Objective value at epoch t=4 is 0.49478448827234667
# Objective value at epoch t=5 is 0.49031271382407543
# Objective value at epoch t=6 is 0.4897542762953182
# Objective value at epoch t=7 is 0.4859159135121406
# Objective value at epoch t=8 is 0.484673927817086
# Objective value at epoch t=9 is 0.4825511387596676
# Objective value at epoch t=10 is 0.4850065108372159
# Objective value at epoch t=11 is 0.4815812712333364
# Objective value at epoch t=12 is 0.47882655354786124
# Objective value at epoch t=13 is 0.47777351378723854
# Objective value at epoch t=14 is 0.4795716289876604
# Objective value at epoch t=15 is 0.475551546701711
# Objective value at epoch t=16 is 0.47253095499786146
# Objective value at epoch t=17 is 0.4711586490987731
# Objective value at epoch t=18 is 0.47120024871127253
# Objective value at epoch t=19 is 0.47049626166723907
# Objective value at epoch t=20 is 0.47202680615827
# Objective value at epoch t=21 is 0.4682687957120871
# Objective value at epoch t=22 is 0.468358168299014
# Objective value at epoch t=23 is 0.4677583039414893
# Objective value at epoch t=24 is 0.4665947113964334
# Objective value at epoch t=25 is 0.46695701023065916
# Objective value at epoch t=26 is 0.4662898248352342
# Objective value at epoch t=27 is 0.4662379222764959
# Objective value at epoch t=28 is 0.46506611906934914
# Objective value at epoch t=29 is 0.46543414315045045
# Objective value at epoch t=30 is 0.4646468286830439
# Objective value at epoch t=31 is 0.4650196947200979
# Objective value at epoch t=32 is 0.46435248370603677
# Objective value at epoch t=33 is 0.4643341698843555
# Objective value at epoch t=34 is 0.46376862815103087
# Objective value at epoch t=35 is 0.46372549059823853
# Objective value at epoch t=36 is 0.4635077329745204
# Objective value at epoch t=37 is 0.46325246362283057
# Objective value at epoch t=38 is 0.4631138454647032
# Objective value at epoch t=39 is 0.4630412168635442
# Objective value at epoch t=40 is 0.4628872510126591
# Objective value at epoch t=41 is 0.4629657938602182
# Objective value at epoch t=42 is 0.4627913952319888
# Objective value at epoch t=43 is 0.46273274460635383
# Objective value at epoch t=44 is 0.46259701087208105
# Objective value at epoch t=45 is 0.46254545284337045
# Objective value at epoch t=46 is 0.46247356317057015
# Objective value at epoch t=47 is 0.46244628014681555
# Objective value at epoch t=48 is 0.46240548517381147
# Objective value at epoch t=49 is 0.46231904887643316
# Objective value at epoch t=50 is 0.46230203675896436
# Objective value at epoch t=51 is 0.462286987492955
# Objective value at epoch t=52 is 0.4622535871289194
# Objective value at epoch t=53 is 0.46221253204460544
# Objective value at epoch t=54 is 0.46216628050450703
# Objective value at epoch t=55 is 0.46214544299038113
# Objective value at epoch t=56 is 0.4621278765566883
# Objective value at epoch t=57 is 0.46210866568587516
# Objective value at epoch t=58 is 0.4620683392366612
# Objective value at epoch t=59 is 0.4620646994796142
# Objective value at epoch t=60 is 0.46206093447969404
# Objective value at epoch t=61 is 0.46204299001355204
# Objective value at epoch t=62 is 0.46202815148927573
# Objective value at epoch t=63 is 0.46203553074837317
# Objective value at epoch t=64 is 0.4620204611906651
# Objective value at epoch t=65 is 0.4620072053165386
# Objective value at epoch t=66 is 0.46199632841876986
# Objective value at epoch t=67 is 0.46198766790975904
# Objective value at epoch t=68 is 0.4619878586262236
# Objective value at epoch t=69 is 0.46197207475673663
# Objective value at epoch t=70 is 0.461973267336767
# Objective value at epoch t=71 is 0.4619647266446557
# Objective value at epoch t=72 is 0.46196518707708706
# Objective value at epoch t=73 is 0.461961931135573
# Objective value at epoch t=74 is 0.46195618758143225
# Objective value at epoch t=75 is 0.46195386263570554
# Objective value at epoch t=76 is 0.46195288523940387
# Objective value at epoch t=77 is 0.4619490209567087
# Objective value at epoch t=78 is 0.46194762023223346
# Objective value at epoch t=79 is 0.4619439862204001
# Objective value at epoch t=80 is 0.46194283099072553
# Objective value at epoch t=81 is 0.4619413726465217
# Objective value at epoch t=82 is 0.4619417401058394
# Objective value at epoch t=83 is 0.4619393658208897
# Objective value at epoch t=84 is 0.46193776818968973
# Objective value at epoch t=85 is 0.4619367739255309
# Objective value at epoch t=86 is 0.46193657401460725
# Objective value at epoch t=87 is 0.46193474226954506
# Objective value at epoch t=88 is 0.46193439495658567
# Objective value at epoch t=89 is 0.46193384001821525
# Objective value at epoch t=90 is 0.46193291976688017
# Objective value at epoch t=91 is 0.46193204184589814
# Objective value at epoch t=92 is 0.46193180564144526
# Objective value at epoch t=93 is 0.46193165369808253
# Objective value at epoch t=94 is 0.4619309672834211
# Objective value at epoch t=95 is 0.46193065394144883
# Objective value at epoch t=96 is 0.46193024428967233
# Objective value at epoch t=97 is 0.46192988380018185
# Objective value at epoch t=98 is 0.46192983715509284
# Objective value at epoch t=99 is 0.46192939075298345
# Objective value at epoch t=0 is 1.8762014361581667
# Objective value at epoch t=1 is 1.4025888412475809
# Objective value at epoch t=2 is 1.3444874486101583
# Objective value at epoch t=3 is 1.234927943732016
# Objective value at epoch t=4 is 1.2464930184870648
# Objective value at epoch t=5 is 1.1375747418727875
# Objective value at epoch t=6 is 1.059103572099552
# Objective value at epoch t=7 is 0.9756935740683961
# Objective value at epoch t=8 is 0.9182956286883153
# Objective value at epoch t=9 is 0.8046100276068678
# Objective value at epoch t=10 is 0.7073245899081141
# Objective value at epoch t=11 is 0.7186689847019535
# Objective value at epoch t=12 is 0.6599573897265528
# Objective value at epoch t=13 is 0.6481333166822115
# Objective value at epoch t=14 is 0.5511100249550844
# Objective value at epoch t=15 is 0.5773826974754963
# Objective value at epoch t=16 is 0.5816466652458366
# Objective value at epoch t=17 is 0.5467664643824699
# Objective value at epoch t=18 is 0.569590274094034
# Objective value at epoch t=19 is 0.5357641078087304
# Objective value at epoch t=20 is 0.512309731775662
# Objective value at epoch t=21 is 0.5190647435986666
# Objective value at epoch t=22 is 0.5199639951726094
# Objective value at epoch t=23 is 0.49598765801797473
# Objective value at epoch t=24 is 0.5058228716521533
# Objective value at epoch t=25 is 0.5067811158060278
# Objective value at epoch t=26 is 0.49131822246036644
# Objective value at epoch t=27 is 0.4928122727914611
# Objective value at epoch t=28 is 0.4886098846518266
# Objective value at epoch t=29 is 0.4850798608951744
# Objective value at epoch t=30 is 0.486105894749739
# Objective value at epoch t=31 is 0.4858821838876282
# Objective value at epoch t=32 is 0.4832067829751027
# Objective value at epoch t=33 is 0.4758782195538579
# Objective value at epoch t=34 is 0.48294562942839764
# Objective value at epoch t=35 is 0.47470403087367413
# Objective value at epoch t=36 is 0.4760054753773386
# Objective value at epoch t=37 is 0.4757518412959401
# Objective value at epoch t=38 is 0.4736377906295496
# Objective value at epoch t=39 is 0.47041017902492743
# Objective value at epoch t=40 is 0.47082188950314885
# Objective value at epoch t=41 is 0.4704570769463551
# Objective value at epoch t=42 is 0.4690592216569091
# Objective value at epoch t=43 is 0.4684775188466127
# Objective value at epoch t=44 is 0.4682728387204663
# Objective value at epoch t=45 is 0.4668941518535032
# Objective value at epoch t=46 is 0.4670011180190795
# Objective value at epoch t=47 is 0.46707181051723967
# Objective value at epoch t=48 is 0.46645145540478217
# Objective value at epoch t=49 is 0.46588646620343094
# Objective value at epoch t=50 is 0.4653776035328323
# Objective value at epoch t=51 is 0.4650267148167272
# Objective value at epoch t=52 is 0.4645753333274783
# Objective value at epoch t=53 is 0.4645518256612243
# Objective value at epoch t=54 is 0.46424089342220515
# Objective value at epoch t=55 is 0.4642713980970175
# Objective value at epoch t=56 is 0.46370366158428544
# Objective value at epoch t=57 is 0.46367706191710223
# Objective value at epoch t=58 is 0.4635245422916873
# Objective value at epoch t=59 is 0.46323636202266305
# Objective value at epoch t=60 is 0.4631898559679806
# Objective value at epoch t=61 is 0.46313443462749077
# Objective value at epoch t=62 is 0.4629753996599343
# Objective value at epoch t=63 is 0.4629108927003407
# Objective value at epoch t=64 is 0.4627154137913868
# Objective value at epoch t=65 is 0.46272740242746907
# Objective value at epoch t=66 is 0.46263099784182893
# Objective value at epoch t=67 is 0.4625386828039515
# Objective value at epoch t=68 is 0.46246318462372604
# Objective value at epoch t=69 is 0.46245698051257544
# Objective value at epoch t=70 is 0.4623578998470602
# Objective value at epoch t=71 is 0.4623407445244565
# Objective value at epoch t=72 is 0.4622968260898806
# Objective value at epoch t=73 is 0.46226056354899303
# Objective value at epoch t=74 is 0.4622230028347417
# Objective value at epoch t=75 is 0.46218342391262873
# Objective value at epoch t=76 is 0.46217404820775865
# Objective value at epoch t=77 is 0.4621574084314772
# Objective value at epoch t=78 is 0.4621173915409882
# Objective value at epoch t=79 is 0.4621020007044344
# Objective value at epoch t=80 is 0.4620876474852773
# Objective value at epoch t=81 is 0.4620638655495489
# Objective value at epoch t=82 is 0.46207669512649724
# Objective value at epoch t=83 is 0.4620437050466394
# Objective value at epoch t=84 is 0.46203452198169054
# Objective value at epoch t=85 is 0.4620261293793936
# Objective value at epoch t=86 is 0.46201768851091957
# Objective value at epoch t=87 is 0.46199575450400887
# Objective value at epoch t=88 is 0.4619925942093962
# Objective value at epoch t=89 is 0.4619864583234822
# Objective value at epoch t=90 is 0.46198344854591167
# Objective value at epoch t=91 is 0.46197559721638637
# Objective value at epoch t=92 is 0.46197495512062037
# Objective value at epoch t=93 is 0.46196694067788996
# Objective value at epoch t=94 is 0.461966122588467
# Objective value at epoch t=95 is 0.46196181966733646
# Objective value at epoch t=96 is 0.4619589324175107
# Objective value at epoch t=97 is 0.46195501009194784
# Objective value at epoch t=98 is 0.4619519918091049
# Objective value at epoch t=99 is 0.46194811106028577
# Objective value at epoch t=0 is 14.773130129482706
# Objective value at epoch t=1 is 16.57635264127701
# Objective value at epoch t=2 is 12.97714187566516
# Objective value at epoch t=3 is 13.922811968889329
# Objective value at epoch t=4 is 12.349314658524372
# Objective value at epoch t=5 is 10.985548880809796
# Objective value at epoch t=6 is 9.810823156533239
# Objective value at epoch t=7 is 10.855979862025587
# Objective value at epoch t=8 is 8.786033247893123
# Objective value at epoch t=9 is 6.341919157234062
# Objective value at epoch t=10 is 4.926339165985706
# Objective value at epoch t=11 is 5.469447244232593
# Objective value at epoch t=12 is 4.224374730656504
# Objective value at epoch t=13 is 3.730326916948622
# Objective value at epoch t=14 is 4.16115532677473
# Objective value at epoch t=15 is 4.147327460629703
# Objective value at epoch t=16 is 3.3277929670738913
# Objective value at epoch t=17 is 3.067102340361067
# Objective value at epoch t=18 is 2.6819431662755155
# Objective value at epoch t=19 is 2.3787886053027427
# Objective value at epoch t=20 is 1.9951904546271166
# Objective value at epoch t=21 is 2.063187345352961
# Objective value at epoch t=22 is 1.813487711057314
# Objective value at epoch t=23 is 1.5573886106639117
# Objective value at epoch t=24 is 1.4564229125179824
# Objective value at epoch t=25 is 1.3285653541694755
# Objective value at epoch t=26 is 1.0908738766576684
# Objective value at epoch t=27 is 1.1207238829063528
# Objective value at epoch t=28 is 0.8510245118528582
# Objective value at epoch t=29 is 0.9260578805275044
# Objective value at epoch t=30 is 0.8750495192716656
# Objective value at epoch t=31 is 0.7967632755718388
# Objective value at epoch t=32 is 0.7216329590347053
# Objective value at epoch t=33 is 0.7141867223154933
# Objective value at epoch t=34 is 0.6395456744196124
# Objective value at epoch t=35 is 0.6318591277983173
# Objective value at epoch t=36 is 0.5758726544010005
# Objective value at epoch t=37 is 0.5526153527401915
# Objective value at epoch t=38 is 0.5744169804317429
# Objective value at epoch t=39 is 0.55711157007142
# Objective value at epoch t=40 is 0.5388920959838714
# Objective value at epoch t=41 is 0.5367003955571128
# Objective value at epoch t=42 is 0.5365492908691712
# Objective value at epoch t=43 is 0.5185063845499237
# Objective value at epoch t=44 is 0.5174194380821625
# Objective value at epoch t=45 is 0.5093190272174928
# Objective value at epoch t=46 is 0.5003408958247182
# Objective value at epoch t=47 is 0.5056568768113523
# Objective value at epoch t=48 is 0.49902093974143263
# Objective value at epoch t=49 is 0.49174438092918676
# Objective value at epoch t=50 is 0.4929180765298657
# Objective value at epoch t=51 is 0.4868448357815738
# Objective value at epoch t=52 is 0.48375632329364987
# Objective value at epoch t=53 is 0.48531908452837297
# Objective value at epoch t=54 is 0.4785343704508486
# Objective value at epoch t=55 is 0.47990608267689144
# Objective value at epoch t=56 is 0.4774396855393814
# Objective value at epoch t=57 is 0.47457974806283254
# Objective value at epoch t=58 is 0.47435070418682435
# Objective value at epoch t=59 is 0.475797578591433
# Objective value at epoch t=60 is 0.4737871073445244
# Objective value at epoch t=61 is 0.47232820876530857
# Objective value at epoch t=62 is 0.4715142459807728
# Objective value at epoch t=63 is 0.47041899178091456
# Objective value at epoch t=64 is 0.46812629585244664
# Objective value at epoch t=65 is 0.46781898824433793
# Objective value at epoch t=66 is 0.4680601978347084
# Objective value at epoch t=67 is 0.46727950373442056
# Objective value at epoch t=68 is 0.46639762298982107
# Objective value at epoch t=69 is 0.46628667162343873
# Objective value at epoch t=70 is 0.46654940734663863
# Objective value at epoch t=71 is 0.4652551276454216
# Objective value at epoch t=72 is 0.4657063194755926
# Objective value at epoch t=73 is 0.46494585503875197
# Objective value at epoch t=74 is 0.464363870813576
# Objective value at epoch t=75 is 0.4644103223933154
# Objective value at epoch t=76 is 0.46437329367847013
# Objective value at epoch t=77 is 0.46420582123080595
# Objective value at epoch t=78 is 0.46372475472483154
# Objective value at epoch t=79 is 0.46356543360323793
# Objective value at epoch t=80 is 0.46348621291606007
# Objective value at epoch t=81 is 0.4633055611319835
# Objective value at epoch t=82 is 0.46308650671026114
# Objective value at epoch t=83 is 0.46307426570583654
# Objective value at epoch t=84 is 0.4630043312403053
# Objective value at epoch t=85 is 0.46288718132922824
# Objective value at epoch t=86 is 0.4626664400458652
# Objective value at epoch t=87 is 0.46266114480626025
# Objective value at epoch t=88 is 0.46258360809122356
# Objective value at epoch t=89 is 0.46249013688708895
# Objective value at epoch t=90 is 0.46244772835918085
# Objective value at epoch t=91 is 0.46244889406932704
# Objective value at epoch t=92 is 0.46236689451290325
# Objective value at epoch t=93 is 0.46233031679644593
# Objective value at epoch t=94 is 0.46228740660391077
# Objective value at epoch t=95 is 0.4622871942128876
# Objective value at epoch t=96 is 0.46223422347635157
# Objective value at epoch t=97 is 0.4621929928922709
# Objective value at epoch t=98 is 0.4621727530516383
# Objective value at epoch t=99 is 0.46214164991065115
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is 50.18551633385546
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is 37.36651132742942
# Objective value at epoch t=15 is 41.166901223614595
# Objective value at epoch t=16 is 33.467880041902745
# Objective value at epoch t=17 is 23.028036218566633
# Objective value at epoch t=18 is 26.570639792086546
# Objective value at epoch t=19 is 26.98038460014745
# Objective value at epoch t=20 is 22.87291128295751
# Objective value at epoch t=21 is 19.136553293729374
# Objective value at epoch t=22 is 18.445960275814322
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in exp
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: overflow encountered in exp
# Objective value at epoch t=23 is 16.032639557921236
# Objective value at epoch t=24 is 13.966520969393647
# Objective value at epoch t=25 is 14.079881352536493
# Objective value at epoch t=26 is 11.400083074246478
# Objective value at epoch t=27 is 10.659841996953745
# Objective value at epoch t=28 is 9.26848115242981
# Objective value at epoch t=29 is 7.697011587614715
# Objective value at epoch t=30 is 9.026395826460544
# Objective value at epoch t=31 is 6.5936170805678405
# Objective value at epoch t=32 is 6.077269087133176
# Objective value at epoch t=33 is 5.334541909952972
# Objective value at epoch t=34 is 5.2636627678096835
# Objective value at epoch t=35 is 4.6030622315868595
# Objective value at epoch t=36 is 3.970771359743833
# Objective value at epoch t=37 is 3.3147691963918335
# Objective value at epoch t=38 is 2.7544074673914474
# Objective value at epoch t=39 is 2.841360390985072
# Objective value at epoch t=40 is 2.9257695804343666
# Objective value at epoch t=41 is 2.1765704771172723
# Objective value at epoch t=42 is 2.452270125985186
# Objective value at epoch t=43 is 1.69525567102407
# Objective value at epoch t=44 is 1.553675880150666
# Objective value at epoch t=45 is 1.6386616927818296
# Objective value at epoch t=46 is 1.3874578321409567
# Objective value at epoch t=47 is 1.316402778677687
# Objective value at epoch t=48 is 1.0619223464401213
# Objective value at epoch t=49 is 1.0575975027143605
# Objective value at epoch t=50 is 0.9019155143441647
# Objective value at epoch t=51 is 0.9432152963628745
# Objective value at epoch t=52 is 0.83245637762475
# Objective value at epoch t=53 is 0.7170681527842613
# Objective value at epoch t=54 is 0.7540893905528122
# Objective value at epoch t=55 is 0.7045735734165564
# Objective value at epoch t=56 is 0.677848460429467
# Objective value at epoch t=57 is 0.6495407652917824
# Objective value at epoch t=58 is 0.6029558091344056
# Objective value at epoch t=59 is 0.6101198362362497
# Objective value at epoch t=60 is 0.5820432801281885
# Objective value at epoch t=61 is 0.5416546491530658
# Objective value at epoch t=62 is 0.5361239657223018
# Objective value at epoch t=63 is 0.5459622748523111
# Objective value at epoch t=64 is 0.5192513971444577
# Objective value at epoch t=65 is 0.5139821004915371
# Objective value at epoch t=66 is 0.5055474810288397
# Objective value at epoch t=67 is 0.5104818603913065
# Objective value at epoch t=68 is 0.5032970616426485
# Objective value at epoch t=69 is 0.5025310527321023
# Objective value at epoch t=70 is 0.49818938260441803
# Objective value at epoch t=71 is 0.49942993226017707
# Objective value at epoch t=72 is 0.4867152442675837
# Objective value at epoch t=73 is 0.48434429798492823
# Objective value at epoch t=74 is 0.4877296641451516
# Objective value at epoch t=75 is 0.4793912413507743
# Objective value at epoch t=76 is 0.4812550867865033
# Objective value at epoch t=77 is 0.48076221838477756
# Objective value at epoch t=78 is 0.4775412628343612
# Objective value at epoch t=79 is 0.47783852708589575
# Objective value at epoch t=80 is 0.47243411966698917
# Objective value at epoch t=81 is 0.4745322830458045
# Objective value at epoch t=82 is 0.4740778135251005
# Objective value at epoch t=83 is 0.4713036772135778
# Objective value at epoch t=84 is 0.4723115628688263
# Objective value at epoch t=85 is 0.470835404501337
# Objective value at epoch t=86 is 0.4693561555550586
# Objective value at epoch t=87 is 0.4698447750587767
# Objective value at epoch t=88 is 0.46743932681071965
# Objective value at epoch t=89 is 0.4674482558813571
# Objective value at epoch t=90 is 0.4655077117579597
# Objective value at epoch t=91 is 0.4670528880587902
# Objective value at epoch t=92 is 0.46574416364722326
# Objective value at epoch t=93 is 0.46563713586148675
# Objective value at epoch t=94 is 0.4650890585403607
# Objective value at epoch t=95 is 0.46501479853857164
# Objective value at epoch t=96 is 0.4650550887689078
# Objective value at epoch t=97 is 0.4645036894755982
# Objective value at epoch t=98 is 0.4641831025727499
# Objective value at epoch t=99 is 0.46398561443268155
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is inf
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is inf
# Objective value at epoch t=15 is inf
# Objective value at epoch t=16 is inf
# Objective value at epoch t=17 is inf
# Objective value at epoch t=18 is inf
# Objective value at epoch t=19 is inf
# Objective value at epoch t=20 is inf
# Objective value at epoch t=21 is inf
# Objective value at epoch t=22 is inf
# Objective value at epoch t=23 is inf
# Objective value at epoch t=24 is inf
# Objective value at epoch t=25 is inf
# Objective value at epoch t=26 is inf
# Objective value at epoch t=27 is inf
# Objective value at epoch t=28 is inf
# Objective value at epoch t=29 is inf
# Objective value at epoch t=30 is inf
# Objective value at epoch t=31 is inf
# Objective value at epoch t=32 is inf
# Objective value at epoch t=33 is 60.80732277991418
# Objective value at epoch t=34 is 50.873382583634196
# Objective value at epoch t=35 is inf
# Objective value at epoch t=36 is inf
# Objective value at epoch t=37 is inf
# Objective value at epoch t=38 is inf
# Objective value at epoch t=39 is 32.568758100762736
# Objective value at epoch t=40 is 28.103028115408943
# Objective value at epoch t=41 is 23.124213206231094
# Objective value at epoch t=42 is 21.9343987015923
# Objective value at epoch t=43 is 22.688705701269377
# Objective value at epoch t=44 is 17.690324526816756
# Objective value at epoch t=45 is 15.893604982024277
# Objective value at epoch t=46 is 13.790811974172039
# Objective value at epoch t=47 is 12.094122285608492
# Objective value at epoch t=48 is 10.007394091987095
# Objective value at epoch t=49 is 11.030982312654192
# Objective value at epoch t=50 is 9.914863304995714
# Objective value at epoch t=51 is 7.898042314630198
# Objective value at epoch t=52 is 7.957927753383868
# Objective value at epoch t=53 is 6.571541937682264
# Objective value at epoch t=54 is 6.165463659220697
# Objective value at epoch t=55 is 5.807655704031545
# Objective value at epoch t=56 is 4.501671475624338
# Objective value at epoch t=57 is 4.484556667930306
# Objective value at epoch t=58 is 4.056678093129167
# Objective value at epoch t=59 is 3.506684110686191
# Objective value at epoch t=60 is 3.2230671038306498
# Objective value at epoch t=61 is 2.981174129191241
# Objective value at epoch t=62 is 2.3646598197373856
# Objective value at epoch t=63 is 2.343855536414267
# Objective value at epoch t=64 is 2.0021494007658287
# Objective value at epoch t=65 is 2.0033637651332654
# Objective value at epoch t=66 is 1.7909844485527775
# Objective value at epoch t=67 is 1.5801706540587461
# Objective value at epoch t=68 is 1.3811384470894499
# Objective value at epoch t=69 is 1.1495286247117409
# Objective value at epoch t=70 is 1.101846538604286
# Objective value at epoch t=71 is 1.1953386792546499
# Objective value at epoch t=72 is 1.0037648677290927
# Objective value at epoch t=73 is 0.9078637806218299
# Objective value at epoch t=74 is 0.8237225803014226
# Objective value at epoch t=75 is 0.7581349717198431
# Objective value at epoch t=76 is 0.7047614230680175
# Objective value at epoch t=77 is 0.7197594009123531
# Objective value at epoch t=78 is 0.6507160355530173
# Objective value at epoch t=79 is 0.584976545017122
# Objective value at epoch t=80 is 0.6176986075864178
# Objective value at epoch t=81 is 0.6052586009745343
# Objective value at epoch t=82 is 0.5762277310521092
# Objective value at epoch t=83 is 0.5472827024855451
# Objective value at epoch t=84 is 0.5389834512815684
# Objective value at epoch t=85 is 0.5400566330910139
# Objective value at epoch t=86 is 0.5258601515355571
# Objective value at epoch t=87 is 0.5242988456100023
# Objective value at epoch t=88 is 0.508396922584633
# Objective value at epoch t=89 is 0.5060068263139592
# Objective value at epoch t=90 is 0.49980593285744107
# Objective value at epoch t=91 is 0.49819815396223194
# Objective value at epoch t=92 is 0.48193753563556785
# Objective value at epoch t=93 is 0.4989974920874406
# Objective value at epoch t=94 is 0.4907966592513164
# Objective value at epoch t=95 is 0.48493490176088594
# Objective value at epoch t=96 is 0.4901147799944683
# Objective value at epoch t=97 is 0.48368481898040033
# Objective value at epoch t=98 is 0.48174810065888896
# Objective value at epoch t=99 is 0.4801216780349448

# %%
# MB-SGD with batch size b=64
lam = 1E-6 # do not change
b = 64 # do not change

errors_train64 = []
errors_test64 = []
objvals_mbsgd64 = []

for stepsize in stepsizes:
    w_tmp, objval_tmp = mb_sgd(x_train, y_train, lam, b, stepsize)
    f_train = predict(w_tmp, x_train)
    diff = numpy.abs(f_train - y_train) / 2
    error_train = numpy.mean(diff)
    f_test = predict(w_tmp, x_test)
    diff = numpy.abs(f_test - y_test) / 2
    error_test = numpy.mean(diff)
    
    errors_train64.append(error_train)
    errors_test64.append(error_test)
    objvals_mbsgd64.append(objval_tmp)
# Out:
# Objective value at epoch t=0 is 0.6927689484378193
# Objective value at epoch t=1 is 0.6919358286209961
# Objective value at epoch t=2 is 0.6911923692191742
# Objective value at epoch t=3 is 0.6905259341372025
# Objective value at epoch t=4 is 0.6899326795015707
# Objective value at epoch t=5 is 0.6893961383790036
# Objective value at epoch t=6 is 0.6889173884805313
# Objective value at epoch t=7 is 0.6884845713751283
# Objective value at epoch t=8 is 0.6880998829956904
# Objective value at epoch t=9 is 0.6877525107885541
# Objective value at epoch t=10 is 0.687441853761148
# Objective value at epoch t=11 is 0.6871604581667172
# Objective value at epoch t=12 is 0.6869091375676883
# Objective value at epoch t=13 is 0.6866833131695733
# Objective value at epoch t=14 is 0.6864799579304217
# Objective value at epoch t=15 is 0.6862982134423439
# Objective value at epoch t=16 is 0.6861329435969726
# Objective value at epoch t=17 is 0.6859857232682758
# Objective value at epoch t=18 is 0.6858526858990656
# Objective value at epoch t=19 is 0.6857332848846938
# Objective value at epoch t=20 is 0.6856263562284459
# Objective value at epoch t=21 is 0.6855294646833996
# Objective value at epoch t=22 is 0.685442443891609
# Objective value at epoch t=23 is 0.6853643915070478
# Objective value at epoch t=24 is 0.6852942670177079
# Objective value at epoch t=25 is 0.6852311669781213
# Objective value at epoch t=26 is 0.685174329735754
# Objective value at epoch t=27 is 0.6851231212380772
# Objective value at epoch t=28 is 0.6850770283729812
# Objective value at epoch t=29 is 0.6850355837824351
# Objective value at epoch t=30 is 0.6849982137699129
# Objective value at epoch t=31 is 0.6849647180605463
# Objective value at epoch t=32 is 0.6849348019426017
# Objective value at epoch t=33 is 0.6849074155078821
# Objective value at epoch t=34 is 0.6848829920646929
# Objective value at epoch t=35 is 0.684861055492303
# Objective value at epoch t=36 is 0.6848412452911363
# Objective value at epoch t=37 is 0.6848234424058818
# Objective value at epoch t=38 is 0.684807402817557
# Objective value at epoch t=39 is 0.684792974498267
# Objective value at epoch t=40 is 0.684780017962851
# Objective value at epoch t=41 is 0.6847683638839337
# Objective value at epoch t=42 is 0.6847578431390227
# Objective value at epoch t=43 is 0.6847484138467858
# Objective value at epoch t=44 is 0.6847398414516113
# Objective value at epoch t=45 is 0.6847322287340656
# Objective value at epoch t=46 is 0.6847253568150787
# Objective value at epoch t=47 is 0.6847191142451865
# Objective value at epoch t=48 is 0.6847135327968075
# Objective value at epoch t=49 is 0.6847085017250903
# Objective value at epoch t=50 is 0.6847039903914114
# Objective value at epoch t=51 is 0.6846999291578614
# Objective value at epoch t=52 is 0.684696265456493
# Objective value at epoch t=53 is 0.684692941760271
# Objective value at epoch t=54 is 0.6846899981120489
# Objective value at epoch t=55 is 0.6846873231605242
# Objective value at epoch t=56 is 0.6846849256195984
# Objective value at epoch t=57 is 0.6846827511855863
# Objective value at epoch t=58 is 0.6846808100417422
# Objective value at epoch t=59 is 0.6846790574577591
# Objective value at epoch t=60 is 0.684677480949205
# Objective value at epoch t=61 is 0.684676058140263
# Objective value at epoch t=62 is 0.6846747875998361
# Objective value at epoch t=63 is 0.6846736367198025
# Objective value at epoch t=64 is 0.6846726032695072
# Objective value at epoch t=65 is 0.6846716710319243
# Objective value at epoch t=66 is 0.6846708330125552
# Objective value at epoch t=67 is 0.6846700797162573
# Objective value at epoch t=68 is 0.6846694001807794
# Objective value at epoch t=69 is 0.6846687903237768
# Objective value at epoch t=70 is 0.6846682399254871
# Objective value at epoch t=71 is 0.6846677454889658
# Objective value at epoch t=72 is 0.6846673004819075
# Objective value at epoch t=73 is 0.6846668989384312
# Objective value at epoch t=74 is 0.6846665399800459
# Objective value at epoch t=75 is 0.6846662152863213
# Objective value at epoch t=76 is 0.684665923191842
# Objective value at epoch t=77 is 0.684665659819045
# Objective value at epoch t=78 is 0.6846654227962368
# Objective value at epoch t=79 is 0.6846652104151622
# Objective value at epoch t=80 is 0.6846650192740289
# Objective value at epoch t=81 is 0.684664846570104
# Objective value at epoch t=82 is 0.6846646914124294
# Objective value at epoch t=83 is 0.684664551395099
# Objective value at epoch t=84 is 0.6846644253837606
# Objective value at epoch t=85 is 0.6846643126091451
# Objective value at epoch t=86 is 0.6846642107516872
# Objective value at epoch t=87 is 0.6846641194083214
# Objective value at epoch t=88 is 0.6846640363235624
# Objective value at epoch t=89 is 0.6846639623189879
# Objective value at epoch t=90 is 0.6846638955012637
# Objective value at epoch t=91 is 0.6846638353493285
# Objective value at epoch t=92 is 0.6846637813255494
# Objective value at epoch t=93 is 0.6846637326441868
# Objective value at epoch t=94 is 0.6846636886952612
# Objective value at epoch t=95 is 0.6846636492975359
# Objective value at epoch t=96 is 0.6846636137440558
# Objective value at epoch t=97 is 0.6846635818183833
# Objective value at epoch t=98 is 0.6846635530441846
# Objective value at epoch t=99 is 0.68466352717526
# Objective value at epoch t=0 is 0.6894091074582939
# Objective value at epoch t=1 is 0.6814545104256757
# Objective value at epoch t=2 is 0.6746212690280441
# Objective value at epoch t=3 is 0.6687612097587439
# Objective value at epoch t=4 is 0.6636961201226417
# Objective value at epoch t=5 is 0.6592759711051109
# Objective value at epoch t=6 is 0.6554291180647323
# Objective value at epoch t=7 is 0.6520593095776654
# Objective value at epoch t=8 is 0.6491119631714923
# Objective value at epoch t=9 is 0.646501387895275
# Objective value at epoch t=10 is 0.6442085674778943
# Objective value at epoch t=11 is 0.6421735023225733
# Objective value at epoch t=12 is 0.6403809635166544
# Objective value at epoch t=13 is 0.6387858934419254
# Objective value at epoch t=14 is 0.6373705248468169
# Objective value at epoch t=15 is 0.6361120328101327
# Objective value at epoch t=16 is 0.6349853476459936
# Objective value at epoch t=17 is 0.6339910086959828
# Objective value at epoch t=18 is 0.6330967292465774
# Objective value at epoch t=19 is 0.6322950467302028
# Objective value at epoch t=20 is 0.631591629518703
# Objective value at epoch t=21 is 0.6309457223933574
# Objective value at epoch t=22 is 0.6303781339560341
# Objective value at epoch t=23 is 0.6298648696060696
# Objective value at epoch t=24 is 0.6294047938116529
# Objective value at epoch t=25 is 0.628995663972405
# Objective value at epoch t=26 is 0.6286275168827864
# Objective value at epoch t=27 is 0.6282968232156615
# Objective value at epoch t=28 is 0.6279997150392117
# Objective value at epoch t=29 is 0.6277346898116829
# Objective value at epoch t=30 is 0.6274948409272081
# Objective value at epoch t=31 is 0.6272801664223004
# Objective value at epoch t=32 is 0.6270877517651787
# Objective value at epoch t=33 is 0.626914293896532
# Objective value at epoch t=34 is 0.6267589616598455
# Objective value at epoch t=35 is 0.6266190831639913
# Objective value at epoch t=36 is 0.6264931403387155
# Objective value at epoch t=37 is 0.6263801179040507
# Objective value at epoch t=38 is 0.6262782553204662
# Objective value at epoch t=39 is 0.626186857101757
# Objective value at epoch t=40 is 0.6261051040184733
# Objective value at epoch t=41 is 0.6260305310578058
# Objective value at epoch t=42 is 0.6259645327078406
# Objective value at epoch t=43 is 0.6259045104975749
# Objective value at epoch t=44 is 0.625850492048204
# Objective value at epoch t=45 is 0.6258022304546091
# Objective value at epoch t=46 is 0.6257588377531274
# Objective value at epoch t=47 is 0.6257194909557232
# Objective value at epoch t=48 is 0.6256843131552962
# Objective value at epoch t=49 is 0.6256524860129772
# Objective value at epoch t=50 is 0.625623956616998
# Objective value at epoch t=51 is 0.6255982618912668
# Objective value at epoch t=52 is 0.6255752841810864
# Objective value at epoch t=53 is 0.6255544254832028
# Objective value at epoch t=54 is 0.6255356566755077
# Objective value at epoch t=55 is 0.6255188775144546
# Objective value at epoch t=56 is 0.6255036798667951
# Objective value at epoch t=57 is 0.625490107114383
# Objective value at epoch t=58 is 0.6254778693523579
# Objective value at epoch t=59 is 0.6254668104427704
# Objective value at epoch t=60 is 0.6254569130787813
# Objective value at epoch t=61 is 0.6254479885654126
# Objective value at epoch t=62 is 0.6254399156180968
# Objective value at epoch t=63 is 0.6254326917176647
# Objective value at epoch t=64 is 0.6254261636994163
# Objective value at epoch t=65 is 0.6254203031408594
# Objective value at epoch t=66 is 0.62541505353817
# Objective value at epoch t=67 is 0.6254102751149209
# Objective value at epoch t=68 is 0.625406001398057
# Objective value at epoch t=69 is 0.6254021612253986
# Objective value at epoch t=70 is 0.6253986934606269
# Objective value at epoch t=71 is 0.6253955860277884
# Objective value at epoch t=72 is 0.6253927827927088
# Objective value at epoch t=73 is 0.625390259102915
# Objective value at epoch t=74 is 0.6253879833039895
# Objective value at epoch t=75 is 0.6253859542308129
# Objective value at epoch t=76 is 0.6253841114978211
# Objective value at epoch t=77 is 0.6253824629305902
# Objective value at epoch t=78 is 0.6253809587514314
# Objective value at epoch t=79 is 0.6253796213272954
# Objective value at epoch t=80 is 0.625378414946282
# Objective value at epoch t=81 is 0.6253773288602098
# Objective value at epoch t=82 is 0.6253763535938195
# Objective value at epoch t=83 is 0.6253754703313679
# Objective value at epoch t=84 is 0.6253746803105529
# Objective value at epoch t=85 is 0.6253739667853173
# Objective value at epoch t=86 is 0.6253733257833489
# Objective value at epoch t=87 is 0.6253727518486016
# Objective value at epoch t=88 is 0.6253722315687467
# Objective value at epoch t=89 is 0.6253717620583005
# Objective value at epoch t=90 is 0.625371342002901
# Objective value at epoch t=91 is 0.625370964481149
# Objective value at epoch t=92 is 0.6253706227751581
# Objective value at epoch t=93 is 0.6253703156643085
# Objective value at epoch t=94 is 0.6253700406423748
# Objective value at epoch t=95 is 0.6253697914896255
# Objective value at epoch t=96 is 0.6253695685489965
# Objective value at epoch t=97 is 0.6253693672722248
# Objective value at epoch t=98 is 0.6253691862595413
# Objective value at epoch t=99 is 0.6253690229304617
# Objective value at epoch t=0 is 0.6602944519309142
# Objective value at epoch t=1 is 0.6068250515681873
# Objective value at epoch t=2 is 0.5759112278418361
# Objective value at epoch t=3 is 0.5556385552024078
# Objective value at epoch t=4 is 0.5420632157763385
# Objective value at epoch t=5 is 0.5321971485841944
# Objective value at epoch t=6 is 0.5247028620143261
# Objective value at epoch t=7 is 0.5191061840635575
# Objective value at epoch t=8 is 0.5143857740771971
# Objective value at epoch t=9 is 0.5108007958409868
# Objective value at epoch t=10 is 0.5076489970558755
# Objective value at epoch t=11 is 0.505187894089621
# Objective value at epoch t=12 is 0.5031055588015346
# Objective value at epoch t=13 is 0.5013166543997013
# Objective value at epoch t=14 is 0.49982055591550817
# Objective value at epoch t=15 is 0.4985441607715515
# Objective value at epoch t=16 is 0.49745963742651433
# Objective value at epoch t=17 is 0.49649529629142963
# Objective value at epoch t=18 is 0.49563588452958074
# Objective value at epoch t=19 is 0.4948716059553681
# Objective value at epoch t=20 is 0.4942541460447691
# Objective value at epoch t=21 is 0.4936760410161348
# Objective value at epoch t=22 is 0.4932017634630273
# Objective value at epoch t=23 is 0.492746082626379
# Objective value at epoch t=24 is 0.4923717485511271
# Objective value at epoch t=25 is 0.4920217411625786
# Objective value at epoch t=26 is 0.4917043577084
# Objective value at epoch t=27 is 0.49144079284243203
# Objective value at epoch t=28 is 0.49119054823911323
# Objective value at epoch t=29 is 0.49098234092217774
# Objective value at epoch t=30 is 0.49078226223676147
# Objective value at epoch t=31 is 0.49060982077081405
# Objective value at epoch t=32 is 0.4904561366533032
# Objective value at epoch t=33 is 0.4903290562760122
# Objective value at epoch t=34 is 0.4902023829457659
# Objective value at epoch t=35 is 0.49009357326127684
# Objective value at epoch t=36 is 0.48998628932884547
# Objective value at epoch t=37 is 0.4899018638048574
# Objective value at epoch t=38 is 0.48982517044933305
# Objective value at epoch t=39 is 0.4897513580663272
# Objective value at epoch t=40 is 0.4896904954641341
# Objective value at epoch t=41 is 0.4896362459366463
# Objective value at epoch t=42 is 0.48958030031703925
# Objective value at epoch t=43 is 0.48953474423243265
# Objective value at epoch t=44 is 0.4894958684206904
# Objective value at epoch t=45 is 0.4894558072374163
# Objective value at epoch t=46 is 0.48942350365249715
# Objective value at epoch t=47 is 0.48939208658602756
# Objective value at epoch t=48 is 0.4893644824984783
# Objective value at epoch t=49 is 0.4893400802887665
# Objective value at epoch t=50 is 0.48931835200562707
# Objective value at epoch t=51 is 0.48929882147354553
# Objective value at epoch t=52 is 0.4892816947523184
# Objective value at epoch t=53 is 0.48926521640294895
# Objective value at epoch t=54 is 0.48925214668055217
# Objective value at epoch t=55 is 0.4892394286250389
# Objective value at epoch t=56 is 0.489226891706595
# Objective value at epoch t=57 is 0.4892167399410898
# Objective value at epoch t=58 is 0.48920711903513814
# Objective value at epoch t=59 is 0.4891988090469891
# Objective value at epoch t=60 is 0.48919118964078984
# Objective value at epoch t=61 is 0.48918436768291923
# Objective value at epoch t=62 is 0.48917885334942196
# Objective value at epoch t=63 is 0.48917275680669403
# Objective value at epoch t=64 is 0.4891677600820315
# Objective value at epoch t=65 is 0.48916337541687777
# Objective value at epoch t=66 is 0.4891591505385632
# Objective value at epoch t=67 is 0.4891558355600796
# Objective value at epoch t=68 is 0.4891523891578287
# Objective value at epoch t=69 is 0.4891493823340623
# Objective value at epoch t=70 is 0.4891468654020887
# Objective value at epoch t=71 is 0.48914448484632655
# Objective value at epoch t=72 is 0.48914236666707256
# Objective value at epoch t=73 is 0.48914057886412
# Objective value at epoch t=74 is 0.48913873504121363
# Objective value at epoch t=75 is 0.4891371205385866
# Objective value at epoch t=76 is 0.48913572465452154
# Objective value at epoch t=77 is 0.48913446685137396
# Objective value at epoch t=78 is 0.48913337778337773
# Objective value at epoch t=79 is 0.48913236946130334
# Objective value at epoch t=80 is 0.48913139771220726
# Objective value at epoch t=81 is 0.4891306063527298
# Objective value at epoch t=82 is 0.4891298514176955
# Objective value at epoch t=83 is 0.4891292279646081
# Objective value at epoch t=84 is 0.4891285816131227
# Objective value at epoch t=85 is 0.4891280261229133
# Objective value at epoch t=86 is 0.48912756601331864
# Objective value at epoch t=87 is 0.48912710001716936
# Objective value at epoch t=88 is 0.48912671539976255
# Objective value at epoch t=89 is 0.48912634016244166
# Objective value at epoch t=90 is 0.489126059567488
# Objective value at epoch t=91 is 0.4891257396827853
# Objective value at epoch t=92 is 0.4891254864995133
# Objective value at epoch t=93 is 0.4891252441093733
# Objective value at epoch t=94 is 0.489125049002476
# Objective value at epoch t=95 is 0.4891248620454536
# Objective value at epoch t=96 is 0.48912468342716736
# Objective value at epoch t=97 is 0.4891245254759168
# Objective value at epoch t=98 is 0.489124394424313
# Objective value at epoch t=99 is 0.4891242729005588
# Objective value at epoch t=0 is 0.5529450510026666
# Objective value at epoch t=1 is 0.48356373780838713
# Objective value at epoch t=2 is 0.47229693422666746
# Objective value at epoch t=3 is 0.4694937838480821
# Objective value at epoch t=4 is 0.4687868151199178
# Objective value at epoch t=5 is 0.46748555490999977
# Objective value at epoch t=6 is 0.4663487522988059
# Objective value at epoch t=7 is 0.4655444030646156
# Objective value at epoch t=8 is 0.46437940077628614
# Objective value at epoch t=9 is 0.46501960324967156
# Objective value at epoch t=10 is 0.4638563510500903
# Objective value at epoch t=11 is 0.4636752551801598
# Objective value at epoch t=12 is 0.46383282515529967
# Objective value at epoch t=13 is 0.4636644534727335
# Objective value at epoch t=14 is 0.4633656016072122
# Objective value at epoch t=15 is 0.46335268709699573
# Objective value at epoch t=16 is 0.4636667197464989
# Objective value at epoch t=17 is 0.46305178521423346
# Objective value at epoch t=18 is 0.4631289754162927
# Objective value at epoch t=19 is 0.4628842135144553
# Objective value at epoch t=20 is 0.46298860107464845
# Objective value at epoch t=21 is 0.46255791253232237
# Objective value at epoch t=22 is 0.4626825329610987
# Objective value at epoch t=23 is 0.4625395115295058
# Objective value at epoch t=24 is 0.46246754874150164
# Objective value at epoch t=25 is 0.46265227694835803
# Objective value at epoch t=26 is 0.46240057841484516
# Objective value at epoch t=27 is 0.46250229500081996
# Objective value at epoch t=28 is 0.46233237874283306
# Objective value at epoch t=29 is 0.46231247934835695
# Objective value at epoch t=30 is 0.46221731089831175
# Objective value at epoch t=31 is 0.46215869874785465
# Objective value at epoch t=32 is 0.46216297769819814
# Objective value at epoch t=33 is 0.4621847464657871
# Objective value at epoch t=34 is 0.4621426984340532
# Objective value at epoch t=35 is 0.46212740467884605
# Objective value at epoch t=36 is 0.46204647599610454
# Objective value at epoch t=37 is 0.4621148552811666
# Objective value at epoch t=38 is 0.46208407264714413
# Objective value at epoch t=39 is 0.462058015856579
# Objective value at epoch t=40 is 0.462047634107147
# Objective value at epoch t=41 is 0.4620131109589988
# Objective value at epoch t=42 is 0.4620306335547875
# Objective value at epoch t=43 is 0.46200948759711036
# Objective value at epoch t=44 is 0.4620069528732743
# Objective value at epoch t=45 is 0.4619821268309582
# Objective value at epoch t=46 is 0.46197383650440005
# Objective value at epoch t=47 is 0.4619760873933262
# Objective value at epoch t=48 is 0.4619738644647272
# Objective value at epoch t=49 is 0.46197397515024663
# Objective value at epoch t=50 is 0.46196023771609446
# Objective value at epoch t=51 is 0.46196036046424416
# Objective value at epoch t=52 is 0.46196133704989667
# Objective value at epoch t=53 is 0.4619486802675635
# Objective value at epoch t=54 is 0.4619538461048253
# Objective value at epoch t=55 is 0.46194638947253724
# Objective value at epoch t=56 is 0.4619485759525948
# Objective value at epoch t=57 is 0.4619504364152536
# Objective value at epoch t=58 is 0.46194514504264583
# Objective value at epoch t=59 is 0.4619479176844057
# Objective value at epoch t=60 is 0.46194353328053894
# Objective value at epoch t=61 is 0.46194455959746356
# Objective value at epoch t=62 is 0.4619428334515351
# Objective value at epoch t=63 is 0.4619404627125621
# Objective value at epoch t=64 is 0.4619427739482296
# Objective value at epoch t=65 is 0.46193958211649433
# Objective value at epoch t=66 is 0.4619400310008328
# Objective value at epoch t=67 is 0.4619369009457551
# Objective value at epoch t=68 is 0.461936832770101
# Objective value at epoch t=69 is 0.46193631404560387
# Objective value at epoch t=70 is 0.4619345697039308
# Objective value at epoch t=71 is 0.46193611933696443
# Objective value at epoch t=72 is 0.4619352454958313
# Objective value at epoch t=73 is 0.46193527968998155
# Objective value at epoch t=74 is 0.46193512705654094
# Objective value at epoch t=75 is 0.4619336212878359
# Objective value at epoch t=76 is 0.4619337050694202
# Objective value at epoch t=77 is 0.4619338535500531
# Objective value at epoch t=78 is 0.4619333485618126
# Objective value at epoch t=79 is 0.461934335555818
# Objective value at epoch t=80 is 0.4619335789741559
# Objective value at epoch t=81 is 0.4619325644993791
# Objective value at epoch t=82 is 0.4619334550253174
# Objective value at epoch t=83 is 0.46193258019897615
# Objective value at epoch t=84 is 0.4619327594032373
# Objective value at epoch t=85 is 0.46193285087116925
# Objective value at epoch t=86 is 0.46193253345247837
# Objective value at epoch t=87 is 0.46193246927438186
# Objective value at epoch t=88 is 0.461932540488729
# Objective value at epoch t=89 is 0.4619322495799324
# Objective value at epoch t=90 is 0.4619322405200399
# Objective value at epoch t=91 is 0.4619322984565294
# Objective value at epoch t=92 is 0.46193216608625604
# Objective value at epoch t=93 is 0.46193212913914844
# Objective value at epoch t=94 is 0.4619322147473322
# Objective value at epoch t=95 is 0.46193210644494187
# Objective value at epoch t=96 is 0.4619320954277895
# Objective value at epoch t=97 is 0.46193202782524
# Objective value at epoch t=98 is 0.4619320207938976
# Objective value at epoch t=99 is 0.4619319800014365
# Objective value at epoch t=0 is 0.5992841482123514
# Objective value at epoch t=1 is 0.6047015119193188
# Objective value at epoch t=2 is 0.5261670081576011
# Objective value at epoch t=3 is 0.49646370373734944
# Objective value at epoch t=4 is 0.4999674736465286
# Objective value at epoch t=5 is 0.5117173919442786
# Objective value at epoch t=6 is 0.4984496235477874
# Objective value at epoch t=7 is 0.489346778596094
# Objective value at epoch t=8 is 0.5019102076929366
# Objective value at epoch t=9 is 0.47926682109756447
# Objective value at epoch t=10 is 0.4876008894130653
# Objective value at epoch t=11 is 0.4703285605126449
# Objective value at epoch t=12 is 0.48051154870372803
# Objective value at epoch t=13 is 0.47844508426466614
# Objective value at epoch t=14 is 0.4745204042175401
# Objective value at epoch t=15 is 0.47784857696804234
# Objective value at epoch t=16 is 0.4711252151362354
# Objective value at epoch t=17 is 0.4748808893789482
# Objective value at epoch t=18 is 0.4749491112441695
# Objective value at epoch t=19 is 0.4675143959452644
# Objective value at epoch t=20 is 0.4674066929651642
# Objective value at epoch t=21 is 0.46912968478379924
# Objective value at epoch t=22 is 0.46823976286106445
# Objective value at epoch t=23 is 0.46772882336871024
# Objective value at epoch t=24 is 0.46664572011743644
# Objective value at epoch t=25 is 0.46567842884325544
# Objective value at epoch t=26 is 0.4649018660424753
# Objective value at epoch t=27 is 0.4647685560923427
# Objective value at epoch t=28 is 0.46603071594807144
# Objective value at epoch t=29 is 0.46471654053699024
# Objective value at epoch t=30 is 0.46435154604590334
# Objective value at epoch t=31 is 0.46394793627002207
# Objective value at epoch t=32 is 0.4637422595037176
# Objective value at epoch t=33 is 0.46314534387241524
# Objective value at epoch t=34 is 0.46411605529833333
# Objective value at epoch t=35 is 0.4638893574446584
# Objective value at epoch t=36 is 0.46309333804623715
# Objective value at epoch t=37 is 0.4631781819395666
# Objective value at epoch t=38 is 0.46282049967676525
# Objective value at epoch t=39 is 0.4633493095583838
# Objective value at epoch t=40 is 0.46299431691196585
# Objective value at epoch t=41 is 0.4626877107305252
# Objective value at epoch t=42 is 0.46257564328081247
# Objective value at epoch t=43 is 0.4628026285118899
# Objective value at epoch t=44 is 0.46240527251888947
# Objective value at epoch t=45 is 0.4626992245937161
# Objective value at epoch t=46 is 0.4626850115853931
# Objective value at epoch t=47 is 0.4623379601860299
# Objective value at epoch t=48 is 0.46229747326871895
# Objective value at epoch t=49 is 0.4623640075402057
# Objective value at epoch t=50 is 0.4623479507432761
# Objective value at epoch t=51 is 0.46220918703106373
# Objective value at epoch t=52 is 0.462127146860944
# Objective value at epoch t=53 is 0.46220373790665875
# Objective value at epoch t=54 is 0.46218930997937846
# Objective value at epoch t=55 is 0.4621187662279314
# Objective value at epoch t=56 is 0.46206736046796726
# Objective value at epoch t=57 is 0.46206314117390734
# Objective value at epoch t=58 is 0.46203015691667193
# Objective value at epoch t=59 is 0.4620448052494024
# Objective value at epoch t=60 is 0.46204663837355475
# Objective value at epoch t=61 is 0.46202520673239933
# Objective value at epoch t=62 is 0.4620210314360298
# Objective value at epoch t=63 is 0.46200376275316807
# Objective value at epoch t=64 is 0.46200257610864776
# Objective value at epoch t=65 is 0.4619913965186252
# Objective value at epoch t=66 is 0.46199465014726304
# Objective value at epoch t=67 is 0.46199172854983866
# Objective value at epoch t=68 is 0.4619849512226536
# Objective value at epoch t=69 is 0.46196637956662406
# Objective value at epoch t=70 is 0.4619705893739696
# Objective value at epoch t=71 is 0.46195187783768094
# Objective value at epoch t=72 is 0.46195496923367785
# Objective value at epoch t=73 is 0.4619554043619029
# Objective value at epoch t=74 is 0.4619492732434981
# Objective value at epoch t=75 is 0.4619517788088957
# Objective value at epoch t=76 is 0.46194778736157005
# Objective value at epoch t=77 is 0.4619432399470985
# Objective value at epoch t=78 is 0.46194351112125365
# Objective value at epoch t=79 is 0.46194626022697644
# Objective value at epoch t=80 is 0.4619402124272603
# Objective value at epoch t=81 is 0.46194124537629266
# Objective value at epoch t=82 is 0.46193918604526923
# Objective value at epoch t=83 is 0.4619393417100161
# Objective value at epoch t=84 is 0.4619348246285573
# Objective value at epoch t=85 is 0.4619343114018511
# Objective value at epoch t=86 is 0.4619337021100983
# Objective value at epoch t=87 is 0.461935626397611
# Objective value at epoch t=88 is 0.46193523222196103
# Objective value at epoch t=89 is 0.4619312575201756
# Objective value at epoch t=90 is 0.4619322342892526
# Objective value at epoch t=91 is 0.4619316364066341
# Objective value at epoch t=92 is 0.461931211946908
# Objective value at epoch t=93 is 0.4619316275587576
# Objective value at epoch t=94 is 0.4619302129432025
# Objective value at epoch t=95 is 0.4619305524255527
# Objective value at epoch t=96 is 0.46193054138925416
# Objective value at epoch t=97 is 0.4619294785829441
# Objective value at epoch t=98 is 0.46192939629891167
# Objective value at epoch t=99 is 0.4619296610032967
# Objective value at epoch t=0 is 4.365489068781536
# Objective value at epoch t=1 is 3.9701292585638823
# Objective value at epoch t=2 is 4.577596192751545
# Objective value at epoch t=3 is 3.343244229082363
# Objective value at epoch t=4 is 2.915156647616593
# Objective value at epoch t=5 is 2.2940322641665807
# Objective value at epoch t=6 is 2.1213607926633866
# Objective value at epoch t=7 is 2.011811373831576
# Objective value at epoch t=8 is 2.4548391154021263
# Objective value at epoch t=9 is 2.065064969672
# Objective value at epoch t=10 is 1.6664721228116377
# Objective value at epoch t=11 is 2.140605119413006
# Objective value at epoch t=12 is 1.2165655693325257
# Objective value at epoch t=13 is 1.3699600034159878
# Objective value at epoch t=14 is 1.1480745661207423
# Objective value at epoch t=15 is 1.000606956373897
# Objective value at epoch t=16 is 1.0940698751545574
# Objective value at epoch t=17 is 0.8117498380899786
# Objective value at epoch t=18 is 0.7226940658025262
# Objective value at epoch t=19 is 0.7842432641620365
# Objective value at epoch t=20 is 0.6731267447396738
# Objective value at epoch t=21 is 0.5674860795000047
# Objective value at epoch t=22 is 0.5927366119178654
# Objective value at epoch t=23 is 0.5440129284147313
# Objective value at epoch t=24 is 0.5243891959926976
# Objective value at epoch t=25 is 0.4992416036084394
# Objective value at epoch t=26 is 0.5069286951610729
# Objective value at epoch t=27 is 0.5007755340171238
# Objective value at epoch t=28 is 0.4914770852260145
# Objective value at epoch t=29 is 0.503603832391545
# Objective value at epoch t=30 is 0.4958087813050954
# Objective value at epoch t=31 is 0.4932417838580797
# Objective value at epoch t=32 is 0.47238726188236824
# Objective value at epoch t=33 is 0.47750432683635485
# Objective value at epoch t=34 is 0.47995702746075264
# Objective value at epoch t=35 is 0.47913587997697815
# Objective value at epoch t=36 is 0.4785513199462839
# Objective value at epoch t=37 is 0.47433034592119316
# Objective value at epoch t=38 is 0.4742705766865939
# Objective value at epoch t=39 is 0.4699163959901866
# Objective value at epoch t=40 is 0.4699719159351236
# Objective value at epoch t=41 is 0.46942562975176616
# Objective value at epoch t=42 is 0.4699215164798013
# Objective value at epoch t=43 is 0.4695840437541695
# Objective value at epoch t=44 is 0.4665035782543554
# Objective value at epoch t=45 is 0.4672915013758149
# Objective value at epoch t=46 is 0.4672593931601289
# Objective value at epoch t=47 is 0.4667038628943964
# Objective value at epoch t=48 is 0.46730942611077964
# Objective value at epoch t=49 is 0.4658817206274589
# Objective value at epoch t=50 is 0.4649617680134245
# Objective value at epoch t=51 is 0.465105201854006
# Objective value at epoch t=52 is 0.4651930603162029
# Objective value at epoch t=53 is 0.4641575728300492
# Objective value at epoch t=54 is 0.4643789716791943
# Objective value at epoch t=55 is 0.46381244248951914
# Objective value at epoch t=56 is 0.46431943165218226
# Objective value at epoch t=57 is 0.4631806123607996
# Objective value at epoch t=58 is 0.46330948144482764
# Objective value at epoch t=59 is 0.46318340368038885
# Objective value at epoch t=60 is 0.46323060589926535
# Objective value at epoch t=61 is 0.462985784225014
# Objective value at epoch t=62 is 0.4636682445535193
# Objective value at epoch t=63 is 0.4627455156389491
# Objective value at epoch t=64 is 0.46276098627391604
# Objective value at epoch t=65 is 0.4627546016401067
# Objective value at epoch t=66 is 0.46269193505524103
# Objective value at epoch t=67 is 0.46260879189030096
# Objective value at epoch t=68 is 0.4623233029557553
# Objective value at epoch t=69 is 0.4625594053457213
# Objective value at epoch t=70 is 0.46233831033061923
# Objective value at epoch t=71 is 0.4623153339922985
# Objective value at epoch t=72 is 0.4622840760773478
# Objective value at epoch t=73 is 0.4621455839236067
# Objective value at epoch t=74 is 0.4622204297458876
# Objective value at epoch t=75 is 0.46215256229857926
# Objective value at epoch t=76 is 0.46219502307795485
# Objective value at epoch t=77 is 0.4620867849104071
# Objective value at epoch t=78 is 0.46210641680083786
# Objective value at epoch t=79 is 0.46204439114324447
# Objective value at epoch t=80 is 0.46207747635064556
# Objective value at epoch t=81 is 0.46205240519759005
# Objective value at epoch t=82 is 0.462007219955726
# Objective value at epoch t=83 is 0.4620600390862431
# Objective value at epoch t=84 is 0.4620181740225936
# Objective value at epoch t=85 is 0.4620275274769967
# Objective value at epoch t=86 is 0.46199493844814976
# Objective value at epoch t=87 is 0.46199589306857664
# Objective value at epoch t=88 is 0.4619892390031025
# Objective value at epoch t=89 is 0.4619752920225374
# Objective value at epoch t=90 is 0.46199041540306157
# Objective value at epoch t=91 is 0.46196157786725883
# Objective value at epoch t=92 is 0.4619897524361519
# Objective value at epoch t=93 is 0.46196723665136863
# Objective value at epoch t=94 is 0.46196353326523515
# Objective value at epoch t=95 is 0.4619528768066868
# Objective value at epoch t=96 is 0.461968522355928
# Objective value at epoch t=97 is 0.46195342613614665
# Objective value at epoch t=98 is 0.4619485170382546
# Objective value at epoch t=99 is 0.4619475737151353
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is 31.59357266407303
# Objective value at epoch t=4 is 28.85430925771147
# Objective value at epoch t=5 is 25.14334694703957
# Objective value at epoch t=6 is 25.252597874077665
# Objective value at epoch t=7 is 21.49716055523845
# Objective value at epoch t=8 is 20.951955348177005
# Objective value at epoch t=9 is 21.434556331394653
# Objective value at epoch t=10 is 20.98900251841696
# Objective value at epoch t=11 is 17.25548112147634
# Objective value at epoch t=12 is 14.21836703125993
# Objective value at epoch t=13 is 14.525108525696556
# Objective value at epoch t=14 is 10.237315448887111
# Objective value at epoch t=15 is 9.005661932406502
# Objective value at epoch t=16 is 7.750420042943264
# Objective value at epoch t=17 is 7.052601550248672
# Objective value at epoch t=18 is 8.585471324801597
# Objective value at epoch t=19 is 9.059553980894277
# Objective value at epoch t=20 is 6.558730704167651
# Objective value at epoch t=21 is 5.327253496118689
# Objective value at epoch t=22 is 5.467362073798969
# Objective value at epoch t=23 is 5.551740236627432
# Objective value at epoch t=24 is 3.925851614974846
# Objective value at epoch t=25 is 3.735111617227333
# Objective value at epoch t=26 is 2.9479139643105463
# Objective value at epoch t=27 is 2.480237491889487
# Objective value at epoch t=28 is 2.9248144666399227
# Objective value at epoch t=29 is 2.9908560596352434
# Objective value at epoch t=30 is 2.5251629499682413
# Objective value at epoch t=31 is 2.1687508968009857
# Objective value at epoch t=32 is 1.5028637675753178
# Objective value at epoch t=33 is 1.5967292807687576
# Objective value at epoch t=34 is 1.423425536250481
# Objective value at epoch t=35 is 1.3311774401577021
# Objective value at epoch t=36 is 0.9212749582002571
# Objective value at epoch t=37 is 1.0240521117768764
# Objective value at epoch t=38 is 0.9937208277000138
# Objective value at epoch t=39 is 0.8652448899380263
# Objective value at epoch t=40 is 0.8535821065353086
# Objective value at epoch t=41 is 0.7726649878061306
# Objective value at epoch t=42 is 0.6324696753400454
# Objective value at epoch t=43 is 0.6585034033499066
# Objective value at epoch t=44 is 0.6114692370754804
# Objective value at epoch t=45 is 0.5635414868404456
# Objective value at epoch t=46 is 0.5157479944903159
# Objective value at epoch t=47 is 0.5301902434701049
# Objective value at epoch t=48 is 0.49541254046383976
# Objective value at epoch t=49 is 0.5085864114369566
# Objective value at epoch t=50 is 0.5100148957944064
# Objective value at epoch t=51 is 0.5056974376113003
# Objective value at epoch t=52 is 0.4822686921173478
# Objective value at epoch t=53 is 0.47814121865804166
# Objective value at epoch t=54 is 0.48210022818703974
# Objective value at epoch t=55 is 0.479446214947303
# Objective value at epoch t=56 is 0.48089486810095405
# Objective value at epoch t=57 is 0.4821617788633718
# Objective value at epoch t=58 is 0.4778515608107149
# Objective value at epoch t=59 is 0.48098726307247536
# Objective value at epoch t=60 is 0.46980501692353915
# Objective value at epoch t=61 is 0.4714838152248257
# Objective value at epoch t=62 is 0.47147613691417334
# Objective value at epoch t=63 is 0.46888522630575247
# Objective value at epoch t=64 is 0.46785057602161917
# Objective value at epoch t=65 is 0.4686191731369118
# Objective value at epoch t=66 is 0.468489334402857
# Objective value at epoch t=67 is 0.4673978352302253
# Objective value at epoch t=68 is 0.46668760658037434
# Objective value at epoch t=69 is 0.46672214804221046
# Objective value at epoch t=70 is 0.46789737409189724
# Objective value at epoch t=71 is 0.4659489703134412
# Objective value at epoch t=72 is 0.4656454101021595
# Objective value at epoch t=73 is 0.46514801313415105
# Objective value at epoch t=74 is 0.4639064552221817
# Objective value at epoch t=75 is 0.46420283238643006
# Objective value at epoch t=76 is 0.46424016400026036
# Objective value at epoch t=77 is 0.46396943667790913
# Objective value at epoch t=78 is 0.4637454813378201
# Objective value at epoch t=79 is 0.46370219505709676
# Objective value at epoch t=80 is 0.4633216772459864
# Objective value at epoch t=81 is 0.46317939302801936
# Objective value at epoch t=82 is 0.4629942014960677
# Objective value at epoch t=83 is 0.4632487988852717
# Objective value at epoch t=84 is 0.46297514017845137
# Objective value at epoch t=85 is 0.46264320674998577
# Objective value at epoch t=86 is 0.462791456698085
# Objective value at epoch t=87 is 0.4625421802549642
# Objective value at epoch t=88 is 0.46261230123067615
# Objective value at epoch t=89 is 0.46253568295745834
# Objective value at epoch t=90 is 0.46228170414123
# Objective value at epoch t=91 is 0.46241332557188936
# Objective value at epoch t=92 is 0.46236667697151035
# Objective value at epoch t=93 is 0.46226882698575017
# Objective value at epoch t=94 is 0.4623392510189105
# Objective value at epoch t=95 is 0.46217536809462423
# Objective value at epoch t=96 is 0.46228307199788554
# Objective value at epoch t=97 is 0.4622331890567418
# Objective value at epoch t=98 is 0.4621392643114538
# Objective value at epoch t=99 is 0.4621322485627012
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is inf
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is inf
# Objective value at epoch t=15 is inf
# Objective value at epoch t=16 is inf
# Objective value at epoch t=17 is inf
# Objective value at epoch t=18 is inf
# Objective value at epoch t=19 is inf
# Objective value at epoch t=20 is inf
# Objective value at epoch t=21 is inf
# Objective value at epoch t=22 is inf
# Objective value at epoch t=23 is inf
# Objective value at epoch t=24 is 42.65560462071413
# Objective value at epoch t=25 is inf
# Objective value at epoch t=26 is 32.33140865186384
# Objective value at epoch t=27 is 32.09844153716017
# Objective value at epoch t=28 is 19.949018939358965
# Objective value at epoch t=29 is inf
# Objective value at epoch t=30 is 21.368070302059497
# Objective value at epoch t=31 is 21.114837016025664
# Objective value at epoch t=32 is 13.602618957813869
# Objective value at epoch t=33 is 13.489848318160787
# Objective value at epoch t=34 is 11.54104909965337
# Objective value at epoch t=35 is 12.038676029740717
# Objective value at epoch t=36 is 11.083053939942804
# Objective value at epoch t=37 is 11.467950555486727
# Objective value at epoch t=38 is 8.031524460062055
# Objective value at epoch t=39 is 7.4038340426717495
# Objective value at epoch t=40 is 8.457305237516858
# Objective value at epoch t=41 is 6.378858442737387
# Objective value at epoch t=42 is 5.1005656685914325
# Objective value at epoch t=43 is 5.521344948310724
# Objective value at epoch t=44 is 6.422477843789113
# Objective value at epoch t=45 is 5.803448751591923
# Objective value at epoch t=46 is 4.608020420393917
# Objective value at epoch t=47 is 3.0635189400410456
# Objective value at epoch t=48 is 3.074598531127321
# Objective value at epoch t=49 is 2.2115220953223624
# Objective value at epoch t=50 is 2.3875241668265064
# Objective value at epoch t=51 is 1.644472298515312
# Objective value at epoch t=52 is 2.1767563342531613
# Objective value at epoch t=53 is 1.873882447202456
# Objective value at epoch t=54 is 1.8535253928050732
# Objective value at epoch t=55 is 1.3897921554650323
# Objective value at epoch t=56 is 1.1900902921148535
# Objective value at epoch t=57 is 1.1848113674352128
# Objective value at epoch t=58 is 1.0428287194870025
# Objective value at epoch t=59 is 0.9453602096114654
# Objective value at epoch t=60 is 0.8038203691100658
# Objective value at epoch t=61 is 0.7560201774862578
# Objective value at epoch t=62 is 0.7317205882179376
# Objective value at epoch t=63 is 0.727747142941574
# Objective value at epoch t=64 is 0.5684223845438966
# Objective value at epoch t=65 is 0.7061221405250493
# Objective value at epoch t=66 is 0.5623034224267454
# Objective value at epoch t=67 is 0.5069837990913195
# Objective value at epoch t=68 is 0.5383597418958674
# Objective value at epoch t=69 is 0.5070179248868116
# Objective value at epoch t=70 is 0.5371753022208565
# Objective value at epoch t=71 is 0.5311384375916248
# Objective value at epoch t=72 is 0.48680967970507305
# Objective value at epoch t=73 is 0.4802814057812446
# Objective value at epoch t=74 is 0.49926054862126945
# Objective value at epoch t=75 is 0.4932461981357627
# Objective value at epoch t=76 is 0.4861936367381123
# Objective value at epoch t=77 is 0.4819406642685262
# Objective value at epoch t=78 is 0.48238513286548024
# Objective value at epoch t=79 is 0.4720533983645547
# Objective value at epoch t=80 is 0.4762246388722625
# Objective value at epoch t=81 is 0.4704677158340475
# Objective value at epoch t=82 is 0.4733736624321751
# Objective value at epoch t=83 is 0.47621900125854905
# Objective value at epoch t=84 is 0.4721592756467068
# Objective value at epoch t=85 is 0.4706501606810473
# Objective value at epoch t=86 is 0.46858978611342783
# Objective value at epoch t=87 is 0.47035104203382405
# Objective value at epoch t=88 is 0.4687051138139635
# Objective value at epoch t=89 is 0.4664734773513313
# Objective value at epoch t=90 is 0.46687584556625444
# Objective value at epoch t=91 is 0.4650517836364858
# Objective value at epoch t=92 is 0.46628427545449025
# Objective value at epoch t=93 is 0.4641478488083973
# Objective value at epoch t=94 is 0.4663684685839195
# Objective value at epoch t=95 is 0.46380241136548495
# Objective value at epoch t=96 is 0.46444336208021586
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: overflow encountered in exp
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in exp
# Objective value at epoch t=97 is 0.46433766756146183
# Objective value at epoch t=98 is 0.464084813106997
# Objective value at epoch t=99 is 0.46397953346369264
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is inf
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is inf
# Objective value at epoch t=15 is inf
# Objective value at epoch t=16 is inf
# Objective value at epoch t=17 is inf
# Objective value at epoch t=18 is inf
# Objective value at epoch t=19 is inf
# Objective value at epoch t=20 is inf
# Objective value at epoch t=21 is inf
# Objective value at epoch t=22 is inf
# Objective value at epoch t=23 is inf
# Objective value at epoch t=24 is inf
# Objective value at epoch t=25 is inf
# Objective value at epoch t=26 is inf
# Objective value at epoch t=27 is inf
# Objective value at epoch t=28 is inf
# Objective value at epoch t=29 is inf
# Objective value at epoch t=30 is inf
# Objective value at epoch t=31 is inf
# Objective value at epoch t=32 is inf
# Objective value at epoch t=33 is inf
# Objective value at epoch t=34 is inf
# Objective value at epoch t=35 is inf
# Objective value at epoch t=36 is inf
# Objective value at epoch t=37 is inf
# Objective value at epoch t=38 is inf
# Objective value at epoch t=39 is inf
# Objective value at epoch t=40 is inf
# Objective value at epoch t=41 is inf
# Objective value at epoch t=42 is inf
# Objective value at epoch t=43 is inf
# Objective value at epoch t=44 is inf
# Objective value at epoch t=45 is inf
# Objective value at epoch t=46 is 44.60099546857807
# Objective value at epoch t=47 is 35.06369159212716
# Objective value at epoch t=48 is 33.55242224978339
# Objective value at epoch t=49 is 24.99509668652989
# Objective value at epoch t=50 is 26.109716233668202
# Objective value at epoch t=51 is 17.85970873210663
# Objective value at epoch t=52 is 19.44071051650328
# Objective value at epoch t=53 is 20.472502215395203
# Objective value at epoch t=54 is 21.784433285009808
# Objective value at epoch t=55 is 16.29083140758705
# Objective value at epoch t=56 is 15.555014478794709
# Objective value at epoch t=57 is 10.578877030861635
# Objective value at epoch t=58 is 10.665318698415224
# Objective value at epoch t=59 is 9.331894118227806
# Objective value at epoch t=60 is 8.529717147522934
# Objective value at epoch t=61 is 8.307385904213115
# Objective value at epoch t=62 is 8.526568643476736
# Objective value at epoch t=63 is 5.836525112332161
# Objective value at epoch t=64 is 5.537085230194935
# Objective value at epoch t=65 is 5.612311645880576
# Objective value at epoch t=66 is 3.125137160101956
# Objective value at epoch t=67 is 3.842301726618878
# Objective value at epoch t=68 is 4.246006063767865
# Objective value at epoch t=69 is 2.098027425525679
# Objective value at epoch t=70 is 3.4407110981563975
# Objective value at epoch t=71 is 2.755594592565667
# Objective value at epoch t=72 is 2.4395573365069003
# Objective value at epoch t=73 is 2.0818946272141594
# Objective value at epoch t=74 is 2.1723575998149807
# Objective value at epoch t=75 is 2.0744386080205395
# Objective value at epoch t=76 is 1.4414042121998984
# Objective value at epoch t=77 is 1.4847212365548261
# Objective value at epoch t=78 is 1.1809860310292581
# Objective value at epoch t=79 is 1.0838043069179626
# Objective value at epoch t=80 is 1.1506731498464868
# Objective value at epoch t=81 is 0.8550348863319593
# Objective value at epoch t=82 is 0.8352682528977704
# Objective value at epoch t=83 is 0.7923033509156656
# Objective value at epoch t=84 is 0.6802485912632137
# Objective value at epoch t=85 is 0.7046665683826548
# Objective value at epoch t=86 is 0.5902437747903957
# Objective value at epoch t=87 is 0.6716726863712734
# Objective value at epoch t=88 is 0.6007908086763687
# Objective value at epoch t=89 is 0.5558904205169029
# Objective value at epoch t=90 is 0.5124776340469211
# Objective value at epoch t=91 is 0.5308583535991301
# Objective value at epoch t=92 is 0.553321230971366
# Objective value at epoch t=93 is 0.5134855661394429
# Objective value at epoch t=94 is 0.502958751313211
# Objective value at epoch t=95 is 0.4869147681250176
# Objective value at epoch t=96 is 0.4916716723908923
# Objective value at epoch t=97 is 0.488293447072161
# Objective value at epoch t=98 is 0.48941366972934935
# Objective value at epoch t=99 is 0.48296181099158214

# %%
print(errors_train8)
print(numpy.array(objvals_mbsgd8)[:,-1])
print(errors_test8)
# Out:
# [0.2546875, 0.253125, 0.2375, 0.215625, 0.215625, 0.215625, 0.215625, 0.2140625, 0.221875]
# [0.68466412 0.62539786 0.48928173 0.46193216 0.46192939 0.46194811
#  0.46214165 0.46398561 0.48012168]
# [0.25, 0.25, 0.28125, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25]

# %%
fig = plt.figure(figsize=(6, 4))

cutoff = 0

stepsizes_log = numpy.log10(stepsizes)

line0, = plt.plot(stepsizes_log, errors_train8, '--b', LineWidth = 2)
line1, = plt.plot(stepsizes_log, errors_test8, '-c', LineWidth = 2)
line2, = plt.plot(stepsizes_log, errors_train64, '--r', LineWidth = 2)
line3, = plt.plot(stepsizes_log, errors_test64, '-m', LineWidth = 2)
plt.xlabel('Log of step sizes', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1, line2, line3], ['MB-SGD8 Train', 'MB-SGD8 Test', 'MB-SGD64 Train', 'MB-SGD64 Test'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('step_sizes.pdf', format='pdf', dpi=1200)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   from ipykernel import kernelapp as app
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   app.launch_new_instance()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later

# %% [markdown]
# According to the graph, the learning rate where the train and test objective values are equal is around 0.0001. It is at this point that the model is not underfit nor overfit.

# %% [markdown]
# # 7. Plot and compare GD, SGD, and MB-SGD

# %% [markdown]
# You are required to compare the following algorithms:
#
# - Gradient descent (GD)
#
# - SGD
#
# - MB-SGD with b=8
#
# - MB-SGD with b=64
#
# Follow the code in Section 4 to plot ```objective function value``` against ```epochs```. There should be four curves in the plot; each curve corresponds to one algorithm.

# %% [markdown]
# Hint: Logistic regression with $\ell_2$-norm regularization is a strongly convex optimization problem. All the algorithms will converge to the same solution. **In the end, the ``objective function value`` of the 4 algorithms will be the same. If not the same, your implementation must be wrong. Do NOT submit wrong code and wrong result!**

# %%
epochs_mbsgd8 = range(len(objvals_mbsgd8[0]))
epochs_mbsgd64 = range(len(objvals_mbsgd64[0]))


fig = plt.figure(figsize=(6, 4))

cutoff = 0

line0, = plt.plot(epochs_gd[cutoff:], objvals_gd[cutoff:], '--b', LineWidth=2)
line1, = plt.plot(epochs_sgd[cutoff:], objvals_sgd[cutoff:], '-r', LineWidth=2)
line2, = plt.plot(epochs_mbsgd8[cutoff:], objvals_mbsgd8[3][cutoff:], '--g', LineWidth = 2)
line3, = plt.plot(epochs_mbsgd64[cutoff:], objvals_mbsgd64[3][cutoff:], '-c', LineWidth = 2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1, line2, line3], ['GD', 'SGD', 'MB-SGD8', 'MB-SGD64'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_all.pdf', format='pdf', dpi=1200)

cutoff = 20

line0, = plt.plot(epochs_gd[cutoff:], objvals_gd[cutoff:], '--b', LineWidth=2)
line1, = plt.plot(epochs_sgd[cutoff:], objvals_sgd[cutoff:], '-r', LineWidth=2)
line2, = plt.plot(epochs_mbsgd8[cutoff:], objvals_mbsgd8[3][cutoff:], '--g', LineWidth = 2)
line3, = plt.plot(epochs_mbsgd64[cutoff:], objvals_mbsgd64[3][cutoff:], '-c', LineWidth = 2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1, line2, line3], ['GD', 'SGD', 'MB-SGD8', 'MB-SGD64'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_all.pdf', format='pdf', dpi=1200)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if __name__ == '__main__':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   from ipykernel import kernelapp as app
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   app.launch_new_instance()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:24: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:27: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:31: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
