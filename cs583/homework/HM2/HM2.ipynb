# %% [markdown]
# # HM2: Numerical Optimization for Logistic Regression.
#
# ### Name: Michael Eng

# %% [markdown]
# ## 0. You will do the following:
#
# 1. Read the lecture note: [click here](https://github.com/wangshusen/DeepLearning/blob/master/LectureNotes/Logistic/paper/logistic.pdf)
#
# 2. Read, complete, and run my code.
#
# 3. **Implement mini-batch SGD** and evaluate the performance.
#
# 4. Convert the .IPYNB file to .HTML file.
#
#     * The HTML file must contain **the code** and **the output after execution**.
#
#     * Missing **the output after execution** will not be graded.
#
# 5. Upload this .HTML file to your Google Drive, Dropbox, or your Github repo.  (If you submit the file to Google Drive or Dropbox, you must make the file "open-access". The delay caused by "deny of access" may result in late penalty.)
#
# 6. Submit the link to this .HTML file to Canvas.
#
#     * Example: https://github.com/wangshusen/CS583-2020S/blob/master/homework/HM2/HM2.html
#
#
# ## Grading criteria:
#
# 1. When computing the ```gradient``` and ```objective function value``` using a batch of samples, use **matrix-vector multiplication** rather than a FOR LOOP of **vector-vector multiplications**.
#
# 2. Plot ```objective function value``` against ```epochs```. In the plot, compare GD, SGD, and MB-SGD (with $b=8$ and $b=64$). The plot must look reasonable.

# %% [markdown]
# # 1. Data processing
#
# - Download the Diabete dataset from https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/diabetes
# - Load the data using sklearn.
# - Preprocess the data.

# %% [markdown]
# ## 1.1. Load the data

# %%
from sklearn import datasets
import numpy

x_sparse, y = datasets.load_svmlight_file('diabetes')
x = x_sparse.todense()

print('Shape of x: ' + str(x.shape))
print('Shape of y: ' + str(y.shape))
# Out:
# Shape of x: (768, 8)
# Shape of y: (768,)

# %% [markdown]
# ## 1.2. Partition to training and test sets

# %%
# partition the data to training and test sets
n = x.shape[0]
n_train = 640
n_test = n - n_train

rand_indices = numpy.random.permutation(n)
train_indices = rand_indices[0:n_train]
test_indices = rand_indices[n_train:n]

x_train = x[train_indices, :]
x_test = x[test_indices, :]
y_train = y[train_indices].reshape(n_train, 1)
y_test = y[test_indices].reshape(n_test, 1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train.shape))
print('Shape of y_test: ' + str(y_test.shape))
# Out:
# Shape of x_train: (640, 8)
# Shape of x_test: (128, 8)
# Shape of y_train: (640, 1)
# Shape of y_test: (128, 1)

# %% [markdown]
# ## 1.3. Feature scaling

# %% [markdown]
# Use the standardization to trainsform both training and test features

# %%
# Standardization
import numpy

# calculate mu and sig using the training set
d = x_train.shape[1]
mu = numpy.mean(x_train, axis=0).reshape(1, d)
sig = numpy.std(x_train, axis=0).reshape(1, d)

# transform the training features
x_train = (x_train - mu) / (sig + 1E-6)

# transform the test features
x_test = (x_test - mu) / (sig + 1E-6)

print('test mean = ')
print(numpy.mean(x_test, axis=0))

print('test std = ')
print(numpy.std(x_test, axis=0))
# Out:
# test mean =
# [[-0.01426002 -0.0214525   0.0142114  -0.01920219 -0.03301505 -0.02590305
#    0.10470225  0.11214563]]
# test std =
# [[0.94688349 0.96788453 0.96314811 0.99725731 0.94316074 0.86209049
#   1.1834352  1.09614732]]

# %% [markdown]
# ## 1.4. Add a dimension of all ones

# %%
n_train, d = x_train.shape
x_train = numpy.concatenate((x_train, numpy.ones((n_train, 1))), axis=1)

n_test, d = x_test.shape
x_test = numpy.concatenate((x_test, numpy.ones((n_test, 1))), axis=1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
# Out:
# Shape of x_train: (640, 9)
# Shape of x_test: (128, 9)

# %% [markdown]
# # 2. Logistic regression model
#
# The objective function is $Q (w; X, y) = \frac{1}{n} \sum_{i=1}^n \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.

# %%
# Calculate the objective function value
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     objective function value (scalar)
def objective(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(-yxw) # n-by-1 matrix
    vec2 = numpy.log(1 + vec1) # n-by-1 matrix
    loss = numpy.mean(vec2) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    return loss + reg

# %%
# initialize w
d = x_train.shape[1]
w = numpy.zeros((d, 1))

# evaluate the objective function value at w
lam = 1E-6
objval0 = objective(w, x_train, y_train, lam)
print('Initial objective function value = ' + str(objval0))
# Out:
# Initial objective function value = 0.6931471805599453

# %% [markdown]
# # 3. Numerical optimization

# %% [markdown]
# ## 3.1. Gradient descent

# %% [markdown]
# The gradient at $w$ is $g = - \frac{1}{n} \sum_{i=1}^n \frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$

# %%
# Calculate the gradient
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     g: g: d-by-1 matrix, full gradient
def gradient(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(yxw) # n-by-1 matrix
    vec2 = numpy.divide(yx, 1+vec1) # n-by-d matrix
    vec3 = -numpy.mean(vec2, axis=0).reshape(d, 1) # d-by-1 matrix
    g = vec3 + lam * w
    return g

# %%
# Gradient descent for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_iter: integer, the maximal iterations
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: d-by-1 matrix, the solution
#     objvals: a record of each iteration's objective value
def grad_descent(x, y, lam, stepsize, max_iter=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_iter) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_iter):
        objval = objective(w, x, y, lam)
        objvals[t] = objval
        print('Objective value at t=' + str(t) + ' is ' + str(objval))
        g = gradient(w, x, y, lam)
        w -= stepsize * g
    
    return w, objvals

# %% [markdown]
# Run gradient descent.

# %%
lam = 1E-6
stepsize = 1.0
w, objvals_gd = grad_descent(x_train, y_train, lam, stepsize)
# Out:
# Objective value at t=0 is 0.6931471805599453
# Objective value at t=1 is 0.585037238763272
# Objective value at t=2 is 0.5418677512636944
# Objective value at t=3 is 0.5188175653602003
# Objective value at t=4 is 0.5044361886968358
# Objective value at t=5 is 0.4946618562860769
# Objective value at t=6 is 0.4876623461162789
# Objective value at t=7 is 0.4824717335614427
# Objective value at t=8 is 0.47852461776919225
# Objective value at t=9 is 0.4754651701813792
# Objective value at t=10 is 0.47305752800114365
# Objective value at t=11 is 0.4711391959768166
# Objective value at t=12 is 0.46959483062078683
# Objective value at t=13 is 0.4683405719381968
# Objective value at t=14 is 0.46731422884952234
# Objective value at t=15 is 0.46646889889866394
# Objective value at t=16 is 0.46576869404753163
# Objective value at t=17 is 0.4651858050206751
# Objective value at t=18 is 0.46469844173768643
# Objective value at t=19 is 0.4642893614705294
# Objective value at t=20 is 0.4639447997170621
# Objective value at t=21 is 0.4636536821867398
# Objective value at t=22 is 0.46340703628133795
# Objective value at t=23 is 0.4631975462741254
# Objective value at t=24 is 0.46301921340961305
# Objective value at t=25 is 0.4628670935685747
# Objective value at t=26 is 0.46273709293543275
# Objective value at t=27 is 0.4626258075003215
# Objective value at t=28 is 0.46253039601477247
# Objective value at t=29 is 0.4624484787113133
# Objective value at t=30 is 0.4623780560327398
# Objective value at t=31 is 0.46231744302406064
# Objective value at t=32 is 0.46226521607391385
# Objective value at t=33 is 0.46222016945909955
# Objective value at t=34 is 0.4621812797199287
# Objective value at t=35 is 0.4621476763275262
# Objective value at t=36 is 0.46211861743417837
# Objective value at t=37 is 0.4620934697508986
# Objective value at t=38 is 0.4620716917919365
# Objective value at t=39 is 0.46205281987808083
# Objective value at t=40 is 0.46203645640970387
# Objective value at t=41 is 0.46202226001432745
# Objective value at t=42 is 0.4620099372478174
# Objective value at t=43 is 0.4619992355875283
# Objective value at t=44 is 0.4619899375031286
# Objective value at t=45 is 0.46198185542898085
# Objective value at t=46 is 0.4619748274927783
# Objective value at t=47 is 0.4619687138801621
# Objective value at t=48 is 0.4619633937354439
# Objective value at t=49 is 0.46195876251524104
# Objective value at t=50 is 0.4619547297255389
# Objective value at t=51 is 0.46195121698398367
# Objective value at t=52 is 0.4619481563585482
# Objective value at t=53 is 0.46194548894145
# Objective value at t=54 is 0.461943163623642
# Objective value at t=55 is 0.4619411360405646
# Objective value at t=56 is 0.4619393676643359
# Objective value at t=57 is 0.4619378250213222
# Objective value at t=58 is 0.4619364790171913
# Objective value at t=59 is 0.461935304354211
# Objective value at t=60 is 0.46193427902780604
# Objective value at t=61 is 0.4619333838912814
# Objective value at t=62 is 0.4619326022792305
# Objective value at t=63 is 0.46193191968151054
# Objective value at t=64 is 0.4619313234608282
# Objective value at t=65 is 0.461930802607966
# Objective value at t=66 is 0.46193034752951967
# Objective value at t=67 is 0.46192994986373864
# Objective value at t=68 is 0.4619296023206734
# Objective value at t=69 is 0.46192929854336084
# Objective value at t=70 is 0.4619290329872275
# Objective value at t=71 is 0.46192880081528004
# Objective value at t=72 is 0.4619285978069821
# Objective value at t=73 is 0.4619284202790007
# Objective value at t=74 is 0.46192826501625567
# Objective value at t=75 is 0.46192812921191184
# Objective value at t=76 is 0.4619280104151389
# Objective value at t=77 is 0.4619279064856222
# Objective value at t=78 is 0.4619278155539373
# Objective value at t=79 is 0.46192773598702874
# Objective value at t=80 is 0.4619276663581238
# Objective value at t=81 is 0.46192760542050804
# Objective value at t=82 is 0.46192755208466074
# Objective value at t=83 is 0.46192750539831545
# Objective value at t=84 is 0.46192746452906863
# Objective value at t=85 is 0.4619274287492071
# Objective value at t=86 is 0.46192739742246985
# Objective value at t=87 is 0.46192736999249295
# Objective value at t=88 is 0.4619273459727261
# Objective value at t=89 is 0.46192732493762784
# Objective value at t=90 is 0.46192730651497776
# Objective value at t=91 is 0.4619272903791649
# Objective value at t=92 is 0.4619272762453227
# Objective value at t=93 is 0.46192726386420857
# Objective value at t=94 is 0.4619272530177289
# Objective value at t=95 is 0.46192724351502956
# Objective value at t=96 is 0.4619272351890793
# Objective value at t=97 is 0.4619272278936838
# Objective value at t=98 is 0.4619272215008761
# Objective value at t=99 is 0.46192721589863495

# %% [markdown]
# ## 3.2. Stochastic gradient descent (SGD)
#
# Define $Q_i (w) = \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.
#
# The stochastic gradient at $w$ is $g_i = \frac{\partial Q_i }{ \partial w} = -\frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_i and the gradient of Q_i
# Inputs:
#     w: d-by-1 matrix
#     xi: 1-by-d matrix
#     yi: scalar
#     lam: scalar, the regularization parameter
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def stochastic_objective_gradient(w, xi, yi, lam):
    d = xi.shape[0]
    yx = yi * xi # 1-by-d matrix
    yxw = float(numpy.dot(yx, w)) # scalar
    
    # calculate objective function Q_i
    loss = numpy.log(1 + numpy.exp(-yxw)) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    obj = loss + reg
    
    # calculate stochastic gradient
    g_loss = -yx.T / (1 + numpy.exp(yxw)) # d-by-1 matrix
    g = g_loss + lam * w # d-by-1 matrix
    
    return obj, g

# %%
# SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def sgd(x, y, lam, stepsize, max_epoch=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_epoch) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_epoch):
        # randomly shuffle the samples
        rand_indices = numpy.random.permutation(n)
        x_rand = x[rand_indices, :]
        y_rand = y[rand_indices, :]
        
        objval = 0 # accumulate the objective values
        for i in range(n):
            xi = x_rand[i, :] # 1-by-d matrix
            yi = float(y_rand[i, :]) # scalar
            obj, g = stochastic_objective_gradient(w, xi, yi, lam)
            objval += obj
            w -= stepsize * g
        
        stepsize *= 0.9 # decrease step size
        objval /= n
        objvals[t] = objval
        print('Objective value at epoch t=' + str(t) + ' is ' + str(objval))
    
    return w, objvals

# %% [markdown]
# Run SGD.

# %%
lam = 1E-6
stepsize = 0.1
w, objvals_sgd = sgd(x_train, y_train, lam, stepsize)
# Out:
# Objective value at epoch t=0 is 0.5297505540310775
# Objective value at epoch t=1 is 0.5067633268048698
# Objective value at epoch t=2 is 0.5013113534657341
# Objective value at epoch t=3 is 0.5014539343699199
# Objective value at epoch t=4 is 0.4930303287455546
# Objective value at epoch t=5 is 0.49275783630729003
# Objective value at epoch t=6 is 0.4820457703080809
# Objective value at epoch t=7 is 0.49186810067311315
# Objective value at epoch t=8 is 0.48016620043864205
# Objective value at epoch t=9 is 0.4790141454607807
# Objective value at epoch t=10 is 0.47902081592160856
# Objective value at epoch t=11 is 0.48082132040090836
# Objective value at epoch t=12 is 0.4757383944592851
# Objective value at epoch t=13 is 0.47795193792634566
# Objective value at epoch t=14 is 0.47639197004544487
# Objective value at epoch t=15 is 0.472696169174473
# Objective value at epoch t=16 is 0.47341266982661906
# Objective value at epoch t=17 is 0.471284799063484
# Objective value at epoch t=18 is 0.4703926415707874
# Objective value at epoch t=19 is 0.4700440010995056
# Objective value at epoch t=20 is 0.4691954760748769
# Objective value at epoch t=21 is 0.4690394380480205
# Objective value at epoch t=22 is 0.4682783123494515
# Objective value at epoch t=23 is 0.4677368124300078
# Objective value at epoch t=24 is 0.4671539774903207
# Objective value at epoch t=25 is 0.46632577388348195
# Objective value at epoch t=26 is 0.46657995217822534
# Objective value at epoch t=27 is 0.46577032009126074
# Objective value at epoch t=28 is 0.4655089980933643
# Objective value at epoch t=29 is 0.46530377376783427
# Objective value at epoch t=30 is 0.4647623036939912
# Objective value at epoch t=31 is 0.46463254062620224
# Objective value at epoch t=32 is 0.4642188692670601
# Objective value at epoch t=33 is 0.4639439892235866
# Objective value at epoch t=34 is 0.4638836284144487
# Objective value at epoch t=35 is 0.46376344251223334
# Objective value at epoch t=36 is 0.4635446026828123
# Objective value at epoch t=37 is 0.4633786126491957
# Objective value at epoch t=38 is 0.4631986078561643
# Objective value at epoch t=39 is 0.463119105421024
# Objective value at epoch t=40 is 0.46300243201145286
# Objective value at epoch t=41 is 0.4628896591739327
# Objective value at epoch t=42 is 0.46278933932203625
# Objective value at epoch t=43 is 0.46270108477613825
# Objective value at epoch t=44 is 0.46263686363863527
# Objective value at epoch t=45 is 0.46256800548564103
# Objective value at epoch t=46 is 0.4625015296027531
# Objective value at epoch t=47 is 0.4624403045707325
# Objective value at epoch t=48 is 0.46238718448830873
# Objective value at epoch t=49 is 0.4623476688934317
# Objective value at epoch t=50 is 0.4623045872177191
# Objective value at epoch t=51 is 0.46226726591395584
# Objective value at epoch t=52 is 0.4622331847360804
# Objective value at epoch t=53 is 0.4622020794289313
# Objective value at epoch t=54 is 0.46217623425534854
# Objective value at epoch t=55 is 0.4621508393202367
# Objective value at epoch t=56 is 0.46212871769089114
# Objective value at epoch t=57 is 0.4621078444554797
# Objective value at epoch t=58 is 0.46209018553315434
# Objective value at epoch t=59 is 0.46207443838500045
# Objective value at epoch t=60 is 0.46205914091287414
# Objective value at epoch t=61 is 0.46204634429495356
# Objective value at epoch t=62 is 0.4620344771360806
# Objective value at epoch t=63 is 0.46202381800487985
# Objective value at epoch t=64 is 0.46201418701991787
# Objective value at epoch t=65 is 0.4620055240170332
# Objective value at epoch t=66 is 0.46199769725420675
# Objective value at epoch t=67 is 0.4619905264881076
# Objective value at epoch t=68 is 0.4619842984986331
# Objective value at epoch t=69 is 0.4619786426186738
# Objective value at epoch t=70 is 0.46197351653062596
# Objective value at epoch t=71 is 0.46196881029305265
# Objective value at epoch t=72 is 0.46196474338060184
# Objective value at epoch t=73 is 0.46196099685492653
# Objective value at epoch t=74 is 0.4619576004903199
# Objective value at epoch t=75 is 0.4619545901727705
# Objective value at epoch t=76 is 0.46195185606735495
# Objective value at epoch t=77 is 0.46194941023256186
# Objective value at epoch t=78 is 0.4619471990837597
# Objective value at epoch t=79 is 0.4619452072220233
# Objective value at epoch t=80 is 0.46194342294321344
# Objective value at epoch t=81 is 0.46194180935554624
# Objective value at epoch t=82 is 0.4619403590019296
# Objective value at epoch t=83 is 0.4619390541878463
# Objective value at epoch t=84 is 0.4619378784763817
# Objective value at epoch t=85 is 0.4619368206295735
# Objective value at epoch t=86 is 0.4619358689908862
# Objective value at epoch t=87 is 0.4619350117255575
# Objective value at epoch t=88 is 0.4619342413646138
# Objective value at epoch t=89 is 0.461933547135144
# Objective value at epoch t=90 is 0.46193292284225923
# Objective value at epoch t=91 is 0.4619323601870544
# Objective value at epoch t=92 is 0.46193185397955727
# Objective value at epoch t=93 is 0.4619313992281602
# Objective value at epoch t=94 is 0.4619309895090531
# Objective value at epoch t=95 is 0.4619306206681708
# Objective value at epoch t=96 is 0.46193028878929115
# Objective value at epoch t=97 is 0.4619299899731807
# Objective value at epoch t=98 is 0.461929721030723
# Objective value at epoch t=99 is 0.46192947894672365

# %% [markdown]
# # 4. Compare GD with SGD
#
# Plot objective function values against epochs.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(6, 4))

epochs_gd = range(len(objvals_gd))
epochs_sgd = range(len(objvals_sgd))

line0, = plt.plot(epochs_gd, objvals_gd, '--b', LineWidth=4)
line1, = plt.plot(epochs_sgd, objvals_sgd, '-r', LineWidth=2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1], ['GD', 'SGD'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_gd_sgd.pdf', format='pdf', dpi=1200)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if __name__ == '__main__':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later

# %% [markdown]
# # 5. Prediction

# %%
# Predict class label
# Inputs:
#     w: d-by-1 matrix
#     X: m-by-d matrix
# Return:
#     f: m-by-1 matrix, the predictions
def predict(w, X):
    xw = numpy.dot(X, w)
    f = numpy.sign(xw)
    return f

# %%
# evaluate training error
f_train = predict(w, x_train)
diff = numpy.abs(f_train - y_train) / 2
error_train = numpy.mean(diff)
print('Training classification error is ' + str(error_train))
# Out:
# Training classification error is 0.215625

# %%
# evaluate test error
f_test = predict(w, x_test)
diff = numpy.abs(f_test - y_test) / 2
error_test = numpy.mean(diff)
print('Test classification error is ' + str(error_test))
# Out:
# Test classification error is 0.25

# %% [markdown]
# # 6. Mini-batch SGD (fill the code)

# %% [markdown]
# ## 6.1. Compute the objective $Q_I$ and its gradient using a batch of samples
#
# Define $Q_I (w) = \frac{1}{b} \sum_{i \in I} \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $, where $I$ is a set containing $b$ indices randomly drawn from $\{ 1, \cdots , n \}$ without replacement.
#
# The stochastic gradient at $w$ is $g_I = \frac{\partial Q_I }{ \partial w} = \frac{1}{b} \sum_{i \in I} \frac{- y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_I and the gradient of Q_I
# Inputs:
#     w: d-by-1 matrix
#     xi: b-by-d matrix
#     yi: b-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def mb_stochastic_objective_gradient(w, xi, yi, lam, b):
    
    d = xi.shape[0]
    
    yx = numpy.multiply(yi, xi) # b-by-d matrix
    yxw = numpy.dot(yx, w) # b-by-1 matrix
    
    # calculate objective function Q_i
    loss = 1 / b * numpy.sum(numpy.log(1 + numpy.exp(-yxw))) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar

    obj = loss + reg 

    # calculate stochastic gradient
    g_loss = numpy.sum(-yx.T / (1 + numpy.exp(yxw)).T, axis=1) # d-by-1 matrix
    g = g_loss + lam * w # d-by-1 matrix
    
    return obj, g

# %% [markdown]
# ## 6.2. Implement mini-batch SGD
#
# Hints:
# 1. In every epoch, randomly permute the $n$ samples (just like SGD).
# 2. Each epoch has $\frac{n}{b}$ iterations. In every iteration, use $b$ samples, and compute the gradient and objective using the ``mb_stochastic_objective_gradient`` function. In the next iteration, use the next $b$ samples, and so on.

# %%
# Mini-Batch SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def mb_sgd(x, y, lam, b, stepsize, max_epoch=100, w=None):
    
    n, d = x.shape
    objvals = numpy.zeros(max_epoch) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
        
    for t in range(max_epoch):
        indecies = numpy.arange(n)
        numpy.random.shuffle(indecies)
        objval = 0 # accumulate the objective values

        batches = int(n / b)
        for j in range(batches):
            first_index = j * b
            last_index = (j + 1) * b
            xb = x[indecies[first_index:last_index],:]
            yb = y[indecies[first_index:last_index],:]
            
            obj, g = mb_stochastic_objective_gradient(w, xb, yb, lam, b)
            objval += obj
            w -= stepsize * g
        
        stepsize *= 0.9 # decrease step size
        objval /= batches 
        objvals[t] = objval
        print('Objective value at epoch t=' + str(t) + ' is ' + str(objval))
    
    return w, objvals

# %% [markdown]
# ## 6.3. Run MB-SGD

# %%
# MB-SGD with batch size b=8
lam = 1E-6 # do not change
b = 8 # do not change
stepsize = 0.1 # you must tune this parameter

stepsizes = [0.00001, 0.0001, 0.001, 0.01, 0.1, 0.8, 1.0, 10.0, 100.0, 1000.0]
errors_train8 = []
errors_test8 = []
objvals_mbsgd8 = []

for stepsize in stepsizes:
    w_tmp, objval_tmp = mb_sgd(x_train, y_train, lam, b, stepsize)
    f_train = predict(w_tmp, x_train)
    diff = numpy.abs(f_train - y_train) / 2
    error_train = numpy.mean(diff)
    f_test = predict(w_tmp, x_test)
    diff = numpy.abs(f_test - y_test) / 2
    error_test = numpy.mean(diff)
    
    errors_train8.append(error_train)
    errors_test8.append(error_test)
    objvals_mbsgd8.append(objval_tmp)
# Out:
# Objective value at epoch t=0 is 0.6927291065498146
# Objective value at epoch t=1 is 0.691902123794435
# Objective value at epoch t=2 is 0.6911636242931234
# Objective value at epoch t=3 is 0.6905025596920015
# Objective value at epoch t=4 is 0.6899074995189093
# Objective value at epoch t=5 is 0.6893755949328375
# Objective value at epoch t=6 is 0.6888985920676732
# Objective value at epoch t=7 is 0.6884687075016158
# Objective value at epoch t=8 is 0.6880846589348328
# Objective value at epoch t=9 is 0.6877390142242263
# Objective value at epoch t=10 is 0.6874285641064091
# Objective value at epoch t=11 is 0.6871501630843515
# Objective value at epoch t=12 is 0.6868997638899217
# Objective value at epoch t=13 is 0.6866746141543303
# Objective value at epoch t=14 is 0.6864726597544581
# Objective value at epoch t=15 is 0.6862903559249173
# Objective value at epoch t=16 is 0.6861271388452047
# Objective value at epoch t=17 is 0.6859802934351665
# Objective value at epoch t=18 is 0.6858479944037965
# Objective value at epoch t=19 is 0.6857293105541722
# Objective value at epoch t=20 is 0.6856223517294515
# Objective value at epoch t=21 is 0.6855262066325862
# Objective value at epoch t=22 is 0.6854398147794124
# Objective value at epoch t=23 is 0.6853619815225237
# Objective value at epoch t=24 is 0.6852921088499383
# Objective value at epoch t=25 is 0.6852291021421693
# Objective value at epoch t=26 is 0.6851725112050461
# Objective value at epoch t=27 is 0.6851216272403902
# Objective value at epoch t=28 is 0.6850757629845716
# Objective value at epoch t=29 is 0.6850345174748965
# Objective value at epoch t=30 is 0.6849974234113099
# Objective value at epoch t=31 is 0.6849640319273993
# Objective value at epoch t=32 is 0.684933980339973
# Objective value at epoch t=33 is 0.6849069708983144
# Objective value at epoch t=34 is 0.6848826233488372
# Objective value at epoch t=35 is 0.6848607801182937
# Objective value at epoch t=36 is 0.684841038191452
# Objective value at epoch t=37 is 0.6848233302927201
# Objective value at epoch t=38 is 0.6848073643608779
# Objective value at epoch t=39 is 0.6847930125721354
# Objective value at epoch t=40 is 0.6847801104078051
# Objective value at epoch t=41 is 0.6847684692765881
# Objective value at epoch t=42 is 0.6847580169612637
# Objective value at epoch t=43 is 0.6847485989779776
# Objective value at epoch t=44 is 0.6847401249330839
# Objective value at epoch t=45 is 0.6847325081355329
# Objective value at epoch t=46 is 0.6847256471706235
# Objective value at epoch t=47 is 0.6847194670800817
# Objective value at epoch t=48 is 0.6847139069005286
# Objective value at epoch t=49 is 0.6847089065192076
# Objective value at epoch t=50 is 0.6847044048576918
# Objective value at epoch t=51 is 0.6847003442142079
# Objective value at epoch t=52 is 0.6846967040750713
# Objective value at epoch t=53 is 0.6846934241791669
# Objective value at epoch t=54 is 0.6846904694264861
# Objective value at epoch t=55 is 0.6846878088384684
# Objective value at epoch t=56 is 0.6846854205996101
# Objective value at epoch t=57 is 0.6846832659423903
# Objective value at epoch t=58 is 0.6846813327341543
# Objective value at epoch t=59 is 0.6846795854899762
# Objective value at epoch t=60 is 0.6846780146914734
# Objective value at epoch t=61 is 0.6846766015607579
# Objective value at epoch t=62 is 0.6846753312600569
# Objective value at epoch t=63 is 0.6846741867077413
# Objective value at epoch t=64 is 0.684673158586744
# Objective value at epoch t=65 is 0.6846722303240764
# Objective value at epoch t=66 is 0.6846713973352013
# Objective value at epoch t=67 is 0.6846706459621094
# Objective value at epoch t=68 is 0.6846699699154286
# Objective value at epoch t=69 is 0.6846693631076768
# Objective value at epoch t=70 is 0.6846688156042935
# Objective value at epoch t=71 is 0.6846683226852832
# Objective value at epoch t=72 is 0.6846678805990224
# Objective value at epoch t=73 is 0.6846674812836683
# Objective value at epoch t=74 is 0.6846671221220166
# Objective value at epoch t=75 is 0.6846667986557674
# Objective value at epoch t=76 is 0.6846665078625925
# Objective value at epoch t=77 is 0.684666246560857
# Objective value at epoch t=78 is 0.6846660106537696
# Objective value at epoch t=79 is 0.6846657984823394
# Objective value at epoch t=80 is 0.6846656079326541
# Objective value at epoch t=81 is 0.6846654361214535
# Objective value at epoch t=82 is 0.6846652820409007
# Objective value at epoch t=83 is 0.684665142709566
# Objective value at epoch t=84 is 0.684665017338943
# Objective value at epoch t=85 is 0.6846649049124186
# Objective value at epoch t=86 is 0.6846648033899495
# Objective value at epoch t=87 is 0.6846647120744979
# Objective value at epoch t=88 is 0.6846646300593753
# Objective value at epoch t=89 is 0.6846645560614935
# Objective value at epoch t=90 is 0.6846644895893002
# Objective value at epoch t=91 is 0.6846644297431379
# Objective value at epoch t=92 is 0.6846643758492099
# Objective value at epoch t=93 is 0.6846643273419996
# Objective value at epoch t=94 is 0.6846642837176138
# Objective value at epoch t=95 is 0.6846642444462063
# Objective value at epoch t=96 is 0.6846642090570065
# Objective value at epoch t=97 is 0.6846641772157269
# Objective value at epoch t=98 is 0.6846641486028362
# Objective value at epoch t=99 is 0.6846641228182954
# Objective value at epoch t=0 is 0.6890205513990035
# Objective value at epoch t=1 is 0.6811432288175785
# Objective value at epoch t=2 is 0.6743725830006448
# Objective value at epoch t=3 is 0.6685559682680693
# Objective value at epoch t=4 is 0.6635185245914521
# Objective value at epoch t=5 is 0.6591369751348019
# Objective value at epoch t=6 is 0.6553003961291423
# Objective value at epoch t=7 is 0.651957109363188
# Objective value at epoch t=8 is 0.6490182351389902
# Objective value at epoch t=9 is 0.6464293592544098
# Objective value at epoch t=10 is 0.644145872066788
# Objective value at epoch t=11 is 0.6421241809893055
# Objective value at epoch t=12 is 0.640339924005726
# Objective value at epoch t=13 is 0.6387536687086033
# Objective value at epoch t=14 is 0.6373435088554306
# Objective value at epoch t=15 is 0.6360902165041071
# Objective value at epoch t=16 is 0.6349724415410238
# Objective value at epoch t=17 is 0.633976798449334
# Objective value at epoch t=18 is 0.6330879517932776
# Objective value at epoch t=19 is 0.6322941890634681
# Objective value at epoch t=20 is 0.6315844630467282
# Objective value at epoch t=21 is 0.6309490238206992
# Objective value at epoch t=22 is 0.6303809028143705
# Objective value at epoch t=23 is 0.6298716410750616
# Objective value at epoch t=24 is 0.6294148533512621
# Objective value at epoch t=25 is 0.6290061015540886
# Objective value at epoch t=26 is 0.628640350815147
# Objective value at epoch t=27 is 0.6283105079954807
# Objective value at epoch t=28 is 0.628015569998795
# Objective value at epoch t=29 is 0.6277503831722236
# Objective value at epoch t=30 is 0.6275126882891997
# Objective value at epoch t=31 is 0.6272989801253778
# Objective value at epoch t=32 is 0.6271066467604353
# Objective value at epoch t=33 is 0.6269341960405546
# Objective value at epoch t=34 is 0.6267792030687637
# Objective value at epoch t=35 is 0.6266397132614058
# Objective value at epoch t=36 is 0.6265144524045579
# Objective value at epoch t=37 is 0.6264017710868719
# Objective value at epoch t=38 is 0.6263004985387367
# Objective value at epoch t=39 is 0.6262096975852856
# Objective value at epoch t=40 is 0.6261275383131762
# Objective value at epoch t=41 is 0.6260538551309967
# Objective value at epoch t=42 is 0.6259877625090905
# Objective value at epoch t=43 is 0.6259281204980036
# Objective value at epoch t=44 is 0.6258745294412698
# Objective value at epoch t=45 is 0.6258263435030287
# Objective value at epoch t=46 is 0.6257829581639377
# Objective value at epoch t=47 is 0.625743990409242
# Objective value at epoch t=48 is 0.6257088452714997
# Objective value at epoch t=49 is 0.6256773034095742
# Objective value at epoch t=50 is 0.6256488904803825
# Objective value at epoch t=51 is 0.625623297718821
# Objective value at epoch t=52 is 0.6256003387400916
# Objective value at epoch t=53 is 0.6255795965904992
# Objective value at epoch t=54 is 0.6255609754804115
# Objective value at epoch t=55 is 0.6255442152812795
# Objective value at epoch t=56 is 0.6255291390827855
# Objective value at epoch t=57 is 0.6255155897329974
# Objective value at epoch t=58 is 0.6255033652425689
# Objective value at epoch t=59 is 0.6254923888824562
# Objective value at epoch t=60 is 0.6254824893059878
# Objective value at epoch t=61 is 0.625473578373329
# Objective value at epoch t=62 is 0.6254655943482668
# Objective value at epoch t=63 is 0.625458360534852
# Objective value at epoch t=64 is 0.6254518677717044
# Objective value at epoch t=65 is 0.625446028865501
# Objective value at epoch t=66 is 0.6254407734704327
# Objective value at epoch t=67 is 0.6254360447228551
# Objective value at epoch t=68 is 0.6254317965354946
# Objective value at epoch t=69 is 0.6254279674594087
# Objective value at epoch t=70 is 0.625424519561179
# Objective value at epoch t=71 is 0.6254214149695223
# Objective value at epoch t=72 is 0.6254186228343126
# Objective value at epoch t=73 is 0.6254161165938553
# Objective value at epoch t=74 is 0.6254138492321454
# Objective value at epoch t=75 is 0.6254118169345254
# Objective value at epoch t=76 is 0.6254099849325387
# Objective value at epoch t=77 is 0.6254083391486878
# Objective value at epoch t=78 is 0.625406855065433
# Objective value at epoch t=79 is 0.6254055204234417
# Objective value at epoch t=80 is 0.6254043181892283
# Objective value at epoch t=81 is 0.6254032371600087
# Objective value at epoch t=82 is 0.6254022643958017
# Objective value at epoch t=83 is 0.6254013891227286
# Objective value at epoch t=84 is 0.625400599671039
# Objective value at epoch t=85 is 0.6253998900150248
# Objective value at epoch t=86 is 0.6253992507733582
# Objective value at epoch t=87 is 0.6253986769550426
# Objective value at epoch t=88 is 0.625398158501653
# Objective value at epoch t=89 is 0.6253976934763841
# Objective value at epoch t=90 is 0.625397275922415
# Objective value at epoch t=91 is 0.625396898673345
# Objective value at epoch t=92 is 0.625396559761997
# Objective value at epoch t=93 is 0.6253962535579171
# Objective value at epoch t=94 is 0.6253959785433924
# Objective value at epoch t=95 is 0.6253957314846854
# Objective value at epoch t=96 is 0.6253955082668214
# Objective value at epoch t=97 is 0.6253953080396675
# Objective value at epoch t=98 is 0.6253951277007392
# Objective value at epoch t=99 is 0.625394965275283
# Objective value at epoch t=0 is 0.6573860660036455
# Objective value at epoch t=1 is 0.6056305709690925
# Objective value at epoch t=2 is 0.5752444843517399
# Objective value at epoch t=3 is 0.5556900734060578
# Objective value at epoch t=4 is 0.5421742108051538
# Objective value at epoch t=5 is 0.5323493951335763
# Objective value at epoch t=6 is 0.5249924185484529
# Objective value at epoch t=7 is 0.5192114603797168
# Objective value at epoch t=8 is 0.5146419122578336
# Objective value at epoch t=9 is 0.5109449832721069
# Objective value at epoch t=10 is 0.5079315575598022
# Objective value at epoch t=11 is 0.5054470334235475
# Objective value at epoch t=12 is 0.5033398540680343
# Objective value at epoch t=13 is 0.5015656615464122
# Objective value at epoch t=14 is 0.5000608035414962
# Objective value at epoch t=15 is 0.49877292440930043
# Objective value at epoch t=16 is 0.49764195726754884
# Objective value at epoch t=17 is 0.4966622662047634
# Objective value at epoch t=18 is 0.49582820860668964
# Objective value at epoch t=19 is 0.4950923424894203
# Objective value at epoch t=20 is 0.49444763574046935
# Objective value at epoch t=21 is 0.4938782295817181
# Objective value at epoch t=22 is 0.49338117023981065
# Objective value at epoch t=23 is 0.49294392160619793
# Objective value at epoch t=24 is 0.4925424005958344
# Objective value at epoch t=25 is 0.4921958638985545
# Objective value at epoch t=26 is 0.49189143522368656
# Objective value at epoch t=27 is 0.4916167362836138
# Objective value at epoch t=28 is 0.491376535057669
# Objective value at epoch t=29 is 0.49115290151964786
# Objective value at epoch t=30 is 0.4909646636969073
# Objective value at epoch t=31 is 0.4907894022063387
# Objective value at epoch t=32 is 0.4906365145464034
# Objective value at epoch t=33 is 0.49049695887743694
# Objective value at epoch t=34 is 0.49037350239677824
# Objective value at epoch t=35 is 0.49026279889355545
# Objective value at epoch t=36 is 0.4901658109014749
# Objective value at epoch t=37 is 0.4900746541096179
# Objective value at epoch t=38 is 0.489995912309327
# Objective value at epoch t=39 is 0.4899252531219308
# Objective value at epoch t=40 is 0.48985972671537387
# Objective value at epoch t=41 is 0.48980361579358433
# Objective value at epoch t=42 is 0.48975113874471693
# Objective value at epoch t=43 is 0.4897045001337804
# Objective value at epoch t=44 is 0.48966282473085015
# Objective value at epoch t=45 is 0.48962582165940693
# Objective value at epoch t=46 is 0.48959250118189923
# Objective value at epoch t=47 is 0.4895616489194204
# Objective value at epoch t=48 is 0.4895343141854062
# Objective value at epoch t=49 is 0.48951011209577866
# Objective value at epoch t=50 is 0.48948826439748583
# Objective value at epoch t=51 is 0.48946865353488
# Objective value at epoch t=52 is 0.4894508894810687
# Objective value at epoch t=53 is 0.48943476699456906
# Objective value at epoch t=54 is 0.48942029732741477
# Objective value at epoch t=55 is 0.48940735125709517
# Objective value at epoch t=56 is 0.4893958186773511
# Objective value at epoch t=57 is 0.48938542625919607
# Objective value at epoch t=58 is 0.4893760393956311
# Objective value at epoch t=59 is 0.489367658188404
# Objective value at epoch t=60 is 0.4893598245017725
# Objective value at epoch t=61 is 0.4893528526312559
# Objective value at epoch t=62 is 0.48934692597374596
# Objective value at epoch t=63 is 0.489341318751029
# Objective value at epoch t=64 is 0.4893362174086338
# Objective value at epoch t=65 is 0.48933188224046775
# Objective value at epoch t=66 is 0.48932780051873676
# Objective value at epoch t=67 is 0.4893241805016377
# Objective value at epoch t=68 is 0.48932088301302057
# Objective value at epoch t=69 is 0.4893179436484861
# Objective value at epoch t=70 is 0.489315344492857
# Objective value at epoch t=71 is 0.4893128947678945
# Objective value at epoch t=72 is 0.4893107538144833
# Objective value at epoch t=73 is 0.48930881585230335
# Objective value at epoch t=74 is 0.4893070700995216
# Objective value at epoch t=75 is 0.4893055132906706
# Objective value at epoch t=76 is 0.48930410724404644
# Objective value at epoch t=77 is 0.489302873244986
# Objective value at epoch t=78 is 0.48930169957559677
# Objective value at epoch t=79 is 0.48930069844084195
# Objective value at epoch t=80 is 0.4892997706602918
# Objective value at epoch t=81 is 0.48929893544644365
# Objective value at epoch t=82 is 0.48929819420409404
# Objective value at epoch t=83 is 0.4892975099645394
# Objective value at epoch t=84 is 0.4892969007319367
# Objective value at epoch t=85 is 0.4892963722468934
# Objective value at epoch t=86 is 0.4892958741515704
# Objective value at epoch t=87 is 0.48929542522812686
# Objective value at epoch t=88 is 0.48929503526844165
# Objective value at epoch t=89 is 0.48929467317466563
# Objective value at epoch t=90 is 0.489294350803572
# Objective value at epoch t=91 is 0.4892940595732812
# Objective value at epoch t=92 is 0.4892938039699028
# Objective value at epoch t=93 is 0.4892935671144355
# Objective value at epoch t=94 is 0.4892933496797195
# Objective value at epoch t=95 is 0.48929316314460947
# Objective value at epoch t=96 is 0.48929299291443085
# Objective value at epoch t=97 is 0.48929283967924186
# Objective value at epoch t=98 is 0.4892927005627533
# Objective value at epoch t=99 is 0.4892925779709909
# Objective value at epoch t=0 is 0.5490820517290026
# Objective value at epoch t=1 is 0.484621234759887
# Objective value at epoch t=2 is 0.4732885668028354
# Objective value at epoch t=3 is 0.4691847492547403
# Objective value at epoch t=4 is 0.4681106210756508
# Objective value at epoch t=5 is 0.4667895197771477
# Objective value at epoch t=6 is 0.46595844356990745
# Objective value at epoch t=7 is 0.4655729317754327
# Objective value at epoch t=8 is 0.4651209136538587
# Objective value at epoch t=9 is 0.4648908942764086
# Objective value at epoch t=10 is 0.46437628588309343
# Objective value at epoch t=11 is 0.46402667176035095
# Objective value at epoch t=12 is 0.4641097795480401
# Objective value at epoch t=13 is 0.4636721964161552
# Objective value at epoch t=14 is 0.4635681025104207
# Objective value at epoch t=15 is 0.4631598620814724
# Objective value at epoch t=16 is 0.4632556858199327
# Objective value at epoch t=17 is 0.46318003386447926
# Objective value at epoch t=18 is 0.46307115843629754
# Objective value at epoch t=19 is 0.4629291630985578
# Objective value at epoch t=20 is 0.46280450036207854
# Objective value at epoch t=21 is 0.4627122786179039
# Objective value at epoch t=22 is 0.46263691283008557
# Objective value at epoch t=23 is 0.462611839106197
# Objective value at epoch t=24 is 0.46250602491940923
# Objective value at epoch t=25 is 0.4624445981566446
# Objective value at epoch t=26 is 0.4623774397058673
# Objective value at epoch t=27 is 0.46234786935515465
# Objective value at epoch t=28 is 0.46229190520091273
# Objective value at epoch t=29 is 0.4622871030057092
# Objective value at epoch t=30 is 0.4622317805672055
# Objective value at epoch t=31 is 0.46221818517306296
# Objective value at epoch t=32 is 0.46219481842115745
# Objective value at epoch t=33 is 0.4621448283851858
# Objective value at epoch t=34 is 0.4621624271513699
# Objective value at epoch t=35 is 0.462134737330335
# Objective value at epoch t=36 is 0.462100996157393
# Objective value at epoch t=37 is 0.46207748198055604
# Objective value at epoch t=38 is 0.46206950249266676
# Objective value at epoch t=39 is 0.4620605367804356
# Objective value at epoch t=40 is 0.4620320131506513
# Objective value at epoch t=41 is 0.4620302235947329
# Objective value at epoch t=42 is 0.46202625615670445
# Objective value at epoch t=43 is 0.4620236330924423
# Objective value at epoch t=44 is 0.46200677315005434
# Objective value at epoch t=45 is 0.4620029794369578
# Objective value at epoch t=46 is 0.4619934164640774
# Objective value at epoch t=47 is 0.46198407267080877
# Objective value at epoch t=48 is 0.4619799758212911
# Objective value at epoch t=49 is 0.4619753251362895
# Objective value at epoch t=50 is 0.4619736338333006
# Objective value at epoch t=51 is 0.46196965104949655
# Objective value at epoch t=52 is 0.46196332763189807
# Objective value at epoch t=53 is 0.4619638457810667
# Objective value at epoch t=54 is 0.4619595427344966
# Objective value at epoch t=55 is 0.4619587539318101
# Objective value at epoch t=56 is 0.46195366816691824
# Objective value at epoch t=57 is 0.46195180923913287
# Objective value at epoch t=58 is 0.46195223808278146
# Objective value at epoch t=59 is 0.46194991086913717
# Objective value at epoch t=60 is 0.4619476005496622
# Objective value at epoch t=61 is 0.46194660707251545
# Objective value at epoch t=62 is 0.46194412689009906
# Objective value at epoch t=63 is 0.46194496915756034
# Objective value at epoch t=64 is 0.46194379465936447
# Objective value at epoch t=65 is 0.46194199350227183
# Objective value at epoch t=66 is 0.4619419551450494
# Objective value at epoch t=67 is 0.4619413547513931
# Objective value at epoch t=68 is 0.46193951740354267
# Objective value at epoch t=69 is 0.46193936162194815
# Objective value at epoch t=70 is 0.4619387736395611
# Objective value at epoch t=71 is 0.4619384851831955
# Objective value at epoch t=72 is 0.4619382502674069
# Objective value at epoch t=73 is 0.4619373704002414
# Objective value at epoch t=74 is 0.4619371841470139
# Objective value at epoch t=75 is 0.4619371107776894
# Objective value at epoch t=76 is 0.46193691642425183
# Objective value at epoch t=77 is 0.46193670960846306
# Objective value at epoch t=78 is 0.4619364691029209
# Objective value at epoch t=79 is 0.4619361579700064
# Objective value at epoch t=80 is 0.46193593275368816
# Objective value at epoch t=81 is 0.4619356218940066
# Objective value at epoch t=82 is 0.4619357388679946
# Objective value at epoch t=83 is 0.4619355330718743
# Objective value at epoch t=84 is 0.46193541668949506
# Objective value at epoch t=85 is 0.4619353149157863
# Objective value at epoch t=86 is 0.46193516839957266
# Objective value at epoch t=87 is 0.461935117848226
# Objective value at epoch t=88 is 0.4619350968280783
# Objective value at epoch t=89 is 0.4619349777737584
# Objective value at epoch t=90 is 0.46193495755792613
# Objective value at epoch t=91 is 0.4619348850452246
# Objective value at epoch t=92 is 0.4619348422565226
# Objective value at epoch t=93 is 0.4619347881091279
# Objective value at epoch t=94 is 0.46193478640815516
# Objective value at epoch t=95 is 0.4619347379787909
# Objective value at epoch t=96 is 0.4619346938732827
# Objective value at epoch t=97 is 0.46193466456503945
# Objective value at epoch t=98 is 0.46193464199817613
# Objective value at epoch t=99 is 0.46193459884577404
# Objective value at epoch t=0 is 0.5265240568922114
# Objective value at epoch t=1 is 0.5138100592262359
# Objective value at epoch t=2 is 0.5066851269370256
# Objective value at epoch t=3 is 0.4868881940188051
# Objective value at epoch t=4 is 0.5005018131620045
# Objective value at epoch t=5 is 0.49147967250261404
# Objective value at epoch t=6 is 0.4920669288511337
# Objective value at epoch t=7 is 0.4891670423631549
# Objective value at epoch t=8 is 0.48651314048726624
# Objective value at epoch t=9 is 0.4852330600721883
# Objective value at epoch t=10 is 0.4817769305907035
# Objective value at epoch t=11 is 0.4812195505599231
# Objective value at epoch t=12 is 0.4769244092149278
# Objective value at epoch t=13 is 0.4799658214767478
# Objective value at epoch t=14 is 0.47449565606447913
# Objective value at epoch t=15 is 0.4759095721750314
# Objective value at epoch t=16 is 0.47449802851583484
# Objective value at epoch t=17 is 0.47176279654408726
# Objective value at epoch t=18 is 0.4720816039207927
# Objective value at epoch t=19 is 0.4705960001507189
# Objective value at epoch t=20 is 0.46865533176531465
# Objective value at epoch t=21 is 0.46980473016740937
# Objective value at epoch t=22 is 0.46841918672153116
# Objective value at epoch t=23 is 0.46806287443028854
# Objective value at epoch t=24 is 0.4686916181838658
# Objective value at epoch t=25 is 0.466476593123305
# Objective value at epoch t=26 is 0.4659571304698491
# Objective value at epoch t=27 is 0.46550142570630176
# Objective value at epoch t=28 is 0.4654940022165304
# Objective value at epoch t=29 is 0.4648024412207086
# Objective value at epoch t=30 is 0.46504411029828924
# Objective value at epoch t=31 is 0.46472411310949335
# Objective value at epoch t=32 is 0.46434626167221876
# Objective value at epoch t=33 is 0.4640336611891877
# Objective value at epoch t=34 is 0.46378063629894994
# Objective value at epoch t=35 is 0.46366221564461085
# Objective value at epoch t=36 is 0.4635678317281335
# Objective value at epoch t=37 is 0.4633469357214525
# Objective value at epoch t=38 is 0.46313284252945086
# Objective value at epoch t=39 is 0.4631259850961403
# Objective value at epoch t=40 is 0.4630392870855914
# Objective value at epoch t=41 is 0.46273361509065064
# Objective value at epoch t=42 is 0.46281101504131994
# Objective value at epoch t=43 is 0.4626985874767963
# Objective value at epoch t=44 is 0.4626251652969947
# Objective value at epoch t=45 is 0.4626189515696737
# Objective value at epoch t=46 is 0.4624820879287831
# Objective value at epoch t=47 is 0.4624404938704223
# Objective value at epoch t=48 is 0.46241142124065265
# Objective value at epoch t=49 is 0.4623166961569908
# Objective value at epoch t=50 is 0.46231294675632445
# Objective value at epoch t=51 is 0.4622984633293018
# Objective value at epoch t=52 is 0.4622388547817525
# Objective value at epoch t=53 is 0.4621897233459504
# Objective value at epoch t=54 is 0.46216265917511584
# Objective value at epoch t=55 is 0.462138321044379
# Objective value at epoch t=56 is 0.462114206595969
# Objective value at epoch t=57 is 0.46212184428207426
# Objective value at epoch t=58 is 0.4620782762985355
# Objective value at epoch t=59 is 0.46207321544512664
# Objective value at epoch t=60 is 0.46205586320114955
# Objective value at epoch t=61 is 0.46205162096462093
# Objective value at epoch t=62 is 0.46203885513772197
# Objective value at epoch t=63 is 0.46201987582843496
# Objective value at epoch t=64 is 0.46201332040322096
# Objective value at epoch t=65 is 0.4620034105055444
# Objective value at epoch t=66 is 0.46198973547328703
# Objective value at epoch t=67 is 0.46198754463504865
# Objective value at epoch t=68 is 0.46197768850819276
# Objective value at epoch t=69 is 0.4619768161159007
# Objective value at epoch t=70 is 0.46197943065012426
# Objective value at epoch t=71 is 0.4619641683318611
# Objective value at epoch t=72 is 0.4619631264026827
# Objective value at epoch t=73 is 0.46195958967449824
# Objective value at epoch t=74 is 0.46195689046587135
# Objective value at epoch t=75 is 0.4619529923702649
# Objective value at epoch t=76 is 0.4619496521393208
# Objective value at epoch t=77 is 0.4619489542037031
# Objective value at epoch t=78 is 0.4619487267584634
# Objective value at epoch t=79 is 0.46194647616808976
# Objective value at epoch t=80 is 0.46194349966363557
# Objective value at epoch t=81 is 0.4619410165168346
# Objective value at epoch t=82 is 0.4619413858119986
# Objective value at epoch t=83 is 0.4619388698282828
# Objective value at epoch t=84 is 0.4619376307943323
# Objective value at epoch t=85 is 0.46193664667441475
# Objective value at epoch t=86 is 0.46193494094376897
# Objective value at epoch t=87 is 0.46193589805573937
# Objective value at epoch t=88 is 0.46193330693055656
# Objective value at epoch t=89 is 0.461933573002296
# Objective value at epoch t=90 is 0.46193268219725925
# Objective value at epoch t=91 is 0.46193246587524905
# Objective value at epoch t=92 is 0.4619316953569125
# Objective value at epoch t=93 is 0.46193150384613135
# Objective value at epoch t=94 is 0.4619307426158444
# Objective value at epoch t=95 is 0.4619305745837711
# Objective value at epoch t=96 is 0.46193021279699875
# Objective value at epoch t=97 is 0.4619302718382846
# Objective value at epoch t=98 is 0.4619298878028288
# Objective value at epoch t=99 is 0.4619293635208651
# Objective value at epoch t=0 is 1.3698235669345498
# Objective value at epoch t=1 is 1.1981075763475888
# Objective value at epoch t=2 is 1.2289375785454886
# Objective value at epoch t=3 is 1.3710871382286318
# Objective value at epoch t=4 is 0.9279563466570979
# Objective value at epoch t=5 is 0.8903610211713608
# Objective value at epoch t=6 is 0.8234633230561288
# Objective value at epoch t=7 is 0.8760303446543187
# Objective value at epoch t=8 is 0.7177885016093012
# Objective value at epoch t=9 is 0.7014332093970796
# Objective value at epoch t=10 is 0.668357154301977
# Objective value at epoch t=11 is 0.6067894763879351
# Objective value at epoch t=12 is 0.595633774834954
# Objective value at epoch t=13 is 0.5877761404212256
# Objective value at epoch t=14 is 0.5846235179949847
# Objective value at epoch t=15 is 0.5669118557732851
# Objective value at epoch t=16 is 0.5742986873139735
# Objective value at epoch t=17 is 0.5415808359795125
# Objective value at epoch t=18 is 0.5292279810878165
# Objective value at epoch t=19 is 0.5285151877037519
# Objective value at epoch t=20 is 0.5086021428945839
# Objective value at epoch t=21 is 0.49717342405010656
# Objective value at epoch t=22 is 0.5050955403841424
# Objective value at epoch t=23 is 0.5069771045696012
# Objective value at epoch t=24 is 0.4973739601682793
# Objective value at epoch t=25 is 0.48812062953453805
# Objective value at epoch t=26 is 0.4874950366145224
# Objective value at epoch t=27 is 0.4847671755951489
# Objective value at epoch t=28 is 0.490521659691054
# Objective value at epoch t=29 is 0.48260310364028297
# Objective value at epoch t=30 is 0.4797154643559107
# Objective value at epoch t=31 is 0.4808547660610155
# Objective value at epoch t=32 is 0.478728109276103
# Objective value at epoch t=33 is 0.4735811562232016
# Objective value at epoch t=34 is 0.4762364295285799
# Objective value at epoch t=35 is 0.4759987756291967
# Objective value at epoch t=36 is 0.47237490962702794
# Objective value at epoch t=37 is 0.4712867630649856
# Objective value at epoch t=38 is 0.47076471177905044
# Objective value at epoch t=39 is 0.4700667644478484
# Objective value at epoch t=40 is 0.4686063266806391
# Objective value at epoch t=41 is 0.46836222553521667
# Objective value at epoch t=42 is 0.4684417786259735
# Objective value at epoch t=43 is 0.4666478713386142
# Objective value at epoch t=44 is 0.4668791926569841
# Objective value at epoch t=45 is 0.46652946315634375
# Objective value at epoch t=46 is 0.4662689074657952
# Objective value at epoch t=47 is 0.4659663467811006
# Objective value at epoch t=48 is 0.46535622901198337
# Objective value at epoch t=49 is 0.46469739182115327
# Objective value at epoch t=50 is 0.4647159184311619
# Objective value at epoch t=51 is 0.4646114990007783
# Objective value at epoch t=52 is 0.464145222935809
# Objective value at epoch t=53 is 0.46406935799710414
# Objective value at epoch t=54 is 0.463800858812525
# Objective value at epoch t=55 is 0.4635888879476367
# Objective value at epoch t=56 is 0.4635054564624997
# Objective value at epoch t=57 is 0.46348108140363936
# Objective value at epoch t=58 is 0.46321893076744924
# Objective value at epoch t=59 is 0.46299583461724525
# Objective value at epoch t=60 is 0.46288405260527343
# Objective value at epoch t=61 is 0.4628326160650711
# Objective value at epoch t=62 is 0.462710479480508
# Objective value at epoch t=63 is 0.4626251717002855
# Objective value at epoch t=64 is 0.4626341044976815
# Objective value at epoch t=65 is 0.4625595877607028
# Objective value at epoch t=66 is 0.46245437842770115
# Objective value at epoch t=67 is 0.46247300959140325
# Objective value at epoch t=68 is 0.46236052991789034
# Objective value at epoch t=69 is 0.46233685190453055
# Objective value at epoch t=70 is 0.46227849311952296
# Objective value at epoch t=71 is 0.46225666896040674
# Objective value at epoch t=72 is 0.4622531382073681
# Objective value at epoch t=73 is 0.4621865978769013
# Objective value at epoch t=74 is 0.4621491206314646
# Objective value at epoch t=75 is 0.46212602841642764
# Objective value at epoch t=76 is 0.4621182488988752
# Objective value at epoch t=77 is 0.462098978586231
# Objective value at epoch t=78 is 0.462083133315175
# Objective value at epoch t=79 is 0.46206864358552197
# Objective value at epoch t=80 is 0.46205719188751215
# Objective value at epoch t=81 is 0.4620381699195305
# Objective value at epoch t=82 is 0.4620400430062116
# Objective value at epoch t=83 is 0.4620210213647441
# Objective value at epoch t=84 is 0.46201218908161445
# Objective value at epoch t=85 is 0.4620128248197376
# Objective value at epoch t=86 is 0.4619911730502329
# Objective value at epoch t=87 is 0.46198544262807706
# Objective value at epoch t=88 is 0.46198503224296256
# Objective value at epoch t=89 is 0.4619739741682972
# Objective value at epoch t=90 is 0.46197018792300293
# Objective value at epoch t=91 is 0.461965183097241
# Objective value at epoch t=92 is 0.4619677683762148
# Objective value at epoch t=93 is 0.4619619080088125
# Objective value at epoch t=94 is 0.46195725955313865
# Objective value at epoch t=95 is 0.46195204608094614
# Objective value at epoch t=96 is 0.46194842490825294
# Objective value at epoch t=97 is 0.46194962449575366
# Objective value at epoch t=98 is 0.46194537769508226
# Objective value at epoch t=99 is 0.461945661837093
# Objective value at epoch t=0 is 1.8558516581635203
# Objective value at epoch t=1 is 1.8927586524821252
# Objective value at epoch t=2 is 1.4231777691017526
# Objective value at epoch t=3 is 1.3153998237883582
# Objective value at epoch t=4 is 1.3609582463323604
# Objective value at epoch t=5 is 0.9399064570706621
# Objective value at epoch t=6 is 1.0313004044426994
# Objective value at epoch t=7 is 0.9062082666803285
# Objective value at epoch t=8 is 0.8982833761164521
# Objective value at epoch t=9 is 0.813946239826344
# Objective value at epoch t=10 is 0.7649427496484817
# Objective value at epoch t=11 is 0.7743855747941519
# Objective value at epoch t=12 is 0.6638070974850425
# Objective value at epoch t=13 is 0.6487764318688936
# Objective value at epoch t=14 is 0.6244534150292655
# Objective value at epoch t=15 is 0.5870929982523926
# Objective value at epoch t=16 is 0.5689926552445679
# Objective value at epoch t=17 is 0.5674250197891665
# Objective value at epoch t=18 is 0.5371559756952157
# Objective value at epoch t=19 is 0.5501787003393739
# Objective value at epoch t=20 is 0.543200823741403
# Objective value at epoch t=21 is 0.5285448761432511
# Objective value at epoch t=22 is 0.5104740186503947
# Objective value at epoch t=23 is 0.5013292878887231
# Objective value at epoch t=24 is 0.505372370176297
# Objective value at epoch t=25 is 0.488873057703858
# Objective value at epoch t=26 is 0.49998790409698496
# Objective value at epoch t=27 is 0.49037847038475946
# Objective value at epoch t=28 is 0.49457022831251585
# Objective value at epoch t=29 is 0.48876305090281785
# Objective value at epoch t=30 is 0.4776276257697062
# Objective value at epoch t=31 is 0.4838848358871638
# Objective value at epoch t=32 is 0.48303805628659946
# Objective value at epoch t=33 is 0.47898817207676075
# Objective value at epoch t=34 is 0.47664930948534445
# Objective value at epoch t=35 is 0.4790733223127881
# Objective value at epoch t=36 is 0.4742837144811592
# Objective value at epoch t=37 is 0.4739236686628375
# Objective value at epoch t=38 is 0.47315003126490573
# Objective value at epoch t=39 is 0.4705907837277695
# Objective value at epoch t=40 is 0.4702872270272714
# Objective value at epoch t=41 is 0.4713152821352293
# Objective value at epoch t=42 is 0.469514919835735
# Objective value at epoch t=43 is 0.46914882523408136
# Objective value at epoch t=44 is 0.4680191475148948
# Objective value at epoch t=45 is 0.4672331169186122
# Objective value at epoch t=46 is 0.4676527925880788
# Objective value at epoch t=47 is 0.4664445451075602
# Objective value at epoch t=48 is 0.4666365584700314
# Objective value at epoch t=49 is 0.4657018485079184
# Objective value at epoch t=50 is 0.465477718719593
# Objective value at epoch t=51 is 0.4648260286700923
# Objective value at epoch t=52 is 0.4647286509482436
# Objective value at epoch t=53 is 0.46439240231161066
# Objective value at epoch t=54 is 0.4642962836345501
# Objective value at epoch t=55 is 0.4641735678314077
# Objective value at epoch t=56 is 0.4637066038313848
# Objective value at epoch t=57 is 0.46355996425557056
# Objective value at epoch t=58 is 0.4637008116338781
# Objective value at epoch t=59 is 0.46333907907405497
# Objective value at epoch t=60 is 0.46309923432144917
# Objective value at epoch t=61 is 0.46303418887154446
# Objective value at epoch t=62 is 0.46296780515226804
# Objective value at epoch t=63 is 0.462847739216777
# Objective value at epoch t=64 is 0.46279649305622356
# Objective value at epoch t=65 is 0.4626070997629081
# Objective value at epoch t=66 is 0.46261822107751593
# Objective value at epoch t=67 is 0.4625507180143128
# Objective value at epoch t=68 is 0.46250658519139104
# Objective value at epoch t=69 is 0.4624162716391248
# Objective value at epoch t=70 is 0.4623631350767674
# Objective value at epoch t=71 is 0.46232892685609317
# Objective value at epoch t=72 is 0.4622685617881882
# Objective value at epoch t=73 is 0.46226621232994747
# Objective value at epoch t=74 is 0.46223004196887996
# Objective value at epoch t=75 is 0.4621815127837829
# Objective value at epoch t=76 is 0.4621831210977335
# Objective value at epoch t=77 is 0.4621588361967516
# Objective value at epoch t=78 is 0.4621098903665133
# Objective value at epoch t=79 is 0.4621021879253992
# Objective value at epoch t=80 is 0.46207791067946963
# Objective value at epoch t=81 is 0.4620586151220173
# Objective value at epoch t=82 is 0.46205652795870245
# Objective value at epoch t=83 is 0.4620370896578316
# Objective value at epoch t=84 is 0.46203383153517585
# Objective value at epoch t=85 is 0.46202649311643534
# Objective value at epoch t=86 is 0.4620071889453077
# Objective value at epoch t=87 is 0.4619986861994964
# Objective value at epoch t=88 is 0.4619979353070745
# Objective value at epoch t=89 is 0.46198919815215483
# Objective value at epoch t=90 is 0.4619834835411525
# Objective value at epoch t=91 is 0.4619766312016499
# Objective value at epoch t=92 is 0.4619702616753198
# Objective value at epoch t=93 is 0.46196769372186264
# Objective value at epoch t=94 is 0.4619605513199295
# Objective value at epoch t=95 is 0.4619583209562398
# Objective value at epoch t=96 is 0.4619559930461687
# Objective value at epoch t=97 is 0.46195222739683023
# Objective value at epoch t=98 is 0.4619487113699014
# Objective value at epoch t=99 is 0.4619485147726078
# Objective value at epoch t=0 is 17.628875247824475
# Objective value at epoch t=1 is 16.237388892455662
# Objective value at epoch t=2 is 15.871656781421283
# Objective value at epoch t=3 is 13.561810919473313
# Objective value at epoch t=4 is 11.176284712619974
# Objective value at epoch t=5 is 10.046068278623979
# Objective value at epoch t=6 is 9.677356799536275
# Objective value at epoch t=7 is 8.16494420287447
# Objective value at epoch t=8 is 7.934611555167524
# Objective value at epoch t=9 is 7.01386074333101
# Objective value at epoch t=10 is 5.833524029548287
# Objective value at epoch t=11 is 5.910016533164731
# Objective value at epoch t=12 is 5.747045486629588
# Objective value at epoch t=13 is 4.0967142202314015
# Objective value at epoch t=14 is 4.133756428112415
# Objective value at epoch t=15 is 3.2931856667438986
# Objective value at epoch t=16 is 3.0359571284732643
# Objective value at epoch t=17 is 2.775845355596709
# Objective value at epoch t=18 is 2.992009215103608
# Objective value at epoch t=19 is 2.7533012099720118
# Objective value at epoch t=20 is 2.1354863628345293
# Objective value at epoch t=21 is 1.8434447511444454
# Objective value at epoch t=22 is 1.7509815945673968
# Objective value at epoch t=23 is 1.4638815310269482
# Objective value at epoch t=24 is 1.481814728147485
# Objective value at epoch t=25 is 1.3506321928991936
# Objective value at epoch t=26 is 1.1347379425820532
# Objective value at epoch t=27 is 1.2325834746328284
# Objective value at epoch t=28 is 1.0997716897767749
# Objective value at epoch t=29 is 0.958234495700552
# Objective value at epoch t=30 is 0.7986529426331515
# Objective value at epoch t=31 is 0.8225004073780957
# Objective value at epoch t=32 is 0.8130519252827423
# Objective value at epoch t=33 is 0.6829331979218243
# Objective value at epoch t=34 is 0.6699719183075947
# Objective value at epoch t=35 is 0.6431101004916793
# Objective value at epoch t=36 is 0.6164341573281431
# Objective value at epoch t=37 is 0.5874465553833447
# Objective value at epoch t=38 is 0.5794229018230574
# Objective value at epoch t=39 is 0.5670555010874205
# Objective value at epoch t=40 is 0.5545215055966113
# Objective value at epoch t=41 is 0.5282996365091202
# Objective value at epoch t=42 is 0.5157213291589489
# Objective value at epoch t=43 is 0.5241973147613745
# Objective value at epoch t=44 is 0.5149325799175959
# Objective value at epoch t=45 is 0.5086797338825488
# Objective value at epoch t=46 is 0.5032727716497531
# Objective value at epoch t=47 is 0.49722016912648986
# Objective value at epoch t=48 is 0.49624643242731203
# Objective value at epoch t=49 is 0.4921127263741602
# Objective value at epoch t=50 is 0.493998425781894
# Objective value at epoch t=51 is 0.49481483959186934
# Objective value at epoch t=52 is 0.48127044421129933
# Objective value at epoch t=53 is 0.48156928659041665
# Objective value at epoch t=54 is 0.48250690590936857
# Objective value at epoch t=55 is 0.479503434233313
# Objective value at epoch t=56 is 0.47769160364752594
# Objective value at epoch t=57 is 0.4774044700222747
# Objective value at epoch t=58 is 0.4710872403139798
# Objective value at epoch t=59 is 0.4753055466685436
# Objective value at epoch t=60 is 0.4720920913840484
# Objective value at epoch t=61 is 0.47327054260258794
# Objective value at epoch t=62 is 0.4714453317706848
# Objective value at epoch t=63 is 0.46985487791625025
# Objective value at epoch t=64 is 0.4704312633637414
# Objective value at epoch t=65 is 0.46877831107075724
# Objective value at epoch t=66 is 0.46872292603487253
# Objective value at epoch t=67 is 0.46764610002821067
# Objective value at epoch t=68 is 0.46667620668615095
# Objective value at epoch t=69 is 0.4663897504169932
# Objective value at epoch t=70 is 0.466615658230634
# Objective value at epoch t=71 is 0.4658420934936567
# Objective value at epoch t=72 is 0.4651866919654311
# Objective value at epoch t=73 is 0.46484876746673826
# Objective value at epoch t=74 is 0.4646519661037473
# Objective value at epoch t=75 is 0.4644282790318061
# Objective value at epoch t=76 is 0.46436016823022375
# Objective value at epoch t=77 is 0.4639787012028407
# Objective value at epoch t=78 is 0.46379492344251066
# Objective value at epoch t=79 is 0.4637335183444031
# Objective value at epoch t=80 is 0.4634129522731154
# Objective value at epoch t=81 is 0.4634317008693162
# Objective value at epoch t=82 is 0.4630927411000124
# Objective value at epoch t=83 is 0.46299021136520724
# Objective value at epoch t=84 is 0.46284351675124136
# Objective value at epoch t=85 is 0.46290759298939055
# Objective value at epoch t=86 is 0.46284064112586554
# Objective value at epoch t=87 is 0.4626996632154345
# Objective value at epoch t=88 is 0.4626060855398844
# Objective value at epoch t=89 is 0.4625665777171378
# Objective value at epoch t=90 is 0.46252305705838515
# Objective value at epoch t=91 is 0.46239498934724754
# Objective value at epoch t=92 is 0.46237726888086933
# Objective value at epoch t=93 is 0.46231434414678524
# Objective value at epoch t=94 is 0.4622580835963176
# Objective value at epoch t=95 is 0.46226447316501956
# Objective value at epoch t=96 is 0.462217664779039
# Objective value at epoch t=97 is 0.46220258754703086
# Objective value at epoch t=98 is 0.46216301481714517
# Objective value at epoch t=99 is 0.46215025351660693
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in exp
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: overflow encountered in exp
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is inf
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is inf
# Objective value at epoch t=15 is 39.52396335032003
# Objective value at epoch t=16 is 35.29643986455116
# Objective value at epoch t=17 is 33.76841922014711
# Objective value at epoch t=18 is 24.274585707910507
# Objective value at epoch t=19 is 26.95977092501834
# Objective value at epoch t=20 is 21.452450476913242
# Objective value at epoch t=21 is inf
# Objective value at epoch t=22 is inf
# Objective value at epoch t=23 is 15.289910878118414
# Objective value at epoch t=24 is 13.949182051284206
# Objective value at epoch t=25 is 14.344133239571525
# Objective value at epoch t=26 is 11.671256303145373
# Objective value at epoch t=27 is 9.77776799315328
# Objective value at epoch t=28 is 9.799869066176786
# Objective value at epoch t=29 is 8.488464584731965
# Objective value at epoch t=30 is 8.705463648290172
# Objective value at epoch t=31 is 7.6161817254496444
# Objective value at epoch t=32 is 6.799723268508032
# Objective value at epoch t=33 is 6.551710608965836
# Objective value at epoch t=34 is 4.336530345853334
# Objective value at epoch t=35 is 4.280697172059456
# Objective value at epoch t=36 is 4.261806678756952
# Objective value at epoch t=37 is 3.8167641161252712
# Objective value at epoch t=38 is 3.1599039881805693
# Objective value at epoch t=39 is 2.612906668730452
# Objective value at epoch t=40 is 2.1482100058191547
# Objective value at epoch t=41 is 2.4082378052365234
# Objective value at epoch t=42 is 2.4022640569370974
# Objective value at epoch t=43 is 1.932491683962554
# Objective value at epoch t=44 is 1.4796523046926142
# Objective value at epoch t=45 is 1.527379245123746
# Objective value at epoch t=46 is 1.4208791599142863
# Objective value at epoch t=47 is 1.2539918296623558
# Objective value at epoch t=48 is 1.2311552112974837
# Objective value at epoch t=49 is 0.9486478856388262
# Objective value at epoch t=50 is 0.9227771716936293
# Objective value at epoch t=51 is 0.9523955507510982
# Objective value at epoch t=52 is 0.8509638909592603
# Objective value at epoch t=53 is 0.8135625278121884
# Objective value at epoch t=54 is 0.8102634007807085
# Objective value at epoch t=55 is 0.7323052073369521
# Objective value at epoch t=56 is 0.6266682117181397
# Objective value at epoch t=57 is 0.6321484693673168
# Objective value at epoch t=58 is 0.5871619875558458
# Objective value at epoch t=59 is 0.5783864761285202
# Objective value at epoch t=60 is 0.5704154785206799
# Objective value at epoch t=61 is 0.55160532210962
# Objective value at epoch t=62 is 0.5472064491423969
# Objective value at epoch t=63 is 0.534024737096981
# Objective value at epoch t=64 is 0.5296403804418233
# Objective value at epoch t=65 is 0.5161658671858838
# Objective value at epoch t=66 is 0.5045580160838143
# Objective value at epoch t=67 is 0.5115052156748517
# Objective value at epoch t=68 is 0.5020630699312808
# Objective value at epoch t=69 is 0.49813270177789837
# Objective value at epoch t=70 is 0.4886536436556221
# Objective value at epoch t=71 is 0.494179758824453
# Objective value at epoch t=72 is 0.48551933143080894
# Objective value at epoch t=73 is 0.4864076472529722
# Objective value at epoch t=74 is 0.48667688052875346
# Objective value at epoch t=75 is 0.48596456439724073
# Objective value at epoch t=76 is 0.4801821989636368
# Objective value at epoch t=77 is 0.48151687097144047
# Objective value at epoch t=78 is 0.4729932270822369
# Objective value at epoch t=79 is 0.47886318453414045
# Objective value at epoch t=80 is 0.47462672776214554
# Objective value at epoch t=81 is 0.4753478755048284
# Objective value at epoch t=82 is 0.47147591008867346
# Objective value at epoch t=83 is 0.4715278510738238
# Objective value at epoch t=84 is 0.4694586338273864
# Objective value at epoch t=85 is 0.46919875354779544
# Objective value at epoch t=86 is 0.4693239769452586
# Objective value at epoch t=87 is 0.4681758652211128
# Objective value at epoch t=88 is 0.4685584804010001
# Objective value at epoch t=89 is 0.4672824893582529
# Objective value at epoch t=90 is 0.46694323382690744
# Objective value at epoch t=91 is 0.4665967873509693
# Objective value at epoch t=92 is 0.46597449475103075
# Objective value at epoch t=93 is 0.4648980901015748
# Objective value at epoch t=94 is 0.46535655210601534
# Objective value at epoch t=95 is 0.46495659569904363
# Objective value at epoch t=96 is 0.46505704877300913
# Objective value at epoch t=97 is 0.4643925327237288
# Objective value at epoch t=98 is 0.4642520746852023
# Objective value at epoch t=99 is 0.463786352858894
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is inf
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is inf
# Objective value at epoch t=15 is inf
# Objective value at epoch t=16 is inf
# Objective value at epoch t=17 is inf
# Objective value at epoch t=18 is inf
# Objective value at epoch t=19 is inf
# Objective value at epoch t=20 is inf
# Objective value at epoch t=21 is inf
# Objective value at epoch t=22 is inf
# Objective value at epoch t=23 is inf
# Objective value at epoch t=24 is inf
# Objective value at epoch t=25 is inf
# Objective value at epoch t=26 is inf
# Objective value at epoch t=27 is inf
# Objective value at epoch t=28 is inf
# Objective value at epoch t=29 is inf
# Objective value at epoch t=30 is inf
# Objective value at epoch t=31 is inf
# Objective value at epoch t=32 is inf
# Objective value at epoch t=33 is inf
# Objective value at epoch t=34 is inf
# Objective value at epoch t=35 is 45.23221281781086
# Objective value at epoch t=36 is inf
# Objective value at epoch t=37 is inf
# Objective value at epoch t=38 is 32.24190233733222
# Objective value at epoch t=39 is 28.89144325173521
# Objective value at epoch t=40 is 25.384536589738254
# Objective value at epoch t=41 is 22.76066138686619
# Objective value at epoch t=42 is 20.663520218508204
# Objective value at epoch t=43 is 18.93102756600044
# Objective value at epoch t=44 is 18.995474712250285
# Objective value at epoch t=45 is 13.974667225222698
# Objective value at epoch t=46 is 14.99015335277279
# Objective value at epoch t=47 is 13.858975842017466
# Objective value at epoch t=48 is 12.465925662889052
# Objective value at epoch t=49 is 10.291022223034734
# Objective value at epoch t=50 is 10.140523170816213
# Objective value at epoch t=51 is 9.33533207113263
# Objective value at epoch t=52 is 6.643741422457685
# Objective value at epoch t=53 is 6.621422633881582
# Objective value at epoch t=54 is 5.975048004594705
# Objective value at epoch t=55 is 6.574516219605668
# Objective value at epoch t=56 is 4.989978581541198
# Objective value at epoch t=57 is 4.213876445471113
# Objective value at epoch t=58 is 4.055106864188495
# Objective value at epoch t=59 is 3.2527298198261603
# Objective value at epoch t=60 is 3.0244863146591143
# Objective value at epoch t=61 is 3.141452164369272
# Objective value at epoch t=62 is 2.590036471286333
# Objective value at epoch t=63 is 2.0405852619281615
# Objective value at epoch t=64 is 1.8990387890466256
# Objective value at epoch t=65 is 1.9121027476020207
# Objective value at epoch t=66 is 1.8211414389680058
# Objective value at epoch t=67 is 1.6313710557644612
# Objective value at epoch t=68 is 1.5279827909958168
# Objective value at epoch t=69 is 1.2906665538861726
# Objective value at epoch t=70 is 1.1070330533690544
# Objective value at epoch t=71 is 1.0207432402718206
# Objective value at epoch t=72 is 1.0474437614982393
# Objective value at epoch t=73 is 0.9397199871559186
# Objective value at epoch t=74 is 0.8382892030315732
# Objective value at epoch t=75 is 0.7940011118710981
# Objective value at epoch t=76 is 0.7402658021064872
# Objective value at epoch t=77 is 0.6929709257493939
# Objective value at epoch t=78 is 0.7013484783237702
# Objective value at epoch t=79 is 0.655215169062555
# Objective value at epoch t=80 is 0.5999375116853563
# Objective value at epoch t=81 is 0.5918195622101614
# Objective value at epoch t=82 is 0.5597877595888155
# Objective value at epoch t=83 is 0.5738581671588664
# Objective value at epoch t=84 is 0.5633751270911094
# Objective value at epoch t=85 is 0.5503712566062382
# Objective value at epoch t=86 is 0.5291353754095027
# Objective value at epoch t=87 is 0.518688958923138
# Objective value at epoch t=88 is 0.5152946406332675
# Objective value at epoch t=89 is 0.5071528936772147
# Objective value at epoch t=90 is 0.502632111678582
# Objective value at epoch t=91 is 0.49993980455040987
# Objective value at epoch t=92 is 0.5038647866364092
# Objective value at epoch t=93 is 0.4892921506716451
# Objective value at epoch t=94 is 0.48095687820995786
# Objective value at epoch t=95 is 0.4914633738314203
# Objective value at epoch t=96 is 0.48499973369953997
# Objective value at epoch t=97 is 0.48617540549135113
# Objective value at epoch t=98 is 0.4827716286043118
# Objective value at epoch t=99 is 0.48056514129085903

# %%
# MB-SGD with batch size b=64
lam = 1E-6 # do not change
b = 64 # do not change

errors_train64 = []
errors_test64 = []
objvals_mbsgd64 = []

for stepsize in stepsizes:
    w_tmp, objval_tmp = mb_sgd(x_train, y_train, lam, b, stepsize)
    f_train = predict(w_tmp, x_train)
    diff = numpy.abs(f_train - y_train) / 2
    error_train = numpy.mean(diff)
    f_test = predict(w_tmp, x_test)
    diff = numpy.abs(f_test - y_test) / 2
    error_test = numpy.mean(diff)
    
    errors_train64.append(error_train)
    errors_test64.append(error_test)
    objvals_mbsgd64.append(objval_tmp)
# Out:
# Objective value at epoch t=0 is 0.6927635934275809
# Objective value at epoch t=1 is 0.691935439892683
# Objective value at epoch t=2 is 0.6911917162423029
# Objective value at epoch t=3 is 0.6905258290588502
# Objective value at epoch t=4 is 0.6899317134958194
# Objective value at epoch t=5 is 0.6893975228743978
# Objective value at epoch t=6 is 0.6889167645250656
# Objective value at epoch t=7 is 0.6884853468998505
# Objective value at epoch t=8 is 0.6880997068352811
# Objective value at epoch t=9 is 0.6877534656152344
# Objective value at epoch t=10 is 0.6874417657167802
# Objective value at epoch t=11 is 0.6871606908036343
# Objective value at epoch t=12 is 0.6869095717488504
# Objective value at epoch t=13 is 0.6866828073183254
# Objective value at epoch t=14 is 0.6864800756186806
# Objective value at epoch t=15 is 0.6862969378497688
# Objective value at epoch t=16 is 0.6861331229420621
# Objective value at epoch t=17 is 0.6859858492736464
# Objective value at epoch t=18 is 0.6858530421292918
# Objective value at epoch t=19 is 0.6857334609893664
# Objective value at epoch t=20 is 0.6856263385097641
# Objective value at epoch t=21 is 0.6855295302750459
# Objective value at epoch t=22 is 0.685442622953215
# Objective value at epoch t=23 is 0.6853647974347579
# Objective value at epoch t=24 is 0.685294332608899
# Objective value at epoch t=25 is 0.6852312373847063
# Objective value at epoch t=26 is 0.6851743577389241
# Objective value at epoch t=27 is 0.6851231862014588
# Objective value at epoch t=28 is 0.6850773203535064
# Objective value at epoch t=29 is 0.6850356333018527
# Objective value at epoch t=30 is 0.6849984625863765
# Objective value at epoch t=31 is 0.6849649257870594
# Objective value at epoch t=32 is 0.6849346622707646
# Objective value at epoch t=33 is 0.6849076288730026
# Objective value at epoch t=34 is 0.6848830725316357
# Objective value at epoch t=35 is 0.6848610951184314
# Objective value at epoch t=36 is 0.6848413121157184
# Objective value at epoch t=37 is 0.6848234914675799
# Objective value at epoch t=38 is 0.68480748584056
# Objective value at epoch t=39 is 0.6847930777550132
# Objective value at epoch t=40 is 0.6847800983001446
# Objective value at epoch t=41 is 0.6847684170353107
# Objective value at epoch t=42 is 0.6847579417451912
# Objective value at epoch t=43 is 0.6847484634586076
# Objective value at epoch t=44 is 0.6847399479144485
# Objective value at epoch t=45 is 0.6847322844990328
# Objective value at epoch t=46 is 0.6847254013595543
# Objective value at epoch t=47 is 0.6847191904015297
# Objective value at epoch t=48 is 0.6847136063848401
# Objective value at epoch t=49 is 0.6847085804681952
# Objective value at epoch t=50 is 0.6847040661507895
# Objective value at epoch t=51 is 0.6846999934000266
# Objective value at epoch t=52 is 0.684696346049813
# Objective value at epoch t=53 is 0.6846930287794099
# Objective value at epoch t=54 is 0.6846900577919234
# Objective value at epoch t=55 is 0.6846874056857248
# Objective value at epoch t=56 is 0.6846850057978844
# Objective value at epoch t=57 is 0.6846828272259541
# Objective value at epoch t=58 is 0.6846808929241455
# Objective value at epoch t=59 is 0.6846791343650593
# Objective value at epoch t=60 is 0.6846775558932628
# Objective value at epoch t=61 is 0.6846761390513052
# Objective value at epoch t=62 is 0.6846748627836451
# Objective value at epoch t=63 is 0.6846737136129526
# Objective value at epoch t=64 is 0.6846726814529511
# Objective value at epoch t=65 is 0.6846717519720673
# Objective value at epoch t=66 is 0.6846709128196241
# Objective value at epoch t=67 is 0.6846701564262128
# Objective value at epoch t=68 is 0.684669477089334
# Objective value at epoch t=69 is 0.6846688665477197
# Objective value at epoch t=70 is 0.6846683190772047
# Objective value at epoch t=71 is 0.6846678244926208
# Objective value at epoch t=72 is 0.6846673782388624
# Objective value at epoch t=73 is 0.6846669779109886
# Objective value at epoch t=74 is 0.6846666161632088
# Objective value at epoch t=75 is 0.6846662926933657
# Objective value at epoch t=76 is 0.6846660003426325
# Objective value at epoch t=77 is 0.6846657372706345
# Objective value at epoch t=78 is 0.684665501660484
# Objective value at epoch t=79 is 0.6846652873088823
# Objective value at epoch t=80 is 0.6846650965279439
# Objective value at epoch t=81 is 0.6846649238502092
# Objective value at epoch t=82 is 0.6846647686856709
# Objective value at epoch t=83 is 0.6846646287247595
# Objective value at epoch t=84 is 0.6846645036420408
# Objective value at epoch t=85 is 0.6846643902022206
# Objective value at epoch t=86 is 0.6846642884270022
# Objective value at epoch t=87 is 0.684664196553441
# Objective value at epoch t=88 is 0.6846641143371219
# Objective value at epoch t=89 is 0.6846640400350262
# Objective value at epoch t=90 is 0.6846639729698485
# Objective value at epoch t=91 is 0.6846639128543054
# Objective value at epoch t=92 is 0.6846638588619882
# Objective value at epoch t=93 is 0.6846638101333199
# Objective value at epoch t=94 is 0.6846637661510457
# Objective value at epoch t=95 is 0.6846637268290408
# Objective value at epoch t=96 is 0.6846636912935125
# Objective value at epoch t=97 is 0.6846636592823392
# Objective value at epoch t=98 is 0.6846636305701025
# Objective value at epoch t=99 is 0.6846636046714651
# Objective value at epoch t=0 is 0.6893884245662176
# Objective value at epoch t=1 is 0.6814468079146923
# Objective value at epoch t=2 is 0.6746164636601268
# Objective value at epoch t=3 is 0.6687629725906921
# Objective value at epoch t=4 is 0.6636935361932915
# Objective value at epoch t=5 is 0.65927643607539
# Objective value at epoch t=6 is 0.6554301163858968
# Objective value at epoch t=7 is 0.6520574835594333
# Objective value at epoch t=8 is 0.6491016036519845
# Objective value at epoch t=9 is 0.6464952896197255
# Objective value at epoch t=10 is 0.6442065468567837
# Objective value at epoch t=11 is 0.6421761115552066
# Objective value at epoch t=12 is 0.6403812586018425
# Objective value at epoch t=13 is 0.6387780672827242
# Objective value at epoch t=14 is 0.6373689320378108
# Objective value at epoch t=15 is 0.6361110278548531
# Objective value at epoch t=16 is 0.634988655462909
# Objective value at epoch t=17 is 0.6339879240615198
# Objective value at epoch t=18 is 0.6330978879195037
# Objective value at epoch t=19 is 0.6322934433122747
# Objective value at epoch t=20 is 0.631584048456616
# Objective value at epoch t=21 is 0.6309454020213128
# Objective value at epoch t=22 is 0.6303740702807851
# Objective value at epoch t=23 is 0.6298667521705833
# Objective value at epoch t=24 is 0.6294048672420187
# Objective value at epoch t=25 is 0.6289936654589401
# Objective value at epoch t=26 is 0.62862585428581
# Objective value at epoch t=27 is 0.6282952706431135
# Objective value at epoch t=28 is 0.6279986706440212
# Objective value at epoch t=29 is 0.6277340164336872
# Objective value at epoch t=30 is 0.6274944414673789
# Objective value at epoch t=31 is 0.6272795038431809
# Objective value at epoch t=32 is 0.6270859182754541
# Objective value at epoch t=33 is 0.6269133236647981
# Objective value at epoch t=34 is 0.6267576481881962
# Objective value at epoch t=35 is 0.6266171912574432
# Objective value at epoch t=36 is 0.6264915565257656
# Objective value at epoch t=37 is 0.6263797158103961
# Objective value at epoch t=38 is 0.6262771518475014
# Objective value at epoch t=39 is 0.6261856442252707
# Objective value at epoch t=40 is 0.6261036079659151
# Objective value at epoch t=41 is 0.6260295012636109
# Objective value at epoch t=42 is 0.6259630347457781
# Objective value at epoch t=43 is 0.6259034514786579
# Objective value at epoch t=44 is 0.6258495175236214
# Objective value at epoch t=45 is 0.625800893143923
# Objective value at epoch t=46 is 0.6257572889831444
# Objective value at epoch t=47 is 0.6257182878885679
# Objective value at epoch t=48 is 0.625683062437705
# Objective value at epoch t=49 is 0.6256513804412518
# Objective value at epoch t=50 is 0.6256228602757066
# Objective value at epoch t=51 is 0.6255971144023892
# Objective value at epoch t=52 is 0.6255740451975821
# Objective value at epoch t=53 is 0.6255532002921609
# Objective value at epoch t=54 is 0.6255345692326421
# Objective value at epoch t=55 is 0.6255177122793096
# Objective value at epoch t=56 is 0.6255025887353565
# Objective value at epoch t=57 is 0.625488933799139
# Objective value at epoch t=58 is 0.6254766569555781
# Objective value at epoch t=59 is 0.6254656839946582
# Objective value at epoch t=60 is 0.625455685669077
# Objective value at epoch t=61 is 0.6254467460465707
# Objective value at epoch t=62 is 0.625438731673116
# Objective value at epoch t=63 is 0.6254315131142127
# Objective value at epoch t=64 is 0.6254249819673093
# Objective value at epoch t=65 is 0.625419107627289
# Objective value at epoch t=66 is 0.6254138386627749
# Objective value at epoch t=67 is 0.6254090872939482
# Objective value at epoch t=68 is 0.6254048230300236
# Objective value at epoch t=69 is 0.6254009947667148
# Objective value at epoch t=70 is 0.6253975110594115
# Objective value at epoch t=71 is 0.6253943905478863
# Objective value at epoch t=72 is 0.6253915919632019
# Objective value at epoch t=73 is 0.6253890665508817
# Objective value at epoch t=74 is 0.625386794169104
# Objective value at epoch t=75 is 0.6253847555767951
# Objective value at epoch t=76 is 0.625382917978252
# Objective value at epoch t=77 is 0.6253812641049514
# Objective value at epoch t=78 is 0.6253797742530269
# Objective value at epoch t=79 is 0.6253784331037734
# Objective value at epoch t=80 is 0.6253772202849076
# Objective value at epoch t=81 is 0.6253761348456657
# Objective value at epoch t=82 is 0.6253751605554244
# Objective value at epoch t=83 is 0.6253742842172262
# Objective value at epoch t=84 is 0.6253734882381272
# Objective value at epoch t=85 is 0.6253727756517311
# Objective value at epoch t=86 is 0.6253721387110989
# Objective value at epoch t=87 is 0.6253715600055062
# Objective value at epoch t=88 is 0.6253710412947717
# Objective value at epoch t=89 is 0.6253705730980876
# Objective value at epoch t=90 is 0.625370153504933
# Objective value at epoch t=91 is 0.62536977450146
# Objective value at epoch t=92 is 0.6253694350063281
# Objective value at epoch t=93 is 0.6253691255875902
# Objective value at epoch t=94 is 0.6253688494668276
# Objective value at epoch t=95 is 0.6253686029650791
# Objective value at epoch t=96 is 0.6253683781438463
# Objective value at epoch t=97 is 0.6253681777957877
# Objective value at epoch t=98 is 0.6253679969842159
# Objective value at epoch t=99 is 0.6253678340807807
# Objective value at epoch t=0 is 0.6599888594476073
# Objective value at epoch t=1 is 0.6069927552130464
# Objective value at epoch t=2 is 0.5757442149243277
# Objective value at epoch t=3 is 0.5558510525808492
# Objective value at epoch t=4 is 0.5422779806923715
# Objective value at epoch t=5 is 0.5324004442074071
# Objective value at epoch t=6 is 0.5248668991170289
# Objective value at epoch t=7 is 0.518974850745853
# Objective value at epoch t=8 is 0.5144304246385892
# Objective value at epoch t=9 is 0.5107432904321287
# Objective value at epoch t=10 is 0.5077725662143536
# Objective value at epoch t=11 is 0.5052744765105576
# Objective value at epoch t=12 is 0.5031312722971077
# Objective value at epoch t=13 is 0.5013676915482631
# Objective value at epoch t=14 is 0.4998508092738779
# Objective value at epoch t=15 is 0.498566858679195
# Objective value at epoch t=16 is 0.49749513437064297
# Objective value at epoch t=17 is 0.49648300330031264
# Objective value at epoch t=18 is 0.4956400243595926
# Objective value at epoch t=19 is 0.4949194979276162
# Objective value at epoch t=20 is 0.4942895452785951
# Objective value at epoch t=21 is 0.49369964862827836
# Objective value at epoch t=22 is 0.49320267307279303
# Objective value at epoch t=23 is 0.49276739785720364
# Objective value at epoch t=24 is 0.49238139223554384
# Objective value at epoch t=25 is 0.49201992887954127
# Objective value at epoch t=26 is 0.4917462642155305
# Objective value at epoch t=27 is 0.49145798700328386
# Objective value at epoch t=28 is 0.491207120019945
# Objective value at epoch t=29 is 0.49099446883930414
# Objective value at epoch t=30 is 0.4907986117638662
# Objective value at epoch t=31 is 0.49063627156012124
# Objective value at epoch t=32 is 0.4904765435648186
# Objective value at epoch t=33 is 0.49033536606103406
# Objective value at epoch t=34 is 0.49021614198271646
# Objective value at epoch t=35 is 0.49010392691107907
# Objective value at epoch t=36 is 0.49000789034798825
# Objective value at epoch t=37 is 0.4899203964671486
# Objective value at epoch t=38 is 0.4898414978853708
# Objective value at epoch t=39 is 0.4897740026397447
# Objective value at epoch t=40 is 0.4897025474909298
# Objective value at epoch t=41 is 0.48964687223149345
# Objective value at epoch t=42 is 0.48959593711795363
# Objective value at epoch t=43 is 0.4895498581578991
# Objective value at epoch t=44 is 0.4895099649336506
# Objective value at epoch t=45 is 0.4894703439015299
# Objective value at epoch t=46 is 0.48943581320795077
# Objective value at epoch t=47 is 0.48940680413403526
# Objective value at epoch t=48 is 0.489379825247459
# Objective value at epoch t=49 is 0.4893552554522606
# Objective value at epoch t=50 is 0.4893338360225184
# Objective value at epoch t=51 is 0.48931409565372175
# Objective value at epoch t=52 is 0.48929702999942204
# Objective value at epoch t=53 is 0.48928090926432644
# Objective value at epoch t=54 is 0.4892654564043662
# Objective value at epoch t=55 is 0.48925411028287424
# Objective value at epoch t=56 is 0.4892423575791214
# Objective value at epoch t=57 is 0.4892316576548536
# Objective value at epoch t=58 is 0.4892222341261097
# Objective value at epoch t=59 is 0.4892136060391524
# Objective value at epoch t=60 is 0.4892060215512665
# Objective value at epoch t=61 is 0.4891993139641985
# Objective value at epoch t=62 is 0.4891931164063975
# Objective value at epoch t=63 is 0.48918754701808265
# Objective value at epoch t=64 is 0.48918258006767645
# Objective value at epoch t=65 is 0.4891781216287798
# Objective value at epoch t=66 is 0.4891744978181394
# Objective value at epoch t=67 is 0.48917070256175127
# Objective value at epoch t=68 is 0.4891673456389481
# Objective value at epoch t=69 is 0.4891644606753058
# Objective value at epoch t=70 is 0.48916183657708173
# Objective value at epoch t=71 is 0.48915944007145223
# Objective value at epoch t=72 is 0.48915726948119576
# Objective value at epoch t=73 is 0.4891553439669053
# Objective value at epoch t=74 is 0.48915361428896187
# Objective value at epoch t=75 is 0.489152043426676
# Objective value at epoch t=76 is 0.489150639614334
# Objective value at epoch t=77 is 0.4891494537441938
# Objective value at epoch t=78 is 0.48914836933967376
# Objective value at epoch t=79 is 0.4891472592689614
# Objective value at epoch t=80 is 0.48914635474888185
# Objective value at epoch t=81 is 0.48914553719345333
# Objective value at epoch t=82 is 0.4891447589843966
# Objective value at epoch t=83 is 0.4891440995331216
# Objective value at epoch t=84 is 0.4891435109214662
# Objective value at epoch t=85 is 0.4891429570023943
# Objective value at epoch t=86 is 0.4891424595983162
# Objective value at epoch t=87 is 0.4891420371664764
# Objective value at epoch t=88 is 0.48914165362326967
# Objective value at epoch t=89 is 0.4891412824528477
# Objective value at epoch t=90 is 0.48914096494344134
# Objective value at epoch t=91 is 0.4891406753041019
# Objective value at epoch t=92 is 0.4891404078353019
# Objective value at epoch t=93 is 0.4891401781308088
# Objective value at epoch t=94 is 0.48913996987463665
# Objective value at epoch t=95 is 0.4891397834105577
# Objective value at epoch t=96 is 0.4891396161496189
# Objective value at epoch t=97 is 0.4891394592551158
# Objective value at epoch t=98 is 0.4891393141314565
# Objective value at epoch t=99 is 0.4891391944710154
# Objective value at epoch t=0 is 0.5494862820609844
# Objective value at epoch t=1 is 0.4797933021022779
# Objective value at epoch t=2 is 0.47208029924183786
# Objective value at epoch t=3 is 0.46790285672145104
# Objective value at epoch t=4 is 0.4691263078938773
# Objective value at epoch t=5 is 0.46643747109296285
# Objective value at epoch t=6 is 0.4648972720398782
# Objective value at epoch t=7 is 0.46490542804859636
# Objective value at epoch t=8 is 0.46449477356319857
# Objective value at epoch t=9 is 0.4638245202035153
# Objective value at epoch t=10 is 0.46412786375167353
# Objective value at epoch t=11 is 0.46452322392801654
# Objective value at epoch t=12 is 0.46392114182737176
# Objective value at epoch t=13 is 0.46438559278107183
# Objective value at epoch t=14 is 0.4632643942722002
# Objective value at epoch t=15 is 0.46326203478014244
# Objective value at epoch t=16 is 0.46354429995131596
# Objective value at epoch t=17 is 0.4630513536756009
# Objective value at epoch t=18 is 0.4628539222056955
# Objective value at epoch t=19 is 0.4627602778069454
# Objective value at epoch t=20 is 0.4626990362651123
# Objective value at epoch t=21 is 0.46256416581719184
# Objective value at epoch t=22 is 0.4627512291151622
# Objective value at epoch t=23 is 0.4625235021204972
# Objective value at epoch t=24 is 0.4626246633820955
# Objective value at epoch t=25 is 0.4623710193806826
# Objective value at epoch t=26 is 0.46236370928824
# Objective value at epoch t=27 is 0.46228290429998725
# Objective value at epoch t=28 is 0.46229640401209837
# Objective value at epoch t=29 is 0.4621681578455667
# Objective value at epoch t=30 is 0.46221978288108695
# Objective value at epoch t=31 is 0.4621768755713978
# Objective value at epoch t=32 is 0.46214673741746354
# Objective value at epoch t=33 is 0.4621060696991803
# Objective value at epoch t=34 is 0.4621438537847089
# Objective value at epoch t=35 is 0.46208366421589375
# Objective value at epoch t=36 is 0.4621114405214783
# Objective value at epoch t=37 is 0.46212502486909424
# Objective value at epoch t=38 is 0.4620242733347898
# Objective value at epoch t=39 is 0.4620268033386156
# Objective value at epoch t=40 is 0.4620095422727025
# Objective value at epoch t=41 is 0.46198726843552135
# Objective value at epoch t=42 is 0.46200370485028086
# Objective value at epoch t=43 is 0.46199342092752893
# Objective value at epoch t=44 is 0.4619984108545988
# Objective value at epoch t=45 is 0.4619814539902469
# Objective value at epoch t=46 is 0.46197226521448725
# Objective value at epoch t=47 is 0.4619859139097704
# Objective value at epoch t=48 is 0.46196405255339235
# Objective value at epoch t=49 is 0.4619662897232413
# Objective value at epoch t=50 is 0.4619560472722258
# Objective value at epoch t=51 is 0.4619594415152008
# Objective value at epoch t=52 is 0.4619565096182523
# Objective value at epoch t=53 is 0.4619570138646297
# Objective value at epoch t=54 is 0.4619531695350047
# Objective value at epoch t=55 is 0.46195840327480264
# Objective value at epoch t=56 is 0.4619538500467746
# Objective value at epoch t=57 is 0.46194678815445317
# Objective value at epoch t=58 is 0.46194916480735504
# Objective value at epoch t=59 is 0.46194006222227346
# Objective value at epoch t=60 is 0.46194216590273446
# Objective value at epoch t=61 is 0.4619419135586469
# Objective value at epoch t=62 is 0.4619382594106053
# Objective value at epoch t=63 is 0.4619368893202731
# Objective value at epoch t=64 is 0.46193988567777533
# Objective value at epoch t=65 is 0.46193772899826513
# Objective value at epoch t=66 is 0.46193696649276295
# Objective value at epoch t=67 is 0.46193688230621277
# Objective value at epoch t=68 is 0.461935741679512
# Objective value at epoch t=69 is 0.46193587095088606
# Objective value at epoch t=70 is 0.4619336729794655
# Objective value at epoch t=71 is 0.46193617586586366
# Objective value at epoch t=72 is 0.46193531017001144
# Objective value at epoch t=73 is 0.46193333735345643
# Objective value at epoch t=74 is 0.4619330628853631
# Objective value at epoch t=75 is 0.46193401928132766
# Objective value at epoch t=76 is 0.46193307785886084
# Objective value at epoch t=77 is 0.4619329109005343
# Objective value at epoch t=78 is 0.46193323661806546
# Objective value at epoch t=79 is 0.46193237870272785
# Objective value at epoch t=80 is 0.4619321768284445
# Objective value at epoch t=81 is 0.461932164638994
# Objective value at epoch t=82 is 0.46193264709823917
# Objective value at epoch t=83 is 0.46193196272753917
# Objective value at epoch t=84 is 0.4619317949359985
# Objective value at epoch t=85 is 0.4619319157747892
# Objective value at epoch t=86 is 0.46193200649922683
# Objective value at epoch t=87 is 0.4619316093341156
# Objective value at epoch t=88 is 0.46193157429136705
# Objective value at epoch t=89 is 0.4619315043610941
# Objective value at epoch t=90 is 0.46193143604738846
# Objective value at epoch t=91 is 0.46193145417963866
# Objective value at epoch t=92 is 0.46193130986223696
# Objective value at epoch t=93 is 0.4619313136967908
# Objective value at epoch t=94 is 0.46193128752173146
# Objective value at epoch t=95 is 0.4619311840689243
# Objective value at epoch t=96 is 0.46193124205824276
# Objective value at epoch t=97 is 0.46193115422383524
# Objective value at epoch t=98 is 0.4619311240351337
# Objective value at epoch t=99 is 0.46193121031225076
# Objective value at epoch t=0 is 0.67809464948946
# Objective value at epoch t=1 is 0.5286457743131282
# Objective value at epoch t=2 is 0.5112949650850964
# Objective value at epoch t=3 is 0.5291933406326954
# Objective value at epoch t=4 is 0.4981959775126231
# Objective value at epoch t=5 is 0.513437080743386
# Objective value at epoch t=6 is 0.5095588584597723
# Objective value at epoch t=7 is 0.4714197756307102
# Objective value at epoch t=8 is 0.487304797920354
# Objective value at epoch t=9 is 0.49243325150665995
# Objective value at epoch t=10 is 0.4825109207321102
# Objective value at epoch t=11 is 0.478341736152973
# Objective value at epoch t=12 is 0.4750571275542602
# Objective value at epoch t=13 is 0.475808216420889
# Objective value at epoch t=14 is 0.4750733994870095
# Objective value at epoch t=15 is 0.4782525259932763
# Objective value at epoch t=16 is 0.47655207140665523
# Objective value at epoch t=17 is 0.4751865229676874
# Objective value at epoch t=18 is 0.472217519848482
# Objective value at epoch t=19 is 0.4703899221607073
# Objective value at epoch t=20 is 0.4699030300494682
# Objective value at epoch t=21 is 0.46864462460413836
# Objective value at epoch t=22 is 0.46732284730106655
# Objective value at epoch t=23 is 0.46705356269289167
# Objective value at epoch t=24 is 0.46866968614005655
# Objective value at epoch t=25 is 0.4671438160390344
# Objective value at epoch t=26 is 0.4661147042608536
# Objective value at epoch t=27 is 0.4656385057012617
# Objective value at epoch t=28 is 0.46570045792228976
# Objective value at epoch t=29 is 0.4650693046009198
# Objective value at epoch t=30 is 0.46474231759952866
# Objective value at epoch t=31 is 0.4645304469296284
# Objective value at epoch t=32 is 0.46474278819403303
# Objective value at epoch t=33 is 0.463727961623548
# Objective value at epoch t=34 is 0.46391858643154016
# Objective value at epoch t=35 is 0.46335821749035916
# Objective value at epoch t=36 is 0.4631265396381152
# Objective value at epoch t=37 is 0.4633308792113631
# Objective value at epoch t=38 is 0.4630821893619902
# Objective value at epoch t=39 is 0.46295735635847873
# Objective value at epoch t=40 is 0.4630199878029864
# Objective value at epoch t=41 is 0.46322320589578875
# Objective value at epoch t=42 is 0.4628639444026934
# Objective value at epoch t=43 is 0.46256442650337276
# Objective value at epoch t=44 is 0.46272231444293277
# Objective value at epoch t=45 is 0.4625662345564495
# Objective value at epoch t=46 is 0.46253593263382015
# Objective value at epoch t=47 is 0.4625141932574631
# Objective value at epoch t=48 is 0.46218396477836066
# Objective value at epoch t=49 is 0.4622323402250455
# Objective value at epoch t=50 is 0.4622716360823258
# Objective value at epoch t=51 is 0.4622748364368784
# Objective value at epoch t=52 is 0.4622129706112563
# Objective value at epoch t=53 is 0.46211851768464457
# Objective value at epoch t=54 is 0.4622176315811598
# Objective value at epoch t=55 is 0.4620474373699402
# Objective value at epoch t=56 is 0.4621088786789677
# Objective value at epoch t=57 is 0.46211282041766644
# Objective value at epoch t=58 is 0.4620739163932798
# Objective value at epoch t=59 is 0.4620863438275191
# Objective value at epoch t=60 is 0.4620395545789622
# Objective value at epoch t=61 is 0.4620309893417877
# Objective value at epoch t=62 is 0.46201287732394547
# Objective value at epoch t=63 is 0.4620121039103499
# Objective value at epoch t=64 is 0.46197767801392564
# Objective value at epoch t=65 is 0.4619999466075986
# Objective value at epoch t=66 is 0.46200483934449965
# Objective value at epoch t=67 is 0.461993155907621
# Objective value at epoch t=68 is 0.46197026960200127
# Objective value at epoch t=69 is 0.4619703777148853
# Objective value at epoch t=70 is 0.46198106792946153
# Objective value at epoch t=71 is 0.4619684435873418
# Objective value at epoch t=72 is 0.46196302160713654
# Objective value at epoch t=73 is 0.46195949635220745
# Objective value at epoch t=74 is 0.4619599306284172
# Objective value at epoch t=75 is 0.4619557971040016
# Objective value at epoch t=76 is 0.461948197280153
# Objective value at epoch t=77 is 0.4619474344484457
# Objective value at epoch t=78 is 0.4619407255316963
# Objective value at epoch t=79 is 0.46194135673257597
# Objective value at epoch t=80 is 0.4619415741153642
# Objective value at epoch t=81 is 0.461940542842403
# Objective value at epoch t=82 is 0.46193756673047603
# Objective value at epoch t=83 is 0.46193504606554175
# Objective value at epoch t=84 is 0.46193800557589737
# Objective value at epoch t=85 is 0.4619358190442888
# Objective value at epoch t=86 is 0.4619337987090164
# Objective value at epoch t=87 is 0.46193405622667666
# Objective value at epoch t=88 is 0.46193444191491606
# Objective value at epoch t=89 is 0.46193240667234614
# Objective value at epoch t=90 is 0.4619341498994741
# Objective value at epoch t=91 is 0.4619327416807667
# Objective value at epoch t=92 is 0.46193115559197667
# Objective value at epoch t=93 is 0.4619322315464445
# Objective value at epoch t=94 is 0.46193138588448557
# Objective value at epoch t=95 is 0.4619297974522955
# Objective value at epoch t=96 is 0.4619299413594263
# Objective value at epoch t=97 is 0.46193019412501907
# Objective value at epoch t=98 is 0.4619297622896684
# Objective value at epoch t=99 is 0.461929380409028
# Objective value at epoch t=0 is 3.995944951311543
# Objective value at epoch t=1 is 3.540552169244285
# Objective value at epoch t=2 is 3.067151769577029
# Objective value at epoch t=3 is 2.746675458582395
# Objective value at epoch t=4 is 2.975231249941315
# Objective value at epoch t=5 is 2.3403093115699525
# Objective value at epoch t=6 is 2.128474240135789
# Objective value at epoch t=7 is 1.7309428167997
# Objective value at epoch t=8 is 1.428665692316575
# Objective value at epoch t=9 is 1.8680407015648661
# Objective value at epoch t=10 is 1.1872100670174406
# Objective value at epoch t=11 is 1.2188934173592816
# Objective value at epoch t=12 is 1.2437713172529763
# Objective value at epoch t=13 is 1.1205007731842165
# Objective value at epoch t=14 is 0.807007496611732
# Objective value at epoch t=15 is 0.8181242304291618
# Objective value at epoch t=16 is 0.826026686597741
# Objective value at epoch t=17 is 0.6563457476231604
# Objective value at epoch t=18 is 0.6681375737038737
# Objective value at epoch t=19 is 0.6254791482166167
# Objective value at epoch t=20 is 0.6080173751201103
# Objective value at epoch t=21 is 0.5459281448141783
# Objective value at epoch t=22 is 0.5150566204426115
# Objective value at epoch t=23 is 0.565543007110792
# Objective value at epoch t=24 is 0.5002558816079219
# Objective value at epoch t=25 is 0.5215621266270271
# Objective value at epoch t=26 is 0.5031847525557445
# Objective value at epoch t=27 is 0.48697656129141187
# Objective value at epoch t=28 is 0.49321409053981274
# Objective value at epoch t=29 is 0.48417533993145545
# Objective value at epoch t=30 is 0.48315423726511614
# Objective value at epoch t=31 is 0.47983450857491006
# Objective value at epoch t=32 is 0.4799204987056102
# Objective value at epoch t=33 is 0.4765762001714443
# Objective value at epoch t=34 is 0.4734103555357082
# Objective value at epoch t=35 is 0.4735979718670505
# Objective value at epoch t=36 is 0.4695831816267389
# Objective value at epoch t=37 is 0.4729033444066121
# Objective value at epoch t=38 is 0.4692361049798467
# Objective value at epoch t=39 is 0.47384510995052975
# Objective value at epoch t=40 is 0.4700577769660204
# Objective value at epoch t=41 is 0.4708517118850214
# Objective value at epoch t=42 is 0.47130790004852113
# Objective value at epoch t=43 is 0.4667593854186511
# Objective value at epoch t=44 is 0.4682353091145095
# Objective value at epoch t=45 is 0.4660639098221807
# Objective value at epoch t=46 is 0.46616455837932574
# Objective value at epoch t=47 is 0.46542384668328196
# Objective value at epoch t=48 is 0.46503045536616006
# Objective value at epoch t=49 is 0.4648250068142453
# Objective value at epoch t=50 is 0.4652640954320777
# Objective value at epoch t=51 is 0.4639078129409291
# Objective value at epoch t=52 is 0.46400380706645816
# Objective value at epoch t=53 is 0.46406187219422124
# Objective value at epoch t=54 is 0.463911623796902
# Objective value at epoch t=55 is 0.46379964950245095
# Objective value at epoch t=56 is 0.4636500825641402
# Objective value at epoch t=57 is 0.46344198024616634
# Objective value at epoch t=58 is 0.462756264773001
# Objective value at epoch t=59 is 0.46298289641587215
# Objective value at epoch t=60 is 0.4629931301810009
# Objective value at epoch t=61 is 0.4628913458930727
# Objective value at epoch t=62 is 0.4627955746584931
# Objective value at epoch t=63 is 0.4624354365840346
# Objective value at epoch t=64 is 0.4625245333191808
# Objective value at epoch t=65 is 0.46263670215052805
# Objective value at epoch t=66 is 0.46238684565991106
# Objective value at epoch t=67 is 0.4624893397192274
# Objective value at epoch t=68 is 0.4622763010350305
# Objective value at epoch t=69 is 0.46218819161383207
# Objective value at epoch t=70 is 0.46241635499161127
# Objective value at epoch t=71 is 0.4621888264486351
# Objective value at epoch t=72 is 0.4622302849738945
# Objective value at epoch t=73 is 0.46218703304997877
# Objective value at epoch t=74 is 0.46213613290856975
# Objective value at epoch t=75 is 0.4620921623670212
# Objective value at epoch t=76 is 0.462069705274347
# Objective value at epoch t=77 is 0.46210383300505775
# Objective value at epoch t=78 is 0.4620865331552763
# Objective value at epoch t=79 is 0.46203660524037
# Objective value at epoch t=80 is 0.4620235298864612
# Objective value at epoch t=81 is 0.4620296718533671
# Objective value at epoch t=82 is 0.4620308061391981
# Objective value at epoch t=83 is 0.46202171822293286
# Objective value at epoch t=84 is 0.462002922744105
# Objective value at epoch t=85 is 0.46198486298611485
# Objective value at epoch t=86 is 0.4619787974435332
# Objective value at epoch t=87 is 0.4619966198076286
# Objective value at epoch t=88 is 0.4619928763319841
# Objective value at epoch t=89 is 0.4619688715316926
# Objective value at epoch t=90 is 0.4619636068168525
# Objective value at epoch t=91 is 0.4619620426620504
# Objective value at epoch t=92 is 0.46196156015615186
# Objective value at epoch t=93 is 0.46195014080611063
# Objective value at epoch t=94 is 0.46195505708214135
# Objective value at epoch t=95 is 0.46194523964621786
# Objective value at epoch t=96 is 0.4619507787972566
# Objective value at epoch t=97 is 0.46194766234791745
# Objective value at epoch t=98 is 0.46194797136565563
# Objective value at epoch t=99 is 0.4619421161377728
# Objective value at epoch t=0 is 3.769168855887789
# Objective value at epoch t=1 is 3.493991167139478
# Objective value at epoch t=2 is 3.5779918270824873
# Objective value at epoch t=3 is 3.7815310257654025
# Objective value at epoch t=4 is 3.8845684937452334
# Objective value at epoch t=5 is 3.1091356366587943
# Objective value at epoch t=6 is 2.7853312358241613
# Objective value at epoch t=7 is 2.4585153241308086
# Objective value at epoch t=8 is 2.20875570188947
# Objective value at epoch t=9 is 2.210506913464692
# Objective value at epoch t=10 is 1.6688350399168492
# Objective value at epoch t=11 is 1.2912059444746071
# Objective value at epoch t=12 is 1.387221633436402
# Objective value at epoch t=13 is 1.4567926825542166
# Objective value at epoch t=14 is 0.9544703657514033
# Objective value at epoch t=15 is 1.1221673341333354
# Objective value at epoch t=16 is 0.9153218143020834
# Objective value at epoch t=17 is 0.7740380269664726
# Objective value at epoch t=18 is 0.6926603199049882
# Objective value at epoch t=19 is 0.8806131903175872
# Objective value at epoch t=20 is 0.9031664576708709
# Objective value at epoch t=21 is 0.545003570160185
# Objective value at epoch t=22 is 0.5345035155992768
# Objective value at epoch t=23 is 0.6330530177422048
# Objective value at epoch t=24 is 0.5317722630771355
# Objective value at epoch t=25 is 0.525625623190935
# Objective value at epoch t=26 is 0.5212391680336894
# Objective value at epoch t=27 is 0.49704929710339985
# Objective value at epoch t=28 is 0.510060095554705
# Objective value at epoch t=29 is 0.5053263049962525
# Objective value at epoch t=30 is 0.5020090470984246
# Objective value at epoch t=31 is 0.48310000058960545
# Objective value at epoch t=32 is 0.4731440550169128
# Objective value at epoch t=33 is 0.477761247087395
# Objective value at epoch t=34 is 0.48120755611210875
# Objective value at epoch t=35 is 0.47555254902280153
# Objective value at epoch t=36 is 0.4764512276384929
# Objective value at epoch t=37 is 0.4764069744706224
# Objective value at epoch t=38 is 0.470328336944353
# Objective value at epoch t=39 is 0.4717959532210413
# Objective value at epoch t=40 is 0.47034094327434134
# Objective value at epoch t=41 is 0.4694162577932402
# Objective value at epoch t=42 is 0.4676478511189729
# Objective value at epoch t=43 is 0.4677607502351567
# Objective value at epoch t=44 is 0.4665801164781259
# Objective value at epoch t=45 is 0.46800782631036775
# Objective value at epoch t=46 is 0.4665553446634
# Objective value at epoch t=47 is 0.4668829621448049
# Objective value at epoch t=48 is 0.46731665639081277
# Objective value at epoch t=49 is 0.46584808352995
# Objective value at epoch t=50 is 0.4643867783526165
# Objective value at epoch t=51 is 0.46473862751287764
# Objective value at epoch t=52 is 0.46395592485308634
# Objective value at epoch t=53 is 0.4646726945364838
# Objective value at epoch t=54 is 0.4642421570265037
# Objective value at epoch t=55 is 0.4648374374516685
# Objective value at epoch t=56 is 0.46364809729403883
# Objective value at epoch t=57 is 0.46370073396110756
# Objective value at epoch t=58 is 0.46339515986149565
# Objective value at epoch t=59 is 0.4634630849564238
# Objective value at epoch t=60 is 0.46303038847975736
# Objective value at epoch t=61 is 0.46288938714654604
# Objective value at epoch t=62 is 0.46263194763960946
# Objective value at epoch t=63 is 0.4631237052248123
# Objective value at epoch t=64 is 0.4624992094452492
# Objective value at epoch t=65 is 0.46257832914235364
# Objective value at epoch t=66 is 0.4624072388919841
# Objective value at epoch t=67 is 0.4625322841397967
# Objective value at epoch t=68 is 0.46249876216805735
# Objective value at epoch t=69 is 0.46236420426500696
# Objective value at epoch t=70 is 0.4622926145461209
# Objective value at epoch t=71 is 0.4622309014617433
# Objective value at epoch t=72 is 0.4622305269053745
# Objective value at epoch t=73 is 0.46226478319977915
# Objective value at epoch t=74 is 0.4622376119508484
# Objective value at epoch t=75 is 0.4621704394752997
# Objective value at epoch t=76 is 0.46213104916195596
# Objective value at epoch t=77 is 0.4621378344550802
# Objective value at epoch t=78 is 0.4621298016886926
# Objective value at epoch t=79 is 0.4620833642348547
# Objective value at epoch t=80 is 0.46207707370137385
# Objective value at epoch t=81 is 0.46205360137374046
# Objective value at epoch t=82 is 0.46206467464308726
# Objective value at epoch t=83 is 0.46201403273835284
# Objective value at epoch t=84 is 0.46202687406948
# Objective value at epoch t=85 is 0.4620060385219037
# Objective value at epoch t=86 is 0.4620196226143542
# Objective value at epoch t=87 is 0.462000952949776
# Objective value at epoch t=88 is 0.46199382357185736
# Objective value at epoch t=89 is 0.4619848262882897
# Objective value at epoch t=90 is 0.46197907839545876
# Objective value at epoch t=91 is 0.4619706360812293
# Objective value at epoch t=92 is 0.46196341006513214
# Objective value at epoch t=93 is 0.46195799598174886
# Objective value at epoch t=94 is 0.46196214483901343
# Objective value at epoch t=95 is 0.4619549849453316
# Objective value at epoch t=96 is 0.46196002600925556
# Objective value at epoch t=97 is 0.4619585065639826
# Objective value at epoch t=98 is 0.4619530639420152
# Objective value at epoch t=99 is 0.46194678588683075
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is 28.65371946381999
# Objective value at epoch t=3 is 32.034969685903576
# Objective value at epoch t=4 is 33.64130312353855
# Objective value at epoch t=5 is 30.529420731724002
# Objective value at epoch t=6 is 19.281698629015256
# Objective value at epoch t=7 is 19.712043435036684
# Objective value at epoch t=8 is 23.69459041695477
# Objective value at epoch t=9 is 15.548431818966312
# Objective value at epoch t=10 is 15.29465804754236
# Objective value at epoch t=11 is 17.973827947263896
# Objective value at epoch t=12 is 12.009505764930015
# Objective value at epoch t=13 is 12.413926318229306
# Objective value at epoch t=14 is 9.98642551886963
# Objective value at epoch t=15 is 10.50288382602362
# Objective value at epoch t=16 is 8.148982822117915
# Objective value at epoch t=17 is 7.185844566743445
# Objective value at epoch t=18 is 7.3080432390810275
# Objective value at epoch t=19 is 7.475812575618906
# Objective value at epoch t=20 is 6.488203246622922
# Objective value at epoch t=21 is 6.0686835264463355
# Objective value at epoch t=22 is 5.0660316976745206
# Objective value at epoch t=23 is 5.4813297850451
# Objective value at epoch t=24 is 4.575511460555335
# Objective value at epoch t=25 is 3.2999818721178835
# Objective value at epoch t=26 is 3.712973687985582
# Objective value at epoch t=27 is 2.968971300418277
# Objective value at epoch t=28 is 1.7540762145683568
# Objective value at epoch t=29 is 2.264959432996105
# Objective value at epoch t=30 is 1.572122398656704
# Objective value at epoch t=31 is 2.2083291371270937
# Objective value at epoch t=32 is 2.082717884357791
# Objective value at epoch t=33 is 1.6462037166627113
# Objective value at epoch t=34 is 1.228544559651036
# Objective value at epoch t=35 is 0.9865200561591605
# Objective value at epoch t=36 is 1.014279552381748
# Objective value at epoch t=37 is 0.7615910458614726
# Objective value at epoch t=38 is 0.9346507932947727
# Objective value at epoch t=39 is 1.0039151982261394
# Objective value at epoch t=40 is 0.7478521549596646
# Objective value at epoch t=41 is 0.7294309420791543
# Objective value at epoch t=42 is 0.6149864770261882
# Objective value at epoch t=43 is 0.6143740803433366
# Objective value at epoch t=44 is 0.5466347604411564
# Objective value at epoch t=45 is 0.5119661127228811
# Objective value at epoch t=46 is 0.5593376343638324
# Objective value at epoch t=47 is 0.546871936846794
# Objective value at epoch t=48 is 0.5054009492756014
# Objective value at epoch t=49 is 0.523427209018928
# Objective value at epoch t=50 is 0.5067450659573571
# Objective value at epoch t=51 is 0.4938180402768775
# Objective value at epoch t=52 is 0.4882812547097772
# Objective value at epoch t=53 is 0.47776811759432125
# Objective value at epoch t=54 is 0.4845532927351126
# Objective value at epoch t=55 is 0.48021126772271927
# Objective value at epoch t=56 is 0.47565466030992143
# Objective value at epoch t=57 is 0.47814035030076835
# Objective value at epoch t=58 is 0.47237999601545855
# Objective value at epoch t=59 is 0.47181777057647933
# Objective value at epoch t=60 is 0.4741114151057662
# Objective value at epoch t=61 is 0.47372980710531615
# Objective value at epoch t=62 is 0.4687185326747132
# Objective value at epoch t=63 is 0.4678884091531496
# Objective value at epoch t=64 is 0.4696291176999726
# Objective value at epoch t=65 is 0.46896364997253326
# Objective value at epoch t=66 is 0.46752040997429745
# Objective value at epoch t=67 is 0.4672534459407295
# Objective value at epoch t=68 is 0.4679456198691943
# Objective value at epoch t=69 is 0.4656383146082308
# Objective value at epoch t=70 is 0.46571347527657253
# Objective value at epoch t=71 is 0.46519539431676754
# Objective value at epoch t=72 is 0.46587204025063234
# Objective value at epoch t=73 is 0.4646964351554462
# Objective value at epoch t=74 is 0.4647680760264087
# Objective value at epoch t=75 is 0.46438184625113194
# Objective value at epoch t=76 is 0.46413337916503705
# Objective value at epoch t=77 is 0.4638191152316227
# Objective value at epoch t=78 is 0.4634969691759559
# Objective value at epoch t=79 is 0.4635707181003199
# Objective value at epoch t=80 is 0.4635275139743723
# Objective value at epoch t=81 is 0.46335782457386865
# Objective value at epoch t=82 is 0.46355112923735653
# Objective value at epoch t=83 is 0.4627918079091648
# Objective value at epoch t=84 is 0.46259768346966484
# Objective value at epoch t=85 is 0.46261228819634737
# Objective value at epoch t=86 is 0.4626121798130406
# Objective value at epoch t=87 is 0.4628588931605213
# Objective value at epoch t=88 is 0.46241331575899663
# Objective value at epoch t=89 is 0.4625601931547288
# Objective value at epoch t=90 is 0.46247235563828115
# Objective value at epoch t=91 is 0.46232677219761065
# Objective value at epoch t=92 is 0.4622030404361098
# Objective value at epoch t=93 is 0.46236708667319526
# Objective value at epoch t=94 is 0.46226391645463555
# Objective value at epoch t=95 is 0.46219686842951757
# Objective value at epoch t=96 is 0.4622498706412042
# Objective value at epoch t=97 is 0.4621226200601275
# Objective value at epoch t=98 is 0.46210093643147604
# Objective value at epoch t=99 is 0.462190899317933
# Objective value at epoch t=0 is inf
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is inf
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is inf
# Objective value at epoch t=15 is inf
# Objective value at epoch t=16 is inf
# Objective value at epoch t=17 is inf
# Objective value at epoch t=18 is inf
# Objective value at epoch t=19 is inf
# Objective value at epoch t=20 is inf
# Objective value at epoch t=21 is inf
# Objective value at epoch t=22 is inf
# Objective value at epoch t=23 is inf
# Objective value at epoch t=24 is inf
# Objective value at epoch t=25 is 35.43478604705176
# Objective value at epoch t=26 is 37.61730983413468
# Objective value at epoch t=27 is 26.026308528715283
# Objective value at epoch t=28 is 26.105101152316564
# Objective value at epoch t=29 is 23.23897513593075
# Objective value at epoch t=30 is 22.446465843401587
# Objective value at epoch t=31 is 18.915836698947782
# Objective value at epoch t=32 is 22.5538700386529
# Objective value at epoch t=33 is 13.142510193495
# Objective value at epoch t=34 is 10.65265843285304
# Objective value at epoch t=35 is 11.98521230356739
# Objective value at epoch t=36 is 11.014467504011185
# Objective value at epoch t=37 is 11.506047348603346
# Objective value at epoch t=38 is 12.71233465342305
# Objective value at epoch t=39 is 11.383689440983257
# Objective value at epoch t=40 is 6.274530826241557
# Objective value at epoch t=41 is 5.980706604248115
# Objective value at epoch t=42 is 5.892454969116361
# Objective value at epoch t=43 is 5.870677754751942
# Objective value at epoch t=44 is 3.748768321942009
# Objective value at epoch t=45 is 4.5787779291796635
# Objective value at epoch t=46 is 4.1946604773467495
# Objective value at epoch t=47 is 3.9908868318169994
# Objective value at epoch t=48 is 3.5209760782088724
# Objective value at epoch t=49 is 2.1050352324713044
# Objective value at epoch t=50 is 2.6621123953745016
# Objective value at epoch t=51 is 2.435370892829021
# Objective value at epoch t=52 is 2.1032043846905326
# Objective value at epoch t=53 is 1.7290996562382717
# Objective value at epoch t=54 is 1.4712802874750477
# Objective value at epoch t=55 is 1.358241297151812
# Objective value at epoch t=56 is 1.245895847373352
# Objective value at epoch t=57 is 1.0687528206374255
# Objective value at epoch t=58 is 0.8216434017295094
# Objective value at epoch t=59 is 1.0647213524994195
# Objective value at epoch t=60 is 0.9191726892067609
# Objective value at epoch t=61 is 0.9003841154517584
# Objective value at epoch t=62 is 0.8144088946541794
# Objective value at epoch t=63 is 0.6134590525303563
# Objective value at epoch t=64 is 0.6844987064194179
# Objective value at epoch t=65 is 0.5466259560034041
# Objective value at epoch t=66 is 0.5115377054467096
# Objective value at epoch t=67 is 0.5797167380898417
# Objective value at epoch t=68 is 0.5560325879262438
# Objective value at epoch t=69 is 0.5144373440781649
# Objective value at epoch t=70 is 0.515075741004805
# Objective value at epoch t=71 is 0.49596287952603274
# Objective value at epoch t=72 is 0.49664233840490335
# Objective value at epoch t=73 is 0.4862741410439983
# Objective value at epoch t=74 is 0.49353804612562435
# Objective value at epoch t=75 is 0.4835755197062106
# Objective value at epoch t=76 is 0.4973079744043246
# Objective value at epoch t=77 is 0.47681113716970075
# Objective value at epoch t=78 is 0.48154856526347184
# Objective value at epoch t=79 is 0.4756488717409435
# Objective value at epoch t=80 is 0.4770821091874791
# Objective value at epoch t=81 is 0.4697891834218876
# Objective value at epoch t=82 is 0.47463021980559433
# Objective value at epoch t=83 is 0.47116467085233804
# Objective value at epoch t=84 is 0.47242994894305135
# Objective value at epoch t=85 is 0.4711834863494976
# Objective value at epoch t=86 is 0.46797502973703364
# Objective value at epoch t=87 is 0.46911976622167295
# Objective value at epoch t=88 is 0.4663604003550311
# Objective value at epoch t=89 is 0.46647571740165966
# Objective value at epoch t=90 is 0.465888372175289
# Objective value at epoch t=91 is 0.46573042856040087
# Objective value at epoch t=92 is 0.4676037425262131
# Objective value at epoch t=93 is 0.4657278110428155
# Objective value at epoch t=94 is 0.46460693811222054
# Objective value at epoch t=95 is 0.4644261831884239
# Objective value at epoch t=96 is 0.464134188448227
# Objective value at epoch t=97 is 0.46452819793845973
# Objective value at epoch t=98 is 0.4646195757580668
# Objective value at epoch t=99 is 0.4633054004813192
# Objective value at epoch t=0 is inf
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in exp
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: overflow encountered in exp
# Objective value at epoch t=1 is inf
# Objective value at epoch t=2 is inf
# Objective value at epoch t=3 is inf
# Objective value at epoch t=4 is inf
# Objective value at epoch t=5 is inf
# Objective value at epoch t=6 is inf
# Objective value at epoch t=7 is inf
# Objective value at epoch t=8 is inf
# Objective value at epoch t=9 is inf
# Objective value at epoch t=10 is inf
# Objective value at epoch t=11 is inf
# Objective value at epoch t=12 is inf
# Objective value at epoch t=13 is inf
# Objective value at epoch t=14 is inf
# Objective value at epoch t=15 is inf
# Objective value at epoch t=16 is inf
# Objective value at epoch t=17 is inf
# Objective value at epoch t=18 is inf
# Objective value at epoch t=19 is inf
# Objective value at epoch t=20 is inf
# Objective value at epoch t=21 is inf
# Objective value at epoch t=22 is inf
# Objective value at epoch t=23 is inf
# Objective value at epoch t=24 is inf
# Objective value at epoch t=25 is inf
# Objective value at epoch t=26 is inf
# Objective value at epoch t=27 is inf
# Objective value at epoch t=28 is inf
# Objective value at epoch t=29 is inf
# Objective value at epoch t=30 is inf
# Objective value at epoch t=31 is inf
# Objective value at epoch t=32 is inf
# Objective value at epoch t=33 is inf
# Objective value at epoch t=34 is inf
# Objective value at epoch t=35 is inf
# Objective value at epoch t=36 is inf
# Objective value at epoch t=37 is inf
# Objective value at epoch t=38 is inf
# Objective value at epoch t=39 is inf
# Objective value at epoch t=40 is inf
# Objective value at epoch t=41 is inf
# Objective value at epoch t=42 is inf
# Objective value at epoch t=43 is inf
# Objective value at epoch t=44 is inf
# Objective value at epoch t=45 is inf
# Objective value at epoch t=46 is inf
# Objective value at epoch t=47 is 33.871829849886566
# Objective value at epoch t=48 is 28.569700482737538
# Objective value at epoch t=49 is 21.74660259105618
# Objective value at epoch t=50 is 24.91437283734993
# Objective value at epoch t=51 is 30.026477570972226
# Objective value at epoch t=52 is 12.253196622050348
# Objective value at epoch t=53 is 19.393706619859163
# Objective value at epoch t=54 is 24.980523399696278
# Objective value at epoch t=55 is 17.1508028738218
# Objective value at epoch t=56 is 15.243039231467128
# Objective value at epoch t=57 is 11.998252947337878
# Objective value at epoch t=58 is 12.912898459597596
# Objective value at epoch t=59 is 8.50320947440184
# Objective value at epoch t=60 is 6.677111022161893
# Objective value at epoch t=61 is 7.2073893404891125
# Objective value at epoch t=62 is 8.287246721132547
# Objective value at epoch t=63 is 5.9435195754309715
# Objective value at epoch t=64 is 6.667594931030311
# Objective value at epoch t=65 is 5.266844576647537
# Objective value at epoch t=66 is 5.384145667549089
# Objective value at epoch t=67 is 3.2927880996947856
# Objective value at epoch t=68 is 4.069783733910696
# Objective value at epoch t=69 is 4.097209493770764
# Objective value at epoch t=70 is 2.8734108613771
# Objective value at epoch t=71 is 2.534755435772531
# Objective value at epoch t=72 is 2.273190544590637
# Objective value at epoch t=73 is 1.8784568427887258
# Objective value at epoch t=74 is 1.704451116602863
# Objective value at epoch t=75 is 2.169427688912953
# Objective value at epoch t=76 is 1.6514571863707714
# Objective value at epoch t=77 is 1.3655077499747714
# Objective value at epoch t=78 is 1.3164999303946587
# Objective value at epoch t=79 is 1.0281624693721734
# Objective value at epoch t=80 is 1.1978828056705029
# Objective value at epoch t=81 is 0.9731467342434768
# Objective value at epoch t=82 is 0.7215588882349413
# Objective value at epoch t=83 is 0.8879624758075899
# Objective value at epoch t=84 is 0.6039113299690485
# Objective value at epoch t=85 is 0.7289648748045712
# Objective value at epoch t=86 is 0.6579062680753848
# Objective value at epoch t=87 is 0.6907442394450726
# Objective value at epoch t=88 is 0.5220436563309796
# Objective value at epoch t=89 is 0.5640729723505669
# Objective value at epoch t=90 is 0.5279922020145253
# Objective value at epoch t=91 is 0.5479516003471601
# Objective value at epoch t=92 is 0.5080511150152726
# Objective value at epoch t=93 is 0.49365664573796086
# Objective value at epoch t=94 is 0.49999994447891344
# Objective value at epoch t=95 is 0.4732464333628804
# Objective value at epoch t=96 is 0.4914976417349295
# Objective value at epoch t=97 is 0.48927269506382387
# Objective value at epoch t=98 is 0.47194425695030395
# Objective value at epoch t=99 is 0.48124471518079276

# %%
print(errors_train8)
print(numpy.array(objvals_mbsgd8)[:,-1])
print(errors_test8)
# Out:
# [0.2546875, 0.253125, 0.2390625, 0.215625, 0.215625, 0.215625, 0.215625, 0.215625, 0.215625, 0.2234375]
# [0.68466412 0.62539497 0.48929258 0.4619346  0.46192936 0.46194566
#  0.46194851 0.46215025 0.46378635 0.48056514]
# [0.25, 0.25, 0.28125, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25]

# %%
fig = plt.figure(figsize=(6, 4))

cutoff = 0

stepsizes_log = numpy.log10(stepsizes)

line0, = plt.plot(stepsizes_log, errors_train8, '--b', LineWidth = 2)
line1, = plt.plot(stepsizes_log, errors_test8, '-c', LineWidth = 2)
line2, = plt.plot(stepsizes_log, errors_train64, '--r', LineWidth = 2)
line3, = plt.plot(stepsizes_log, errors_test64, '-m', LineWidth = 2)
plt.xlabel('Log of step sizes', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1, line2, line3], ['MB-SGD8 Train', 'MB-SGD8 Test', 'MB-SGD64 Train', 'MB-SGD64 Test'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('step_sizes.pdf', format='pdf', dpi=1200)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   from ipykernel import kernelapp as app
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   app.launch_new_instance()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later

# %% [markdown]
# According to the graph, the learning rate where the train and test objective values are equal is around 0.0001. It is at this point that the model is not underfit nor overfit.

# %% [markdown]
# # 7. Plot and compare GD, SGD, and MB-SGD

# %% [markdown]
# You are required to compare the following algorithms:
#
# - Gradient descent (GD)
#
# - SGD
#
# - MB-SGD with b=8
#
# - MB-SGD with b=64
#
# Follow the code in Section 4 to plot ```objective function value``` against ```epochs```. There should be four curves in the plot; each curve corresponds to one algorithm.

# %% [markdown]
# Hint: Logistic regression with $\ell_2$-norm regularization is a strongly convex optimization problem. All the algorithms will converge to the same solution. **In the end, the ``objective function value`` of the 4 algorithms will be the same. If not the same, your implementation must be wrong. Do NOT submit wrong code and wrong result!**

# %%
epochs_mbsgd8 = range(len(objvals_mbsgd8[0]))
epochs_mbsgd64 = range(len(objvals_mbsgd64[0]))


fig = plt.figure(figsize=(6, 4))

cutoff = 0

line0, = plt.plot(epochs_gd[cutoff:], objvals_gd[cutoff:], '--b', LineWidth=2)
line1, = plt.plot(epochs_sgd[cutoff:], objvals_sgd[cutoff:], '-r', LineWidth=2)
line2, = plt.plot(epochs_mbsgd8[cutoff:], objvals_mbsgd8[3][cutoff:], '--g', LineWidth = 2)
line3, = plt.plot(epochs_mbsgd64[cutoff:], objvals_mbsgd64[3][cutoff:], '-c', LineWidth = 2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1, line2, line3], ['GD', 'SGD', 'MB-SGD8', 'MB-SGD64'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_all.pdf', format='pdf', dpi=1200)

cutoff = 20

line0, = plt.plot(epochs_gd[cutoff:], objvals_gd[cutoff:], '--b', LineWidth=2)
line1, = plt.plot(epochs_sgd[cutoff:], objvals_sgd[cutoff:], '-r', LineWidth=2)
line2, = plt.plot(epochs_mbsgd8[cutoff:], objvals_mbsgd8[3][cutoff:], '--g', LineWidth = 2)
line3, = plt.plot(epochs_mbsgd64[cutoff:], objvals_mbsgd64[3][cutoff:], '-c', LineWidth = 2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1, line2, line3], ['GD', 'SGD', 'MB-SGD8', 'MB-SGD64'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_all.pdf', format='pdf', dpi=1200)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if __name__ == '__main__':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   from ipykernel import kernelapp as app
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   app.launch_new_instance()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:24: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:27: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:31: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
